# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from typing import Optional, Union, Tuple
import copy
from scipy.stats import multivariate_normal
from types import SimpleNamespace
import math
from das.smc_utils import compute_ess_from_log_w, normalize_log_weights, resampling_function, normalize_weights, adaptive_tempering

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

import torch
import random
import torch.backends.cudnn as cudnn

torch.manual_seed(42)
torch.cuda.manual_seed(42)
torch.cuda.manual_seed_all(42)
np.random.seed(42)
cudnn.benchmark = False
cudnn.deterministic = True
random.seed(42)
# Out:
# Using device: cuda

# %% [markdown]
# ## Define Functions and Classes for Diffusion

# %%
class SimpleUNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(4, 64),  # 3D input + time
            nn.ReLU(),
            # nn.Linear(64, 128),
            # nn.ReLU(),
            # nn.Linear(128, 64),
            nn.Linear(64, 64),
            nn.ReLU(),
            nn.Linear(64, 3)  # 3D output
        )

    def forward(self, x, t):
        x = torch.cat([x, t.unsqueeze(-1)], dim=-1)
        return self.net(x)

# %%
def linear_beta_schedule(timesteps, start=0.0001, end=0.02):
    return torch.linspace(start, end, timesteps)

class DDIMScheduler:
    def __init__(self, num_train_timesteps=1000, beta_start=0.0001, beta_end=0.02, device='cpu'):
        self.num_train_timesteps = num_train_timesteps
        
        self.betas = linear_beta_schedule(num_train_timesteps, beta_start, beta_end).to(device)
        self.alphas = 1.0 - self.betas
        self.alphas_cumprod = torch.cumprod(self.alphas, dim=0)
        
        self.final_alpha_cumprod = self.alphas_cumprod[0]
        self.num_inference_steps = None
        
    def set_timesteps(self, num_inference_steps):
        self.num_inference_steps = num_inference_steps
        self.timesteps = torch.linspace(self.num_train_timesteps - 1, 0, num_inference_steps, dtype=torch.long)
        
    def _get_variance(self, timestep, prev_timestep):
        alpha_prod_t = self.alphas_cumprod[timestep]
        alpha_prod_t_prev = torch.where(
            prev_timestep >= 0,
            self.alphas_cumprod[prev_timestep],
            self.final_alpha_cumprod
        )
        beta_prod_t = 1 - alpha_prod_t
        beta_prod_t_prev = 1 - alpha_prod_t_prev
        
        variance = (beta_prod_t_prev / beta_prod_t) * (1 - alpha_prod_t / alpha_prod_t_prev)
        return variance

# %%
def ddim_step_with_logprob(
    scheduler,
    model_output: torch.FloatTensor,
    timestep: int,
    sample: torch.FloatTensor,
    eta: float = 0.0,
    prev_sample: Optional[torch.FloatTensor] = None,
) -> Tuple[torch.FloatTensor, torch.FloatTensor]:
    """
    Perform a single DDIM step with log probability calculation.
    
    Args:
        scheduler: The DDIMScheduler object.
        model_output: The output from the UNet model.
        timestep: The current timestep.
        sample: The current sample (x_t).
        eta: The eta parameter for adding noise (0 for DDIM, 1 for DDPM).
        prev_sample: Optional; the previous sample (x_{t-1}) if available.
    
    Returns:
        A tuple containing:
        - The previous sample (x_{t-1})
        - The log probability of the step
    """
    # 1. get previous step value (=t-1)
    prev_timestep = timestep - scheduler.num_train_timesteps // scheduler.num_inference_steps

    # 2. compute alphas, betas
    alpha_prod_t = scheduler.alphas_cumprod[timestep]
    alpha_prod_t_prev = torch.where(
        prev_timestep >= 0,
        scheduler.alphas_cumprod[prev_timestep],
        scheduler.final_alpha_cumprod
    )

    beta_prod_t = 1 - alpha_prod_t

    # 3. compute predicted original sample from predicted noise
    pred_original_sample = (sample - beta_prod_t.sqrt().unsqueeze(-1) * model_output) / alpha_prod_t.sqrt().unsqueeze(-1)
    
    # 4. compute variance
    variance = scheduler._get_variance(timestep, prev_timestep)
    std_dev_t = eta * variance.sqrt()

    # 5. compute "direction pointing to x_t" of formula (12) from https://arxiv.org/pdf/fontsize10.02502.pdf
    pred_sample_direction = (1 - alpha_prod_t_prev - std_dev_t**2).sqrt().unsqueeze(-1) * model_output

    # 6. compute x_t without "random noise" of formula (12) from https://arxiv.org/pdf/2010.02502.pdf
    prev_sample_mean = alpha_prod_t_prev.sqrt().unsqueeze(-1) * pred_original_sample + pred_sample_direction

    # 6. Add noise
    if prev_sample is None:
        noise = torch.randn(model_output.shape, device=device, dtype=model_output.dtype)
        prev_sample = prev_sample_mean + std_dev_t.unsqueeze(-1) * noise
    
    # 7. Compute log probability
    log_prob = _compute_gaussian_log_prob(prev_sample, prev_sample_mean, std_dev_t.unsqueeze(-1)).mean(-1)

    return prev_sample, log_prob

def _compute_gaussian_log_prob(x, mean, std):
    """Compute log probability for Gaussian distribution."""
    log_scale = torch.log(std)
    return -((x - mean) ** 2) / (2 * std ** 2) - log_scale - math.log(math.sqrt(2 * math.pi))

# %%
def ddim_step_KL(
    scheduler: DDIMScheduler,
    model_output: torch.FloatTensor,
    old_model_output: torch.FloatTensor,
    timestep: torch.LongTensor,
    sample: torch.FloatTensor,
    eta: float = 0.0,
    generator=None,
    variance_noise: Optional[torch.FloatTensor] = None,
) -> Union[Tuple[torch.FloatTensor, torch.FloatTensor], Tuple]:
    
    # 1. get previous step value (=t-1)
    prev_timestep = timestep - scheduler.num_train_timesteps // scheduler.num_inference_steps

    # 2. compute alphas, betas
    alpha_prod_t = scheduler.alphas_cumprod[timestep]
    alpha_prod_t_prev = torch.where(
        prev_timestep >= 0,
        scheduler.alphas_cumprod[prev_timestep],
        scheduler.final_alpha_cumprod
    )

    beta_prod_t = 1 - alpha_prod_t

    # 3. compute predicted original sample from predicted noise
    pred_original_sample = (sample - beta_prod_t.sqrt().unsqueeze(-1) * model_output) / alpha_prod_t.sqrt().unsqueeze(-1)
    old_pred_original_sample = (sample - beta_prod_t.sqrt().unsqueeze(-1) * old_model_output) / alpha_prod_t.sqrt().unsqueeze(-1)

    # 4. compute variance
    variance = scheduler._get_variance(timestep, prev_timestep)
    std_dev_t = eta * variance.sqrt()

    # 5. compute "direction pointing to x_t" of formula (12) from https://arxiv.org/pdf/2010.02502.pdf
    pred_sample_direction = (1 - alpha_prod_t_prev - std_dev_t**2).sqrt().unsqueeze(-1) * model_output
    old_pred_sample_direction = (1 - alpha_prod_t_prev - std_dev_t**2).sqrt().unsqueeze(-1) * old_model_output

    # 6. compute x_t without "random noise" of formula (12) from https://arxiv.org/pdf/2010.02502.pdf
    prev_sample_mean = alpha_prod_t_prev.sqrt().unsqueeze(-1) * pred_original_sample + pred_sample_direction
    old_prev_sample_mean = alpha_prod_t_prev.sqrt().unsqueeze(-1) * old_pred_original_sample + old_pred_sample_direction

    if eta > 0 and timestep[0] > 0:
        device = model_output.device
        noise = torch.randn(model_output.shape, generator=generator, device=device, dtype=model_output.dtype)
        variance = std_dev_t.unsqueeze(-1) * noise

        prev_sample = prev_sample_mean + variance
        # print((prev_sample_mean - old_prev_sample_mean))
        kl_terms = (prev_sample_mean - old_prev_sample_mean)**2 / (2 * (std_dev_t**2).unsqueeze(-1))
        kl_terms = kl_terms.sum(dim=-1)  # Sum over the 2D dimensions
        # print(kl_terms)
    else:
        prev_sample = prev_sample_mean
        kl_terms = torch.zeros(prev_sample_mean.size(0), device=prev_sample_mean.device)

    # 7. Compute log probability
    log_prob = _compute_gaussian_log_prob(prev_sample, prev_sample_mean, std_dev_t.unsqueeze(-1)).mean(-1)

    return prev_sample, log_prob, kl_terms

# %%
@torch.no_grad()
def ddim_sample(model, scheduler, n, device, eta=1.0):
    x = torch.randn((n, 3)).to(device)
    
    for i, t in enumerate(scheduler.timesteps):
        t_tensor = torch.full((n,), scheduler.timesteps[i], device=device) # torch.full((n,), t, device=device).long()
        model_output = model(x, t_tensor / scheduler.num_train_timesteps)
        x, _, _ = ddim_step_KL(scheduler, model_output, 0., t_tensor, x, eta)
    
    return x

# %% [markdown]
# ## Define Data Distribution (Swill roll)
# ## Define Reward, KL penalty coefficient, and Corresponding Target Distribution

# %%
import numpy as np
import torch
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def compute_reward(x):
    """Compute reward for 3D points"""
    if isinstance(x, torch.Tensor):
        x_squared = torch.clamp(x**2, max=10000)
        # Modified reward function for 3D - you can adjust this
        return - x_squared[:, 0] / 100 - x_squared[:, 1] / 100 - x_squared[:, 2]
    else:
        x_squared = x**2
        x_squared = np.where(x_squared > 10000, 10000, x_squared)
        return - x_squared[:, 0] / 100 - x_squared[:, 1] / 100 - x_squared[:, 2]

def generate_swiss_roll_samples(n_samples, noise=0.1):
    """Generate larger-scale swiss roll samples"""
    t = 3 * np.pi * (0.5 + np.random.rand(n_samples))  # increased range
    x = t * np.cos(t) / 2  # less division for larger scale
    y = t * np.sin(t) / 2
    z = 6 * np.random.rand(n_samples) - 3  # -3 ~ 3
    
    samples = np.column_stack([x, y, z])
    samples += noise * np.random.randn(n_samples, 3)
    
    return samples

def swiss_roll_pdf(x, noise=0.1):
    """Faster swiss roll PDF using vectorized operations"""
    # Generate fewer manifold points for comparison
    n_manifold = 1000
    t = 2 * np.pi * (1 + np.random.rand(n_manifold))
    manifold = np.column_stack([
        t * np.cos(t) / 2,
        t * np.sin(t) / 2,
        6 * np.random.rand(n_manifold) - 3
    ])
    
    # Vectorized distance computation
    x_expanded = x[:, np.newaxis, :]
    manifold_expanded = manifold[np.newaxis, :, :]
    distances = np.sum((x_expanded - manifold_expanded) ** 2, axis=2)
    min_distances = np.min(distances, axis=1)
    
    return np.exp(-min_distances / (2 * noise**2)) / ((2 * np.pi * noise**2)**(3/2))

def target_distribution_pdf(x, noise=0.1, kl_weight=1.0):
    """
    Compute target distribution PDF using swiss roll base distribution
    """
    base_pdf = swiss_roll_pdf(x, noise)
    reward = compute_reward(x)
    return base_pdf * np.exp(reward / kl_weight)

def sample_target_distribution(n_samples, noise=0.1, kl_weight=1.0):
    """
    Sample from target distribution using rejection sampling
    """
    accepted_samples = []
    proposal_std = noise * 2  # Wider proposal distribution
    
    # Estimate normalization constant
    base_samples = generate_swiss_roll_samples(10000, noise)
    rewards = compute_reward(base_samples)
    max_reward = np.max(rewards)
    
    while len(accepted_samples) < n_samples:
        # Generate batch of proposals
        batch_size = min(10000, n_samples * 5)
        proposals = generate_swiss_roll_samples(batch_size, noise)
        
        # Compute acceptance probabilities
        rewards = compute_reward(proposals)
        accept_probs = np.exp((rewards - max_reward) / kl_weight)
        
        # Accept/reject
        uniform_samples = np.random.rand(batch_size)
        accepted = proposals[uniform_samples < accept_probs]
        accepted_samples.extend(accepted)
    
    accepted_samples = np.array(accepted_samples[:n_samples])
    return accepted_samples

# Example usage
n_samples = 10000
noise = 0.3
kl_weight = 1.

# Generate base swiss roll samples
base_samples = generate_swiss_roll_samples(n_samples, noise)
base_samples_tensor = torch.FloatTensor(base_samples).to(device)
base_rewards = compute_reward(base_samples)
base_reward = base_rewards.mean().item()

# Generate target distribution samples
target_samples = sample_target_distribution(n_samples, noise, kl_weight)
target_samples_tensor = torch.FloatTensor(target_samples).to(device)

# Compute average reward for target distribution
target_rewards = compute_reward(target_samples_tensor)
target_reward = target_rewards.mean().item()
print(f"Average target reward: {target_reward}")

def plot_samples_3d(base_samples, target_samples):
    """Visualize both base and target distributions"""
    fig = plt.figure(figsize=(15, 7))
    
    # Plot base distribution
    ax1 = fig.add_subplot(121, projection='3d')
    ax1.scatter(base_samples[:, 0], base_samples[:, 1], base_samples[:, 2], 
                c='blue', alpha=0.6, s=1)
    ax1.set_title('Base Swiss Roll Distribution')
    
    # Plot target distribution
    ax2 = fig.add_subplot(122, projection='3d')
    ax2.scatter(target_samples[:, 0], target_samples[:, 1], target_samples[:, 2],
                c='red', alpha=0.6, s=1)
    ax2.set_title('Target Distribution')
    
    plt.show()

# Visualize the distributions
plot_samples_3d(base_samples, target_samples)
# Out:
# Average target reward: -0.7248051166534424

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def plot_3d_points(points, rewards=None, title="3D Points", figsize=(10, 10), 
                  view_angle=(20, 45), cmap='viridis', alpha=0.6, point_size=10):
    """
    Plot 3D points with optional reward-based coloring
    
    Parameters:
        points: np.array of shape (n_points, 3)
        rewards: np.array of shape (n_points,) or None
        title: str, plot title
        figsize: tuple, figure size
        view_angle: tuple (elevation, azimuth)
        cmap: str, colormap name
        alpha: float, point transparency
        point_size: float, size of points
    """
    fig = plt.figure(figsize=figsize)
    ax = fig.add_subplot(111, projection='3d')
    
    # If no rewards provided, use uniform color
    colors = rewards if rewards is not None else 'blue'
    
    # Plot points
    scatter = ax.scatter(points[:, 0], points[:, 1], points[:, 2],
                        c=colors,
                        cmap=cmap,
                        s=point_size,
                        alpha=alpha)
    
    # Add colorbar if rewards provided
    if rewards is not None:
        plt.colorbar(scatter, label='Reward')
    
    # Set viewing angle
    ax.view_init(*view_angle)
    
    # Labels
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    plt.title(title)
    
    plt.show()

# %%
# For base distribution:
plot_3d_points(base_samples, rewards=base_rewards, title="Base Distribution")

# For target distribution:
plot_3d_points(target_samples, rewards=target_rewards.cpu(), title="Target Distribution")

# %% [markdown]
# ## Pre-training

# %%
# Hyperparameters
num_train_timesteps = 1000

# Initialize scheduler
scheduler = DDIMScheduler(num_train_timesteps=num_train_timesteps, device=device)

# Initialize models and optimizer
pre_trained_model = SimpleUNet().to(device)
optimizer = optim.Adam(pre_trained_model.parameters(), lr=1e-3)

# %%
data = base_samples_tensor

# Pre-training loop
epochs = 5000
for epoch in range(epochs):
    optimizer.zero_grad()
    t = torch.randint(0, num_train_timesteps, (n_samples,), device=device).long()
    noise = torch.randn_like(data)
    noisy_data = scheduler.alphas_cumprod[t].sqrt().unsqueeze(-1) * data + \
                 (1 - scheduler.alphas_cumprod[t]).sqrt().unsqueeze(-1) * noise
    predicted_noise = pre_trained_model(noisy_data, t.float() / num_train_timesteps)
    loss = F.mse_loss(predicted_noise, noise)
    loss.backward()
    optimizer.step()
    if epoch % 100 == 0:
        print(f"Pre-training Epoch {epoch}, Loss: {loss.item()}")
# Out:
# Pre-training Epoch 0, Loss: 1.0346126556396484
# Pre-training Epoch 100, Loss: 0.5519130229949951
# Pre-training Epoch 200, Loss: 0.4903052747249603
# Pre-training Epoch 300, Loss: 0.45071661472320557
# Pre-training Epoch 400, Loss: 0.4425705671310425
# Pre-training Epoch 500, Loss: 0.4292251467704773
# Pre-training Epoch 600, Loss: 0.4304840564727783
# Pre-training Epoch 700, Loss: 0.42083269357681274
# Pre-training Epoch 800, Loss: 0.4220609962940216
# Pre-training Epoch 900, Loss: 0.41749563813209534
# Pre-training Epoch 1000, Loss: 0.42289668321609497
# Pre-training Epoch 1100, Loss: 0.41010355949401855
# Pre-training Epoch 1200, Loss: 0.416315495967865
# Pre-training Epoch 1300, Loss: 0.41906431317329407
# Pre-training Epoch 1400, Loss: 0.4136712849140167
# Pre-training Epoch 1500, Loss: 0.4079698622226715
# Pre-training Epoch 1600, Loss: 0.41076549887657166
# Pre-training Epoch 1700, Loss: 0.4197770357131958
# Pre-training Epoch 1800, Loss: 0.40706637501716614
# Pre-training Epoch 1900, Loss: 0.4145554304122925
# Pre-training Epoch 2000, Loss: 0.404725581407547
# Pre-training Epoch 2100, Loss: 0.40717533230781555
# Pre-training Epoch 2200, Loss: 0.4115079939365387
# Pre-training Epoch 2300, Loss: 0.41413614153862
# Pre-training Epoch 2400, Loss: 0.4102634787559509
# Pre-training Epoch 2500, Loss: 0.4012031853199005
# Pre-training Epoch 2600, Loss: 0.3987348675727844
# Pre-training Epoch 2700, Loss: 0.40815913677215576
# Pre-training Epoch 2800, Loss: 0.402079701423645
# Pre-training Epoch 2900, Loss: 0.4084135591983795
# Pre-training Epoch 3000, Loss: 0.40439581871032715
# Pre-training Epoch 3100, Loss: 0.40163320302963257
# Pre-training Epoch 3200, Loss: 0.4181642532348633
# Pre-training Epoch 3300, Loss: 0.3897663354873657
# Pre-training Epoch 3400, Loss: 0.40210357308387756
# Pre-training Epoch 3500, Loss: 0.40687838196754456
# Pre-training Epoch 3600, Loss: 0.40284353494644165
# Pre-training Epoch 3700, Loss: 0.4046512842178345
# Pre-training Epoch 3800, Loss: 0.3973764479160309
# Pre-training Epoch 3900, Loss: 0.4066711962223053
# Pre-training Epoch 4000, Loss: 0.40195292234420776
# Pre-training Epoch 4100, Loss: 0.40330925583839417
# Pre-training Epoch 4200, Loss: 0.3951038420200348
# Pre-training Epoch 4300, Loss: 0.3985203206539154
# Pre-training Epoch 4400, Loss: 0.39723482728004456
# Pre-training Epoch 4500, Loss: 0.4011654257774353
# Pre-training Epoch 4600, Loss: 0.3880020081996918
# Pre-training Epoch 4700, Loss: 0.40348848700523376
# Pre-training Epoch 4800, Loss: 0.394671231508255
# Pre-training Epoch 4900, Loss: 0.4029625356197357

# %%
# Set the number of inference steps before fine-tuning and sampling
num_inference_steps = 100
scheduler.set_timesteps(num_inference_steps)

# %%
# Generate pre-trained samples
pre_trained_samples = ddim_sample(pre_trained_model, scheduler, 10000, device)
pre_trained_rewards = compute_reward(pre_trained_samples)
pre_trained_reward = pre_trained_rewards.mean().item()
pre_trained_samples = pre_trained_samples.cpu().numpy()

# %%
plot_3d_points(pre_trained_samples, rewards=pre_trained_rewards.cpu(), title="Pre-trained Distribution")

# %% [markdown]
# ## RL fine-tuning with KL regularization

# %%
class DDPO:
    def __init__(self, model, scheduler, config):
        self.model = model
        self.scheduler = scheduler
        self.config = config
        self.optimizer = optim.Adam(self.model.parameters(), lr=config.learning_rate)

    def train_step(self, old_log_probs, states, actions, advantages):
        for _ in range(self.config.ppo_epochs):
            for batch in self.get_batches(old_log_probs, states, actions, advantages):
                batch_old_log_probs, batch_states, batch_actions, batch_advantages = batch
                self.optimizer.zero_grad()
                total_loss = 0

                for j in range(self.scheduler.num_inference_steps - 1):
                    t_tensor = torch.full((batch_states.shape[0],), self.scheduler.timesteps[j], device=batch_states.device)
                    
                    # Compute model output
                    model_output = self.model(batch_states[:, j], t_tensor.float() / self.scheduler.num_train_timesteps)
                    
                    _, log_probs = ddim_step_with_logprob(
                        self.scheduler, 
                        model_output, 
                        t_tensor, 
                        batch_states[:, j], 
                        eta=self.config.eta,
                        prev_sample=batch_actions[:, j]
                    )
                    if torch.isnan(log_probs).any() or torch.isnan(batch_old_log_probs[:, j]).any():
                        print(j)
                        print(t_tensor[0])
                        print(log_probs)
                        print(batch_old_log_probs[:, j])
                        raise e

                    # Compute loss
                    ratio = torch.exp(log_probs - batch_old_log_probs[:, j])
                    # print(ratio)
                    unclipped_loss = - ratio * batch_advantages[:, j]
                    clipped_loss = - torch.clamp(ratio, 1.0 - self.config.clip_range, 1.0 + self.config.clip_range) * batch_advantages[:, j]
                    loss = torch.max(unclipped_loss, clipped_loss).mean()
                    # print(unclipped_loss)
                    # print(clipped_loss)
                    # print(loss)
                    # total_loss += loss

                    loss.backward()
                    # Clip gradients and perform optimization step
                    nn.utils.clip_grad_norm_(self.model.parameters(), self.config.max_grad_norm)
                    # Calculate mean and max of the gradients
                    total_norm = 0.0
                    num_params = 0
                    max_grad = 0.0
                    grad_sum = 0.0
                    norm_sum = 0.0
                    for param in self.model.parameters():
                        if param.grad is not None:
                            grad_norm = param.grad.data.norm(2)  # L2 norm of the gradients
                            grad_sum += grad_norm.item()
                            max_grad = max(max_grad, grad_norm.item())
                            norm_sum += param.data.norm(2).item()
                            num_params += 1
                    # print(f"Mean gradient norm: {grad_sum / num_params}, Max gradient norm: {max_grad}")
                    # print(f"Mean parameter norm: {norm_sum / num_params}")

                    self.optimizer.step()
                    self.optimizer.zero_grad()
                # total_loss.backward()
                # optimizer.step()
                # optimizer.zero_grad()

    def get_batches(self, old_log_probs, states, actions, advantages):
        batch_size = self.config.batch_size
        indices = np.random.permutation(old_log_probs.shape[0])
        for start_idx in range(0, old_log_probs.shape[0], batch_size):
            end_idx = start_idx + batch_size
            batch_indices = indices[start_idx:end_idx]
            yield (old_log_probs[batch_indices], states[batch_indices],
                   actions[batch_indices], advantages[batch_indices])

    def fine_tune(self, reward_fn, num_epochs, samples_per_epoch, device):
        for epoch in range(num_epochs):
            # Sample trajectories
            with torch.no_grad():
                latents, old_log_probs, kl_divs = self.sample_trajectories(samples_per_epoch, device)

                # Compute rewards
                rewards = reward_fn(latents[:, -1])

            states = latents[:, :-1]
            actions = latents[:, 1:]

            # Compute advantages using the original DDPO method
            advantages = ((rewards - rewards.mean()) / (rewards.std() + 1e-8)).repeat(self.scheduler.num_inference_steps, 1).transpose(0, 1) + self.config.kl_weight * kl_divs

            # Update policy
            self.train_step(old_log_probs, states, actions, advantages)

            # Log progress
            print(f"Epoch {epoch + 1}/{num_epochs}, Mean Reward: {rewards.mean().item():.4f}, Mean KL Div: {kl_divs.sum(dim=1).mean().item():.4f}")

    def sample_trajectories(self, num_samples, device):
        latents = torch.randn((num_samples, 3)).to(device)
        all_latents = [latents]
        all_log_probs = []
        all_kl_divs = []

        # Assuming states is of shape (num_samples, 2)
        for i, t in enumerate(self.scheduler.timesteps):
            t_tensor = torch.full((num_samples,), self.scheduler.timesteps[i], device=device)
            model_output = self.model(latents, t_tensor / self.scheduler.num_train_timesteps)
            with torch.no_grad():
                pre_trained_model_output = pre_trained_model(latents, t_tensor / self.scheduler.num_train_timesteps)
            latents, log_prob, kl_div = ddim_step_KL(self.scheduler, model_output, pre_trained_model_output, t_tensor, latents, eta=self.config.eta)
            
            all_latents.append(latents)
            all_log_probs.append(log_prob)
            all_kl_divs.append(kl_div)

        return torch.stack(all_latents, dim=1), torch.stack(all_log_probs, dim=1), torch.stack(all_kl_divs, dim=1)

# %% [markdown]
# ### RL training

# %%
# Hyperparameters
config = SimpleNamespace(
    learning_rate=3e-5,
    eta=1.0,
    clip_range=1e-4,
    ppo_epochs=1,
    batch_size=256,
    max_grad_norm=1.,
    kl_weight=kl_weight
)

# Copy pre-trained weights to fine-tune model
rl_model = copy.deepcopy(pre_trained_model).to(device)

# Initialize DDPO for fine-tuning
ddpo = DDPO(rl_model, scheduler, config)

# Fine-tune with DDPO
rl_epochs = 1000
samples_per_epoch = 256
ddpo.fine_tune(compute_reward, rl_epochs, samples_per_epoch, device)
# Out:
# Epoch 1/1000, Mean Reward: -3.4020, Mean KL Div: 0.0000
# Epoch 2/1000, Mean Reward: -3.5390, Mean KL Div: 0.0002
# Epoch 3/1000, Mean Reward: -3.3187, Mean KL Div: 0.0007
# Epoch 4/1000, Mean Reward: -3.1049, Mean KL Div: 0.0023
# Epoch 5/1000, Mean Reward: -3.1554, Mean KL Div: 0.0021
# Epoch 6/1000, Mean Reward: -3.4468, Mean KL Div: 0.0039
# Epoch 7/1000, Mean Reward: -3.3977, Mean KL Div: 0.0034
# Epoch 8/1000, Mean Reward: -3.4005, Mean KL Div: 0.0053
# Epoch 9/1000, Mean Reward: -3.0587, Mean KL Div: 0.0071
# Epoch 10/1000, Mean Reward: -3.4378, Mean KL Div: 0.0054
# Epoch 11/1000, Mean Reward: -3.0057, Mean KL Div: 0.0053
# Epoch 12/1000, Mean Reward: -3.2415, Mean KL Div: 0.0081
# Epoch 13/1000, Mean Reward: -3.3040, Mean KL Div: 0.0087
# Epoch 14/1000, Mean Reward: -2.9983, Mean KL Div: 0.0099
# Epoch 15/1000, Mean Reward: -3.3289, Mean KL Div: 0.0068
# Epoch 16/1000, Mean Reward: -3.2363, Mean KL Div: 0.0071
# Epoch 17/1000, Mean Reward: -3.3267, Mean KL Div: 0.0060
# Epoch 18/1000, Mean Reward: -3.2331, Mean KL Div: 0.0051
# Epoch 19/1000, Mean Reward: -3.5357, Mean KL Div: 0.0073
# Epoch 20/1000, Mean Reward: -2.9403, Mean KL Div: 0.0058
# Epoch 21/1000, Mean Reward: -3.0655, Mean KL Div: 0.0102
# Epoch 22/1000, Mean Reward: -3.1533, Mean KL Div: 0.0106
# Epoch 23/1000, Mean Reward: -3.2011, Mean KL Div: 0.0073
# Epoch 24/1000, Mean Reward: -3.2225, Mean KL Div: 0.0091
# Epoch 25/1000, Mean Reward: -3.2144, Mean KL Div: 0.0086
# Epoch 26/1000, Mean Reward: -3.4624, Mean KL Div: 0.0087
# Epoch 27/1000, Mean Reward: -3.2012, Mean KL Div: 0.0108
# Epoch 28/1000, Mean Reward: -3.1695, Mean KL Div: 0.0106
# Epoch 29/1000, Mean Reward: -3.3865, Mean KL Div: 0.0128
# Epoch 30/1000, Mean Reward: -3.3124, Mean KL Div: 0.0118
# Epoch 31/1000, Mean Reward: -2.7843, Mean KL Div: 0.0138
# Epoch 32/1000, Mean Reward: -3.0369, Mean KL Div: 0.0163
# Epoch 33/1000, Mean Reward: -3.2326, Mean KL Div: 0.0179
# Epoch 34/1000, Mean Reward: -3.4053, Mean KL Div: 0.0194
# Epoch 35/1000, Mean Reward: -3.1140, Mean KL Div: 0.0197
# Epoch 36/1000, Mean Reward: -3.1172, Mean KL Div: 0.0149
# Epoch 37/1000, Mean Reward: -3.0685, Mean KL Div: 0.0161
# Epoch 38/1000, Mean Reward: -3.3589, Mean KL Div: 0.0199
# Epoch 39/1000, Mean Reward: -3.6070, Mean KL Div: 0.0186
# Epoch 40/1000, Mean Reward: -3.0881, Mean KL Div: 0.0183
# Epoch 41/1000, Mean Reward: -3.2060, Mean KL Div: 0.0165
# Epoch 42/1000, Mean Reward: -3.0698, Mean KL Div: 0.0173
# Epoch 43/1000, Mean Reward: -2.9375, Mean KL Div: 0.0138
# Epoch 44/1000, Mean Reward: -3.3574, Mean KL Div: 0.0147
# Epoch 45/1000, Mean Reward: -3.1780, Mean KL Div: 0.0156
# Epoch 46/1000, Mean Reward: -3.3148, Mean KL Div: 0.0152
# Epoch 47/1000, Mean Reward: -3.2406, Mean KL Div: 0.0178
# Epoch 48/1000, Mean Reward: -3.0018, Mean KL Div: 0.0167
# Epoch 49/1000, Mean Reward: -2.9869, Mean KL Div: 0.0181
# Epoch 50/1000, Mean Reward: -3.2740, Mean KL Div: 0.0180
# Epoch 51/1000, Mean Reward: -2.8654, Mean KL Div: 0.0190
# Epoch 52/1000, Mean Reward: -3.2117, Mean KL Div: 0.0201
# Epoch 53/1000, Mean Reward: -2.7880, Mean KL Div: 0.0215
# Epoch 54/1000, Mean Reward: -3.1060, Mean KL Div: 0.0254
# Epoch 55/1000, Mean Reward: -3.0966, Mean KL Div: 0.0277
# Epoch 56/1000, Mean Reward: -3.1611, Mean KL Div: 0.0268
# Epoch 57/1000, Mean Reward: -2.7762, Mean KL Div: 0.0287
# Epoch 58/1000, Mean Reward: -3.4448, Mean KL Div: 0.0360
# Epoch 59/1000, Mean Reward: -3.1731, Mean KL Div: 0.0323
# Epoch 60/1000, Mean Reward: -2.7916, Mean KL Div: 0.0421
# Epoch 61/1000, Mean Reward: -3.4514, Mean KL Div: 0.0474
# Epoch 62/1000, Mean Reward: -3.1500, Mean KL Div: 0.0496
# Epoch 63/1000, Mean Reward: -3.2861, Mean KL Div: 0.0492
# Epoch 64/1000, Mean Reward: -2.9767, Mean KL Div: 0.0460
# Epoch 65/1000, Mean Reward: -3.1112, Mean KL Div: 0.0485
# Epoch 66/1000, Mean Reward: -2.9188, Mean KL Div: 0.0519
# Epoch 67/1000, Mean Reward: -3.1077, Mean KL Div: 0.0508
# Epoch 68/1000, Mean Reward: -3.3532, Mean KL Div: 0.0555
# Epoch 69/1000, Mean Reward: -3.2562, Mean KL Div: 0.0565
# Epoch 70/1000, Mean Reward: -2.9614, Mean KL Div: 0.0614
# Epoch 71/1000, Mean Reward: -2.9085, Mean KL Div: 0.0635
# Epoch 72/1000, Mean Reward: -3.0088, Mean KL Div: 0.0587
# Epoch 73/1000, Mean Reward: -3.0620, Mean KL Div: 0.0662
# Epoch 74/1000, Mean Reward: -2.9355, Mean KL Div: 0.0705
# Epoch 75/1000, Mean Reward: -3.3209, Mean KL Div: 0.0740
# Epoch 76/1000, Mean Reward: -3.3157, Mean KL Div: 0.0798
# Epoch 77/1000, Mean Reward: -3.3544, Mean KL Div: 0.0824
# Epoch 78/1000, Mean Reward: -3.1755, Mean KL Div: 0.0816
# Epoch 79/1000, Mean Reward: -2.8215, Mean KL Div: 0.0812
# Epoch 80/1000, Mean Reward: -3.0506, Mean KL Div: 0.0832
# Epoch 81/1000, Mean Reward: -2.9888, Mean KL Div: 0.0854
# Epoch 82/1000, Mean Reward: -3.0969, Mean KL Div: 0.0850
# Epoch 83/1000, Mean Reward: -3.0032, Mean KL Div: 0.0793
# Epoch 84/1000, Mean Reward: -2.9218, Mean KL Div: 0.0898
# Epoch 85/1000, Mean Reward: -3.1031, Mean KL Div: 0.0852
# Epoch 86/1000, Mean Reward: -3.1688, Mean KL Div: 0.0752
# Epoch 87/1000, Mean Reward: -2.9519, Mean KL Div: 0.0848
# Epoch 88/1000, Mean Reward: -2.9288, Mean KL Div: 0.0761
# Epoch 89/1000, Mean Reward: -3.1092, Mean KL Div: 0.0855
# Epoch 90/1000, Mean Reward: -3.0868, Mean KL Div: 0.0965
# Epoch 91/1000, Mean Reward: -3.0828, Mean KL Div: 0.0930
# Epoch 92/1000, Mean Reward: -2.9799, Mean KL Div: 0.0920
# Epoch 93/1000, Mean Reward: -3.0595, Mean KL Div: 0.1012
# Epoch 94/1000, Mean Reward: -3.1141, Mean KL Div: 0.0907
# Epoch 95/1000, Mean Reward: -2.8148, Mean KL Div: 0.0814
# Epoch 96/1000, Mean Reward: -3.0952, Mean KL Div: 0.0896
# Epoch 97/1000, Mean Reward: -2.9385, Mean KL Div: 0.0876
# Epoch 98/1000, Mean Reward: -3.0408, Mean KL Div: 0.0859
# Epoch 99/1000, Mean Reward: -2.9632, Mean KL Div: 0.0897
# Epoch 100/1000, Mean Reward: -2.7242, Mean KL Div: 0.0949
# Epoch 101/1000, Mean Reward: -2.9491, Mean KL Div: 0.0919
# Epoch 102/1000, Mean Reward: -2.7087, Mean KL Div: 0.0882
# Epoch 103/1000, Mean Reward: -2.7935, Mean KL Div: 0.0921
# Epoch 104/1000, Mean Reward: -2.7635, Mean KL Div: 0.0923
# Epoch 105/1000, Mean Reward: -2.8189, Mean KL Div: 0.0871
# Epoch 106/1000, Mean Reward: -3.0342, Mean KL Div: 0.1011
# Epoch 107/1000, Mean Reward: -2.9836, Mean KL Div: 0.1037
# Epoch 108/1000, Mean Reward: -2.9928, Mean KL Div: 0.1117
# Epoch 109/1000, Mean Reward: -3.0074, Mean KL Div: 0.1137
# Epoch 110/1000, Mean Reward: -2.8831, Mean KL Div: 0.1155
# Epoch 111/1000, Mean Reward: -3.0118, Mean KL Div: 0.1170
# Epoch 112/1000, Mean Reward: -2.9082, Mean KL Div: 0.1328
# Epoch 113/1000, Mean Reward: -2.7210, Mean KL Div: 0.1275
# Epoch 114/1000, Mean Reward: -2.8405, Mean KL Div: 0.1241
# Epoch 115/1000, Mean Reward: -2.9126, Mean KL Div: 0.1447
# Epoch 116/1000, Mean Reward: -2.9367, Mean KL Div: 0.1319
# Epoch 117/1000, Mean Reward: -2.9389, Mean KL Div: 0.1403
# Epoch 118/1000, Mean Reward: -3.0190, Mean KL Div: 0.1378
# Epoch 119/1000, Mean Reward: -3.0612, Mean KL Div: 0.1342
# Epoch 120/1000, Mean Reward: -3.0229, Mean KL Div: 0.1289
# Epoch 121/1000, Mean Reward: -2.9090, Mean KL Div: 0.1168
# Epoch 122/1000, Mean Reward: -2.7005, Mean KL Div: 0.1087
# Epoch 123/1000, Mean Reward: -2.7450, Mean KL Div: 0.1015
# Epoch 124/1000, Mean Reward: -2.8430, Mean KL Div: 0.0969
# Epoch 125/1000, Mean Reward: -2.9794, Mean KL Div: 0.1100
# Epoch 126/1000, Mean Reward: -2.6708, Mean KL Div: 0.0985
# Epoch 127/1000, Mean Reward: -3.0026, Mean KL Div: 0.0990
# Epoch 128/1000, Mean Reward: -2.8873, Mean KL Div: 0.1066
# Epoch 129/1000, Mean Reward: -2.8551, Mean KL Div: 0.1034
# Epoch 130/1000, Mean Reward: -3.0472, Mean KL Div: 0.0982
# Epoch 131/1000, Mean Reward: -2.5401, Mean KL Div: 0.1128
# Epoch 132/1000, Mean Reward: -2.8400, Mean KL Div: 0.1059
# Epoch 133/1000, Mean Reward: -2.9041, Mean KL Div: 0.1200
# Epoch 134/1000, Mean Reward: -2.5705, Mean KL Div: 0.1144
# Epoch 135/1000, Mean Reward: -2.5785, Mean KL Div: 0.1271
# Epoch 136/1000, Mean Reward: -2.7235, Mean KL Div: 0.1291
# Epoch 137/1000, Mean Reward: -2.6600, Mean KL Div: 0.1240
# Epoch 138/1000, Mean Reward: -2.6815, Mean KL Div: 0.1244
# Epoch 139/1000, Mean Reward: -2.8692, Mean KL Div: 0.1372
# Epoch 140/1000, Mean Reward: -2.8740, Mean KL Div: 0.1282
# Epoch 141/1000, Mean Reward: -2.8190, Mean KL Div: 0.1348
# Epoch 142/1000, Mean Reward: -3.2559, Mean KL Div: 0.1223
# Epoch 143/1000, Mean Reward: -3.0823, Mean KL Div: 0.1259
# Epoch 144/1000, Mean Reward: -2.9406, Mean KL Div: 0.1237
# Epoch 145/1000, Mean Reward: -2.8426, Mean KL Div: 0.1386
# Epoch 146/1000, Mean Reward: -2.7927, Mean KL Div: 0.1272
# Epoch 147/1000, Mean Reward: -2.9438, Mean KL Div: 0.1442
# Epoch 148/1000, Mean Reward: -3.0174, Mean KL Div: 0.1507
# Epoch 149/1000, Mean Reward: -2.6358, Mean KL Div: 0.1501
# Epoch 150/1000, Mean Reward: -3.0142, Mean KL Div: 0.1543
# Epoch 151/1000, Mean Reward: -2.8547, Mean KL Div: 0.1551
# Epoch 152/1000, Mean Reward: -2.7897, Mean KL Div: 0.1592
# Epoch 153/1000, Mean Reward: -2.7218, Mean KL Div: 0.1590
# Epoch 154/1000, Mean Reward: -2.4969, Mean KL Div: 0.1572
# Epoch 155/1000, Mean Reward: -2.7441, Mean KL Div: 0.1614
# Epoch 156/1000, Mean Reward: -2.6616, Mean KL Div: 0.1799
# Epoch 157/1000, Mean Reward: -3.0218, Mean KL Div: 0.1894
# Epoch 158/1000, Mean Reward: -2.9523, Mean KL Div: 0.1797
# Epoch 159/1000, Mean Reward: -2.7204, Mean KL Div: 0.1787
# Epoch 160/1000, Mean Reward: -2.9074, Mean KL Div: 0.1636
# Epoch 161/1000, Mean Reward: -3.0431, Mean KL Div: 0.1734
# Epoch 162/1000, Mean Reward: -3.0568, Mean KL Div: 0.1812
# Epoch 163/1000, Mean Reward: -2.5266, Mean KL Div: 0.1748
# Epoch 164/1000, Mean Reward: -2.8468, Mean KL Div: 0.1807
# Epoch 165/1000, Mean Reward: -2.8315, Mean KL Div: 0.1662
# Epoch 166/1000, Mean Reward: -2.9453, Mean KL Div: 0.1682
# Epoch 167/1000, Mean Reward: -3.1439, Mean KL Div: 0.1750
# Epoch 168/1000, Mean Reward: -2.8123, Mean KL Div: 0.1706
# Epoch 169/1000, Mean Reward: -2.9053, Mean KL Div: 0.1791
# Epoch 170/1000, Mean Reward: -2.4491, Mean KL Div: 0.1765
# Epoch 171/1000, Mean Reward: -2.7448, Mean KL Div: 0.1782
# Epoch 172/1000, Mean Reward: -2.6833, Mean KL Div: 0.1883
# Epoch 173/1000, Mean Reward: -2.6085, Mean KL Div: 0.1842
# Epoch 174/1000, Mean Reward: -2.7664, Mean KL Div: 0.1910
# Epoch 175/1000, Mean Reward: -2.7576, Mean KL Div: 0.1980
# Epoch 176/1000, Mean Reward: -2.6827, Mean KL Div: 0.1880
# Epoch 177/1000, Mean Reward: -2.9407, Mean KL Div: 0.2055
# Epoch 178/1000, Mean Reward: -2.8354, Mean KL Div: 0.1923
# Epoch 179/1000, Mean Reward: -2.9454, Mean KL Div: 0.1931
# Epoch 180/1000, Mean Reward: -2.6848, Mean KL Div: 0.1995
# Epoch 181/1000, Mean Reward: -2.9010, Mean KL Div: 0.2022
# Epoch 182/1000, Mean Reward: -2.9964, Mean KL Div: 0.2042
# Epoch 183/1000, Mean Reward: -2.5999, Mean KL Div: 0.1926
# Epoch 184/1000, Mean Reward: -2.8438, Mean KL Div: 0.2137
# Epoch 185/1000, Mean Reward: -2.6811, Mean KL Div: 0.2375
# Epoch 186/1000, Mean Reward: -2.7401, Mean KL Div: 0.2313
# Epoch 187/1000, Mean Reward: -2.5799, Mean KL Div: 0.2261
# Epoch 188/1000, Mean Reward: -2.8278, Mean KL Div: 0.2340
# Epoch 189/1000, Mean Reward: -2.7592, Mean KL Div: 0.2331
# Epoch 190/1000, Mean Reward: -2.8607, Mean KL Div: 0.2274
# Epoch 191/1000, Mean Reward: -2.4662, Mean KL Div: 0.2127
# Epoch 192/1000, Mean Reward: -2.9644, Mean KL Div: 0.2094
# Epoch 193/1000, Mean Reward: -2.8768, Mean KL Div: 0.2005
# Epoch 194/1000, Mean Reward: -2.6290, Mean KL Div: 0.1863
# Epoch 195/1000, Mean Reward: -2.8277, Mean KL Div: 0.2023
# Epoch 196/1000, Mean Reward: -2.7600, Mean KL Div: 0.2005
# Epoch 197/1000, Mean Reward: -2.7431, Mean KL Div: 0.1929
# Epoch 198/1000, Mean Reward: -2.7846, Mean KL Div: 0.1962
# Epoch 199/1000, Mean Reward: -2.5530, Mean KL Div: 0.1858
# Epoch 200/1000, Mean Reward: -2.8469, Mean KL Div: 0.2219
# Epoch 201/1000, Mean Reward: -2.7568, Mean KL Div: 0.2046
# Epoch 202/1000, Mean Reward: -2.9899, Mean KL Div: 0.1953
# Epoch 203/1000, Mean Reward: -2.9166, Mean KL Div: 0.2168
# Epoch 204/1000, Mean Reward: -2.4192, Mean KL Div: 0.1971
# Epoch 205/1000, Mean Reward: -2.8811, Mean KL Div: 0.2071
# Epoch 206/1000, Mean Reward: -2.5509, Mean KL Div: 0.2014
# Epoch 207/1000, Mean Reward: -2.9543, Mean KL Div: 0.2406
# Epoch 208/1000, Mean Reward: -2.7840, Mean KL Div: 0.2053
# Epoch 209/1000, Mean Reward: -2.8055, Mean KL Div: 0.2011
# Epoch 210/1000, Mean Reward: -2.6538, Mean KL Div: 0.1889
# Epoch 211/1000, Mean Reward: -2.5061, Mean KL Div: 0.2071
# Epoch 212/1000, Mean Reward: -2.6399, Mean KL Div: 0.1952
# Epoch 213/1000, Mean Reward: -2.6889, Mean KL Div: 0.1871
# Epoch 214/1000, Mean Reward: -2.6400, Mean KL Div: 0.1884
# Epoch 215/1000, Mean Reward: -2.4026, Mean KL Div: 0.1905
# Epoch 216/1000, Mean Reward: -2.8155, Mean KL Div: 0.1865
# Epoch 217/1000, Mean Reward: -3.0509, Mean KL Div: 0.2005
# Epoch 218/1000, Mean Reward: -2.5942, Mean KL Div: 0.2082
# Epoch 219/1000, Mean Reward: -2.8233, Mean KL Div: 0.1920
# Epoch 220/1000, Mean Reward: -2.7901, Mean KL Div: 0.2161
# Epoch 221/1000, Mean Reward: -2.8225, Mean KL Div: 0.2318
# Epoch 222/1000, Mean Reward: -2.7427, Mean KL Div: 0.2141
# Epoch 223/1000, Mean Reward: -2.7158, Mean KL Div: 0.2270
# Epoch 224/1000, Mean Reward: -2.8626, Mean KL Div: 0.2138
# Epoch 225/1000, Mean Reward: -2.3810, Mean KL Div: 0.2239
# Epoch 226/1000, Mean Reward: -2.8139, Mean KL Div: 0.2288
# Epoch 227/1000, Mean Reward: -3.0400, Mean KL Div: 0.2161
# Epoch 228/1000, Mean Reward: -2.6826, Mean KL Div: 0.2265
# Epoch 229/1000, Mean Reward: -2.6808, Mean KL Div: 0.2198
# Epoch 230/1000, Mean Reward: -2.5397, Mean KL Div: 0.2113
# Epoch 231/1000, Mean Reward: -2.7527, Mean KL Div: 0.2141
# Epoch 232/1000, Mean Reward: -2.6453, Mean KL Div: 0.2267
# Epoch 233/1000, Mean Reward: -2.2234, Mean KL Div: 0.2180
# Epoch 234/1000, Mean Reward: -2.5540, Mean KL Div: 0.2186
# Epoch 235/1000, Mean Reward: -2.5139, Mean KL Div: 0.2371
# Epoch 236/1000, Mean Reward: -2.7182, Mean KL Div: 0.2358
# Epoch 237/1000, Mean Reward: -2.7981, Mean KL Div: 0.2509
# Epoch 238/1000, Mean Reward: -2.7467, Mean KL Div: 0.2460
# Epoch 239/1000, Mean Reward: -2.5752, Mean KL Div: 0.2531
# Epoch 240/1000, Mean Reward: -2.6079, Mean KL Div: 0.2538
# Epoch 241/1000, Mean Reward: -2.7438, Mean KL Div: 0.2641
# Epoch 242/1000, Mean Reward: -2.7982, Mean KL Div: 0.2872
# Epoch 243/1000, Mean Reward: -2.7413, Mean KL Div: 0.2723
# Epoch 244/1000, Mean Reward: -2.3675, Mean KL Div: 0.2671
# Epoch 245/1000, Mean Reward: -2.7038, Mean KL Div: 0.2745
# Epoch 246/1000, Mean Reward: -2.6275, Mean KL Div: 0.2922
# Epoch 247/1000, Mean Reward: -3.0083, Mean KL Div: 0.2831
# Epoch 248/1000, Mean Reward: -2.7897, Mean KL Div: 0.2964
# Epoch 249/1000, Mean Reward: -2.7411, Mean KL Div: 0.2962
# Epoch 250/1000, Mean Reward: -2.6863, Mean KL Div: 0.2872
# Epoch 251/1000, Mean Reward: -2.9465, Mean KL Div: 0.3306
# Epoch 252/1000, Mean Reward: -2.7499, Mean KL Div: 0.3033
# Epoch 253/1000, Mean Reward: -2.6444, Mean KL Div: 0.3171
# Epoch 254/1000, Mean Reward: -2.9657, Mean KL Div: 0.3163
# Epoch 255/1000, Mean Reward: -2.5771, Mean KL Div: 0.3079
# Epoch 256/1000, Mean Reward: -2.7324, Mean KL Div: 0.3022
# Epoch 257/1000, Mean Reward: -2.4930, Mean KL Div: 0.3145
# Epoch 258/1000, Mean Reward: -2.7713, Mean KL Div: 0.3342
# Epoch 259/1000, Mean Reward: -2.5035, Mean KL Div: 0.3142
# Epoch 260/1000, Mean Reward: -2.6401, Mean KL Div: 0.3117
# Epoch 261/1000, Mean Reward: -2.8082, Mean KL Div: 0.3101
# Epoch 262/1000, Mean Reward: -2.7282, Mean KL Div: 0.3044
# Epoch 263/1000, Mean Reward: -2.9178, Mean KL Div: 0.3453
# Epoch 264/1000, Mean Reward: -2.4904, Mean KL Div: 0.3366
# Epoch 265/1000, Mean Reward: -2.9071, Mean KL Div: 0.3536
# Epoch 266/1000, Mean Reward: -2.3627, Mean KL Div: 0.3261
# Epoch 267/1000, Mean Reward: -2.3439, Mean KL Div: 0.3612
# Epoch 268/1000, Mean Reward: -2.4590, Mean KL Div: 0.3557
# Epoch 269/1000, Mean Reward: -2.6319, Mean KL Div: 0.3758
# Epoch 270/1000, Mean Reward: -2.6951, Mean KL Div: 0.3661
# Epoch 271/1000, Mean Reward: -2.6085, Mean KL Div: 0.3638
# Epoch 272/1000, Mean Reward: -2.7950, Mean KL Div: 0.3321
# Epoch 273/1000, Mean Reward: -2.8215, Mean KL Div: 0.3316
# Epoch 274/1000, Mean Reward: -2.6019, Mean KL Div: 0.2971
# Epoch 275/1000, Mean Reward: -2.6688, Mean KL Div: 0.3243
# Epoch 276/1000, Mean Reward: -2.4207, Mean KL Div: 0.3073
# Epoch 277/1000, Mean Reward: -2.5607, Mean KL Div: 0.3088
# Epoch 278/1000, Mean Reward: -2.5202, Mean KL Div: 0.3231
# Epoch 279/1000, Mean Reward: -2.3433, Mean KL Div: 0.3141
# Epoch 280/1000, Mean Reward: -2.5489, Mean KL Div: 0.3112
# Epoch 281/1000, Mean Reward: -2.5103, Mean KL Div: 0.3032
# Epoch 282/1000, Mean Reward: -2.9029, Mean KL Div: 0.3173
# Epoch 283/1000, Mean Reward: -2.6146, Mean KL Div: 0.3315
# Epoch 284/1000, Mean Reward: -2.4976, Mean KL Div: 0.3266
# Epoch 285/1000, Mean Reward: -2.5598, Mean KL Div: 0.3256
# Epoch 286/1000, Mean Reward: -2.4373, Mean KL Div: 0.3502
# Epoch 287/1000, Mean Reward: -2.7304, Mean KL Div: 0.3825
# Epoch 288/1000, Mean Reward: -2.7739, Mean KL Div: 0.3496
# Epoch 289/1000, Mean Reward: -2.5980, Mean KL Div: 0.3702
# Epoch 290/1000, Mean Reward: -2.6425, Mean KL Div: 0.3834
# Epoch 291/1000, Mean Reward: -2.9722, Mean KL Div: 0.3979
# Epoch 292/1000, Mean Reward: -2.6164, Mean KL Div: 0.3380
# Epoch 293/1000, Mean Reward: -2.6195, Mean KL Div: 0.3820
# Epoch 294/1000, Mean Reward: -2.4225, Mean KL Div: 0.3494
# Epoch 295/1000, Mean Reward: -2.4711, Mean KL Div: 0.3563
# Epoch 296/1000, Mean Reward: -2.6461, Mean KL Div: 0.3727
# Epoch 297/1000, Mean Reward: -2.8328, Mean KL Div: 0.3750
# Epoch 298/1000, Mean Reward: -2.5233, Mean KL Div: 0.3780
# Epoch 299/1000, Mean Reward: -2.4819, Mean KL Div: 0.3630
# Epoch 300/1000, Mean Reward: -2.8099, Mean KL Div: 0.3831
# Epoch 301/1000, Mean Reward: -2.5862, Mean KL Div: 0.4029
# Epoch 302/1000, Mean Reward: -2.5629, Mean KL Div: 0.3854
# Epoch 303/1000, Mean Reward: -2.3872, Mean KL Div: 0.3710
# Epoch 304/1000, Mean Reward: -2.4805, Mean KL Div: 0.3768
# Epoch 305/1000, Mean Reward: -2.5978, Mean KL Div: 0.4042
# Epoch 306/1000, Mean Reward: -2.3666, Mean KL Div: 0.3887
# Epoch 307/1000, Mean Reward: -2.7451, Mean KL Div: 0.4206
# Epoch 308/1000, Mean Reward: -2.4741, Mean KL Div: 0.4088
# Epoch 309/1000, Mean Reward: -2.6662, Mean KL Div: 0.4189
# Epoch 310/1000, Mean Reward: -2.5882, Mean KL Div: 0.3968
# Epoch 311/1000, Mean Reward: -2.2848, Mean KL Div: 0.3917
# Epoch 312/1000, Mean Reward: -2.4120, Mean KL Div: 0.4154
# Epoch 313/1000, Mean Reward: -2.6241, Mean KL Div: 0.4144
# Epoch 314/1000, Mean Reward: -2.5305, Mean KL Div: 0.4223
# Epoch 315/1000, Mean Reward: -3.0864, Mean KL Div: 0.4699
# Epoch 316/1000, Mean Reward: -2.3896, Mean KL Div: 0.4101
# Epoch 317/1000, Mean Reward: -2.5031, Mean KL Div: 0.4415
# Epoch 318/1000, Mean Reward: -2.5771, Mean KL Div: 0.4344
# Epoch 319/1000, Mean Reward: -2.6276, Mean KL Div: 0.4465
# Epoch 320/1000, Mean Reward: -2.2590, Mean KL Div: 0.4197
# Epoch 321/1000, Mean Reward: -2.9003, Mean KL Div: 0.4886
# Epoch 322/1000, Mean Reward: -2.7455, Mean KL Div: 0.4575
# Epoch 323/1000, Mean Reward: -2.5903, Mean KL Div: 0.4737
# Epoch 324/1000, Mean Reward: -2.6080, Mean KL Div: 0.4625
# Epoch 325/1000, Mean Reward: -2.5173, Mean KL Div: 0.4480
# Epoch 326/1000, Mean Reward: -2.8071, Mean KL Div: 0.5075
# Epoch 327/1000, Mean Reward: -2.5775, Mean KL Div: 0.4688
# Epoch 328/1000, Mean Reward: -2.4575, Mean KL Div: 0.4648
# Epoch 329/1000, Mean Reward: -2.7537, Mean KL Div: 0.4615
# Epoch 330/1000, Mean Reward: -2.3884, Mean KL Div: 0.4675
# Epoch 331/1000, Mean Reward: -2.2814, Mean KL Div: 0.4813
# Epoch 332/1000, Mean Reward: -2.4823, Mean KL Div: 0.4986
# Epoch 333/1000, Mean Reward: -2.7490, Mean KL Div: 0.4886
# Epoch 334/1000, Mean Reward: -2.4215, Mean KL Div: 0.4698
# Epoch 335/1000, Mean Reward: -2.5044, Mean KL Div: 0.4898
# Epoch 336/1000, Mean Reward: -2.4720, Mean KL Div: 0.4863
# Epoch 337/1000, Mean Reward: -2.5194, Mean KL Div: 0.4794
# Epoch 338/1000, Mean Reward: -2.6918, Mean KL Div: 0.4682
# Epoch 339/1000, Mean Reward: -2.2987, Mean KL Div: 0.4939
# Epoch 340/1000, Mean Reward: -2.4649, Mean KL Div: 0.5032
# Epoch 341/1000, Mean Reward: -2.6338, Mean KL Div: 0.5015
# Epoch 342/1000, Mean Reward: -2.1775, Mean KL Div: 0.4661
# Epoch 343/1000, Mean Reward: -2.4781, Mean KL Div: 0.4857
# Epoch 344/1000, Mean Reward: -2.6760, Mean KL Div: 0.4504
# Epoch 345/1000, Mean Reward: -2.5324, Mean KL Div: 0.4802
# Epoch 346/1000, Mean Reward: -2.6864, Mean KL Div: 0.4680
# Epoch 347/1000, Mean Reward: -2.5959, Mean KL Div: 0.4879
# Epoch 348/1000, Mean Reward: -2.3694, Mean KL Div: 0.4474
# Epoch 349/1000, Mean Reward: -2.6111, Mean KL Div: 0.4518
# Epoch 350/1000, Mean Reward: -2.5354, Mean KL Div: 0.4745
# Epoch 351/1000, Mean Reward: -2.3965, Mean KL Div: 0.4530
# Epoch 352/1000, Mean Reward: -2.6829, Mean KL Div: 0.4709
# Epoch 353/1000, Mean Reward: -2.8619, Mean KL Div: 0.5002
# Epoch 354/1000, Mean Reward: -2.5269, Mean KL Div: 0.4993
# Epoch 355/1000, Mean Reward: -2.5535, Mean KL Div: 0.4907
# Epoch 356/1000, Mean Reward: -2.3274, Mean KL Div: 0.4494
# Epoch 357/1000, Mean Reward: -2.6552, Mean KL Div: 0.5045
# Epoch 358/1000, Mean Reward: -2.6365, Mean KL Div: 0.4940
# Epoch 359/1000, Mean Reward: -2.4763, Mean KL Div: 0.4952
# Epoch 360/1000, Mean Reward: -2.5585, Mean KL Div: 0.4926
# Epoch 361/1000, Mean Reward: -2.6281, Mean KL Div: 0.5154
# Epoch 362/1000, Mean Reward: -2.7929, Mean KL Div: 0.5126
# Epoch 363/1000, Mean Reward: -2.7637, Mean KL Div: 0.5139
# Epoch 364/1000, Mean Reward: -2.7477, Mean KL Div: 0.5250
# Epoch 365/1000, Mean Reward: -2.4813, Mean KL Div: 0.5341
# Epoch 366/1000, Mean Reward: -2.7932, Mean KL Div: 0.5877
# Epoch 367/1000, Mean Reward: -2.4580, Mean KL Div: 0.5280
# Epoch 368/1000, Mean Reward: -2.3486, Mean KL Div: 0.5611
# Epoch 369/1000, Mean Reward: -2.5615, Mean KL Div: 0.5609
# Epoch 370/1000, Mean Reward: -2.6675, Mean KL Div: 0.4986
# Epoch 371/1000, Mean Reward: -2.6568, Mean KL Div: 0.5116
# Epoch 372/1000, Mean Reward: -2.4470, Mean KL Div: 0.4642
# Epoch 373/1000, Mean Reward: -2.5606, Mean KL Div: 0.5032
# Epoch 374/1000, Mean Reward: -2.7187, Mean KL Div: 0.4654
# Epoch 375/1000, Mean Reward: -2.7311, Mean KL Div: 0.4925
# Epoch 376/1000, Mean Reward: -2.5998, Mean KL Div: 0.4922
# Epoch 377/1000, Mean Reward: -2.6906, Mean KL Div: 0.5076
# Epoch 378/1000, Mean Reward: -2.5466, Mean KL Div: 0.5181
# Epoch 379/1000, Mean Reward: -2.6248, Mean KL Div: 0.4999
# Epoch 380/1000, Mean Reward: -2.7770, Mean KL Div: 0.5013
# Epoch 381/1000, Mean Reward: -2.8060, Mean KL Div: 0.5407
# Epoch 382/1000, Mean Reward: -2.6239, Mean KL Div: 0.4976
# Epoch 383/1000, Mean Reward: -2.5442, Mean KL Div: 0.4891
# Epoch 384/1000, Mean Reward: -2.7639, Mean KL Div: 0.4870
# Epoch 385/1000, Mean Reward: -2.6908, Mean KL Div: 0.5266
# Epoch 386/1000, Mean Reward: -2.8691, Mean KL Div: 0.5034
# Epoch 387/1000, Mean Reward: -2.7028, Mean KL Div: 0.5295
# Epoch 388/1000, Mean Reward: -2.4855, Mean KL Div: 0.4700
# Epoch 389/1000, Mean Reward: -2.1434, Mean KL Div: 0.4664
# Epoch 390/1000, Mean Reward: -2.5803, Mean KL Div: 0.4775
# Epoch 391/1000, Mean Reward: -2.4398, Mean KL Div: 0.5073
# Epoch 392/1000, Mean Reward: -2.4369, Mean KL Div: 0.4711
# Epoch 393/1000, Mean Reward: -2.7007, Mean KL Div: 0.5145
# Epoch 394/1000, Mean Reward: -2.4316, Mean KL Div: 0.5055
# Epoch 395/1000, Mean Reward: -2.7456, Mean KL Div: 0.5519
# Epoch 396/1000, Mean Reward: -2.5966, Mean KL Div: 0.5450
# Epoch 397/1000, Mean Reward: -2.6142, Mean KL Div: 0.5758
# Epoch 398/1000, Mean Reward: -2.2817, Mean KL Div: 0.4819
# Epoch 399/1000, Mean Reward: -2.5462, Mean KL Div: 0.5276
# Epoch 400/1000, Mean Reward: -2.5229, Mean KL Div: 0.5327
# Epoch 401/1000, Mean Reward: -2.6446, Mean KL Div: 0.5389
# Epoch 402/1000, Mean Reward: -2.2603, Mean KL Div: 0.5261
# Epoch 403/1000, Mean Reward: -2.9829, Mean KL Div: 0.5999
# Epoch 404/1000, Mean Reward: -2.9837, Mean KL Div: 0.5870
# Epoch 405/1000, Mean Reward: -2.5384, Mean KL Div: 0.5435
# Epoch 406/1000, Mean Reward: -2.4353, Mean KL Div: 0.5592
# Epoch 407/1000, Mean Reward: -2.8273, Mean KL Div: 0.5624
# Epoch 408/1000, Mean Reward: -2.4594, Mean KL Div: 0.5501
# Epoch 409/1000, Mean Reward: -2.4170, Mean KL Div: 0.5669
# Epoch 410/1000, Mean Reward: -2.4215, Mean KL Div: 0.5407
# Epoch 411/1000, Mean Reward: -2.7655, Mean KL Div: 0.5892
# Epoch 412/1000, Mean Reward: -2.4264, Mean KL Div: 0.5460
# Epoch 413/1000, Mean Reward: -2.7363, Mean KL Div: 0.5717
# Epoch 414/1000, Mean Reward: -2.7130, Mean KL Div: 0.5696
# Epoch 415/1000, Mean Reward: -2.4134, Mean KL Div: 0.5108
# Epoch 416/1000, Mean Reward: -2.5078, Mean KL Div: 0.5641
# Epoch 417/1000, Mean Reward: -2.4858, Mean KL Div: 0.5726
# Epoch 418/1000, Mean Reward: -2.6214, Mean KL Div: 0.5562
# Epoch 419/1000, Mean Reward: -2.4009, Mean KL Div: 0.5630
# Epoch 420/1000, Mean Reward: -2.5095, Mean KL Div: 0.6007
# Epoch 421/1000, Mean Reward: -2.4686, Mean KL Div: 0.6199
# Epoch 422/1000, Mean Reward: -2.5577, Mean KL Div: 0.6251
# Epoch 423/1000, Mean Reward: -2.4490, Mean KL Div: 0.6363
# Epoch 424/1000, Mean Reward: -2.9047, Mean KL Div: 0.5961
# Epoch 425/1000, Mean Reward: -2.0268, Mean KL Div: 0.5571
# Epoch 426/1000, Mean Reward: -2.3924, Mean KL Div: 0.6130
# Epoch 427/1000, Mean Reward: -2.4083, Mean KL Div: 0.6030
# Epoch 428/1000, Mean Reward: -2.6151, Mean KL Div: 0.6186
# Epoch 429/1000, Mean Reward: -2.6715, Mean KL Div: 0.6226
# Epoch 430/1000, Mean Reward: -2.3629, Mean KL Div: 0.6176
# Epoch 431/1000, Mean Reward: -2.7003, Mean KL Div: 0.6476
# Epoch 432/1000, Mean Reward: -2.6490, Mean KL Div: 0.6245
# Epoch 433/1000, Mean Reward: -2.2325, Mean KL Div: 0.6164
# Epoch 434/1000, Mean Reward: -2.2652, Mean KL Div: 0.5766
# Epoch 435/1000, Mean Reward: -2.5067, Mean KL Div: 0.5895
# Epoch 436/1000, Mean Reward: -2.2132, Mean KL Div: 0.5986
# Epoch 437/1000, Mean Reward: -2.1033, Mean KL Div: 0.5999
# Epoch 438/1000, Mean Reward: -2.3803, Mean KL Div: 0.5843
# Epoch 439/1000, Mean Reward: -2.6053, Mean KL Div: 0.6113
# Epoch 440/1000, Mean Reward: -2.2153, Mean KL Div: 0.6051
# Epoch 441/1000, Mean Reward: -2.6481, Mean KL Div: 0.6402
# Epoch 442/1000, Mean Reward: -2.4601, Mean KL Div: 0.6201
# Epoch 443/1000, Mean Reward: -2.3846, Mean KL Div: 0.6311
# Epoch 444/1000, Mean Reward: -2.6200, Mean KL Div: 0.6775
# Epoch 445/1000, Mean Reward: -2.4765, Mean KL Div: 0.5934
# Epoch 446/1000, Mean Reward: -2.7174, Mean KL Div: 0.6587
# Epoch 447/1000, Mean Reward: -2.2838, Mean KL Div: 0.6057
# Epoch 448/1000, Mean Reward: -2.3888, Mean KL Div: 0.6350
# Epoch 449/1000, Mean Reward: -2.2067, Mean KL Div: 0.6034
# Epoch 450/1000, Mean Reward: -2.4285, Mean KL Div: 0.6135
# Epoch 451/1000, Mean Reward: -2.3898, Mean KL Div: 0.5943
# Epoch 452/1000, Mean Reward: -2.4353, Mean KL Div: 0.6973
# Epoch 453/1000, Mean Reward: -2.4109, Mean KL Div: 0.6757
# Epoch 454/1000, Mean Reward: -2.4744, Mean KL Div: 0.6432
# Epoch 455/1000, Mean Reward: -2.2149, Mean KL Div: 0.6699
# Epoch 456/1000, Mean Reward: -2.6488, Mean KL Div: 0.6201
# Epoch 457/1000, Mean Reward: -2.4084, Mean KL Div: 0.6142
# Epoch 458/1000, Mean Reward: -2.4391, Mean KL Div: 0.6550
# Epoch 459/1000, Mean Reward: -2.4579, Mean KL Div: 0.6753
# Epoch 460/1000, Mean Reward: -2.4142, Mean KL Div: 0.6446
# Epoch 461/1000, Mean Reward: -2.4578, Mean KL Div: 0.6515
# Epoch 462/1000, Mean Reward: -2.1080, Mean KL Div: 0.6520
# Epoch 463/1000, Mean Reward: -2.3166, Mean KL Div: 0.6447
# Epoch 464/1000, Mean Reward: -2.3606, Mean KL Div: 0.6464
# Epoch 465/1000, Mean Reward: -1.9875, Mean KL Div: 0.6219
# Epoch 466/1000, Mean Reward: -2.0870, Mean KL Div: 0.6545
# Epoch 467/1000, Mean Reward: -2.1996, Mean KL Div: 0.6271
# Epoch 468/1000, Mean Reward: -2.6357, Mean KL Div: 0.6749
# Epoch 469/1000, Mean Reward: -2.4137, Mean KL Div: 0.7396
# Epoch 470/1000, Mean Reward: -2.5992, Mean KL Div: 0.6702
# Epoch 471/1000, Mean Reward: -2.5251, Mean KL Div: 0.7308
# Epoch 472/1000, Mean Reward: -2.3429, Mean KL Div: 0.6966
# Epoch 473/1000, Mean Reward: -2.3430, Mean KL Div: 0.6787
# Epoch 474/1000, Mean Reward: -2.7409, Mean KL Div: 0.7599
# Epoch 475/1000, Mean Reward: -2.5142, Mean KL Div: 0.7137
# Epoch 476/1000, Mean Reward: -2.6513, Mean KL Div: 0.7168
# Epoch 477/1000, Mean Reward: -2.6994, Mean KL Div: 0.7399
# Epoch 478/1000, Mean Reward: -2.5244, Mean KL Div: 0.7349
# Epoch 479/1000, Mean Reward: -2.4444, Mean KL Div: 0.7436
# Epoch 480/1000, Mean Reward: -2.5847, Mean KL Div: 0.7802
# Epoch 481/1000, Mean Reward: -2.5926, Mean KL Div: 0.7541
# Epoch 482/1000, Mean Reward: -2.7680, Mean KL Div: 0.8289
# Epoch 483/1000, Mean Reward: -2.4165, Mean KL Div: 0.7324
# Epoch 484/1000, Mean Reward: -2.4090, Mean KL Div: 0.7549
# Epoch 485/1000, Mean Reward: -2.4023, Mean KL Div: 0.7187
# Epoch 486/1000, Mean Reward: -2.4092, Mean KL Div: 0.7524
# Epoch 487/1000, Mean Reward: -2.5540, Mean KL Div: 0.7617
# Epoch 488/1000, Mean Reward: -2.7454, Mean KL Div: 0.8854
# Epoch 489/1000, Mean Reward: -2.5292, Mean KL Div: 0.7609
# Epoch 490/1000, Mean Reward: -2.4780, Mean KL Div: 0.8010
# Epoch 491/1000, Mean Reward: -2.4605, Mean KL Div: 0.7649
# Epoch 492/1000, Mean Reward: -2.6805, Mean KL Div: 0.7297
# Epoch 493/1000, Mean Reward: -2.7607, Mean KL Div: 0.7538
# Epoch 494/1000, Mean Reward: -2.3785, Mean KL Div: 0.6866
# Epoch 495/1000, Mean Reward: -2.8842, Mean KL Div: 0.8737
# Epoch 496/1000, Mean Reward: -2.3688, Mean KL Div: 0.8149
# Epoch 497/1000, Mean Reward: -2.6518, Mean KL Div: 0.8320
# Epoch 498/1000, Mean Reward: -2.3117, Mean KL Div: 0.7324
# Epoch 499/1000, Mean Reward: -2.6117, Mean KL Div: 0.7782
# Epoch 500/1000, Mean Reward: -2.6153, Mean KL Div: 0.7622
# Epoch 501/1000, Mean Reward: -2.5353, Mean KL Div: 0.7487
# Epoch 502/1000, Mean Reward: -2.4111, Mean KL Div: 0.7706
# Epoch 503/1000, Mean Reward: -2.5506, Mean KL Div: 0.7934
# Epoch 504/1000, Mean Reward: -2.2777, Mean KL Div: 0.7609
# Epoch 505/1000, Mean Reward: -2.5618, Mean KL Div: 0.7701
# Epoch 506/1000, Mean Reward: -2.7554, Mean KL Div: 0.8400
# Epoch 507/1000, Mean Reward: -2.3477, Mean KL Div: 0.7933
# Epoch 508/1000, Mean Reward: -2.7646, Mean KL Div: 0.7965
# Epoch 509/1000, Mean Reward: -2.3558, Mean KL Div: 0.7853
# Epoch 510/1000, Mean Reward: -2.3876, Mean KL Div: 0.8583
# Epoch 511/1000, Mean Reward: -2.4178, Mean KL Div: 0.8282
# Epoch 512/1000, Mean Reward: -2.5184, Mean KL Div: 0.7415
# Epoch 513/1000, Mean Reward: -2.4717, Mean KL Div: 0.8279
# Epoch 514/1000, Mean Reward: -2.3548, Mean KL Div: 0.7684
# Epoch 515/1000, Mean Reward: -2.6190, Mean KL Div: 0.8157
# Epoch 516/1000, Mean Reward: -2.1557, Mean KL Div: 0.8024
# Epoch 517/1000, Mean Reward: -2.6830, Mean KL Div: 0.8235
# Epoch 518/1000, Mean Reward: -2.3508, Mean KL Div: 0.8689
# Epoch 519/1000, Mean Reward: -2.4959, Mean KL Div: 0.8144
# Epoch 520/1000, Mean Reward: -2.3474, Mean KL Div: 0.8516
# Epoch 521/1000, Mean Reward: -2.1752, Mean KL Div: 0.8488
# Epoch 522/1000, Mean Reward: -2.4775, Mean KL Div: 0.9388
# Epoch 523/1000, Mean Reward: -2.5671, Mean KL Div: 0.8426
# Epoch 524/1000, Mean Reward: -2.4615, Mean KL Div: 0.8564
# Epoch 525/1000, Mean Reward: -2.3821, Mean KL Div: 0.8471
# Epoch 526/1000, Mean Reward: -2.3754, Mean KL Div: 0.7335
# Epoch 527/1000, Mean Reward: -2.4734, Mean KL Div: 0.9050
# Epoch 528/1000, Mean Reward: -2.7124, Mean KL Div: 0.9278
# Epoch 529/1000, Mean Reward: -2.2336, Mean KL Div: 0.8715
# Epoch 530/1000, Mean Reward: -2.2619, Mean KL Div: 0.8774
# Epoch 531/1000, Mean Reward: -2.2921, Mean KL Div: 0.9488
# Epoch 532/1000, Mean Reward: -2.3912, Mean KL Div: 0.8649
# Epoch 533/1000, Mean Reward: -2.1853, Mean KL Div: 0.8514
# Epoch 534/1000, Mean Reward: -2.2558, Mean KL Div: 0.8965
# Epoch 535/1000, Mean Reward: -2.7796, Mean KL Div: 0.9525
# Epoch 536/1000, Mean Reward: -2.4711, Mean KL Div: 0.8835
# Epoch 537/1000, Mean Reward: -2.2756, Mean KL Div: 0.9169
# Epoch 538/1000, Mean Reward: -2.2262, Mean KL Div: 0.9575
# Epoch 539/1000, Mean Reward: -2.4256, Mean KL Div: 0.9225
# Epoch 540/1000, Mean Reward: -2.3042, Mean KL Div: 0.8971
# Epoch 541/1000, Mean Reward: -2.2117, Mean KL Div: 0.8937
# Epoch 542/1000, Mean Reward: -2.4036, Mean KL Div: 0.9534
# Epoch 543/1000, Mean Reward: -2.3634, Mean KL Div: 0.8864
# Epoch 544/1000, Mean Reward: -2.4842, Mean KL Div: 0.9374
# Epoch 545/1000, Mean Reward: -2.5903, Mean KL Div: 0.9274
# Epoch 546/1000, Mean Reward: -2.4087, Mean KL Div: 0.9501
# Epoch 547/1000, Mean Reward: -2.1623, Mean KL Div: 0.9211
# Epoch 548/1000, Mean Reward: -2.3454, Mean KL Div: 0.9506
# Epoch 549/1000, Mean Reward: -2.3237, Mean KL Div: 0.9116
# Epoch 550/1000, Mean Reward: -2.1952, Mean KL Div: 0.9117
# Epoch 551/1000, Mean Reward: -2.4918, Mean KL Div: 0.9491
# Epoch 552/1000, Mean Reward: -2.4137, Mean KL Div: 0.9768
# Epoch 553/1000, Mean Reward: -2.6026, Mean KL Div: 0.9443
# Epoch 554/1000, Mean Reward: -2.3001, Mean KL Div: 1.0087
# Epoch 555/1000, Mean Reward: -2.1334, Mean KL Div: 0.9162
# Epoch 556/1000, Mean Reward: -2.3572, Mean KL Div: 0.9956
# Epoch 557/1000, Mean Reward: -2.3870, Mean KL Div: 0.9616
# Epoch 558/1000, Mean Reward: -2.2682, Mean KL Div: 0.9847
# Epoch 559/1000, Mean Reward: -2.2084, Mean KL Div: 1.0527
# Epoch 560/1000, Mean Reward: -2.1767, Mean KL Div: 0.9904
# Epoch 561/1000, Mean Reward: -2.4031, Mean KL Div: 0.9926
# Epoch 562/1000, Mean Reward: -2.0625, Mean KL Div: 0.9883
# Epoch 563/1000, Mean Reward: -2.4096, Mean KL Div: 0.9409
# Epoch 564/1000, Mean Reward: -2.3028, Mean KL Div: 1.0068
# Epoch 565/1000, Mean Reward: -2.4670, Mean KL Div: 1.1341
# Epoch 566/1000, Mean Reward: -2.0252, Mean KL Div: 0.9155
# Epoch 567/1000, Mean Reward: -2.0888, Mean KL Div: 0.9148
# Epoch 568/1000, Mean Reward: -2.2147, Mean KL Div: 0.9956
# Epoch 569/1000, Mean Reward: -2.3556, Mean KL Div: 1.0161
# Epoch 570/1000, Mean Reward: -2.2340, Mean KL Div: 0.9809
# Epoch 571/1000, Mean Reward: -2.1203, Mean KL Div: 0.9619
# Epoch 572/1000, Mean Reward: -2.3102, Mean KL Div: 1.0014
# Epoch 573/1000, Mean Reward: -2.3149, Mean KL Div: 0.9703
# Epoch 574/1000, Mean Reward: -2.3815, Mean KL Div: 0.9708
# Epoch 575/1000, Mean Reward: -2.2491, Mean KL Div: 0.9930
# Epoch 576/1000, Mean Reward: -2.4336, Mean KL Div: 0.9809
# Epoch 577/1000, Mean Reward: -2.7863, Mean KL Div: 1.0511
# Epoch 578/1000, Mean Reward: -2.3562, Mean KL Div: 0.9899
# Epoch 579/1000, Mean Reward: -2.7900, Mean KL Div: 1.0177
# Epoch 580/1000, Mean Reward: -2.3317, Mean KL Div: 0.9025
# Epoch 581/1000, Mean Reward: -2.5153, Mean KL Div: 1.0209
# Epoch 582/1000, Mean Reward: -2.5492, Mean KL Div: 1.1210
# Epoch 583/1000, Mean Reward: -2.1250, Mean KL Div: 1.0590
# Epoch 584/1000, Mean Reward: -2.4972, Mean KL Div: 1.0448
# Epoch 585/1000, Mean Reward: -2.3127, Mean KL Div: 0.9769
# Epoch 586/1000, Mean Reward: -2.5841, Mean KL Div: 1.0408
# Epoch 587/1000, Mean Reward: -2.5217, Mean KL Div: 1.0390
# Epoch 588/1000, Mean Reward: -2.3301, Mean KL Div: 1.0589
# Epoch 589/1000, Mean Reward: -2.3433, Mean KL Div: 1.0222
# Epoch 590/1000, Mean Reward: -2.0139, Mean KL Div: 1.0226
# Epoch 591/1000, Mean Reward: -2.2070, Mean KL Div: 1.0444
# Epoch 592/1000, Mean Reward: -2.6682, Mean KL Div: 1.1181
# Epoch 593/1000, Mean Reward: -2.7333, Mean KL Div: 0.9930
# Epoch 594/1000, Mean Reward: -2.2537, Mean KL Div: 1.0450
# Epoch 595/1000, Mean Reward: -2.5048, Mean KL Div: 1.1216
# Epoch 596/1000, Mean Reward: -2.2649, Mean KL Div: 1.1133
# Epoch 597/1000, Mean Reward: -2.5953, Mean KL Div: 1.2326
# Epoch 598/1000, Mean Reward: -2.3712, Mean KL Div: 1.1211
# Epoch 599/1000, Mean Reward: -2.6735, Mean KL Div: 1.1429
# Epoch 600/1000, Mean Reward: -2.1644, Mean KL Div: 1.1039
# Epoch 601/1000, Mean Reward: -2.4889, Mean KL Div: 1.1655
# Epoch 602/1000, Mean Reward: -2.3006, Mean KL Div: 1.1848
# Epoch 603/1000, Mean Reward: -2.5104, Mean KL Div: 1.2156
# Epoch 604/1000, Mean Reward: -2.3416, Mean KL Div: 1.1720
# Epoch 605/1000, Mean Reward: -2.2423, Mean KL Div: 1.1097
# Epoch 606/1000, Mean Reward: -2.1783, Mean KL Div: 1.1282
# Epoch 607/1000, Mean Reward: -2.3940, Mean KL Div: 1.1494
# Epoch 608/1000, Mean Reward: -2.3046, Mean KL Div: 1.2579
# Epoch 609/1000, Mean Reward: -2.3012, Mean KL Div: 1.1862
# Epoch 610/1000, Mean Reward: -2.2449, Mean KL Div: 1.1417
# Epoch 611/1000, Mean Reward: -2.2480, Mean KL Div: 1.1934
# Epoch 612/1000, Mean Reward: -2.4046, Mean KL Div: 1.1420
# Epoch 613/1000, Mean Reward: -2.2953, Mean KL Div: 1.1692
# Epoch 614/1000, Mean Reward: -2.6458, Mean KL Div: 1.2278
# Epoch 615/1000, Mean Reward: -2.1964, Mean KL Div: 1.1444
# Epoch 616/1000, Mean Reward: -2.3080, Mean KL Div: 1.1346
# Epoch 617/1000, Mean Reward: -2.3319, Mean KL Div: 1.1429
# Epoch 618/1000, Mean Reward: -2.3995, Mean KL Div: 1.0747
# Epoch 619/1000, Mean Reward: -2.4719, Mean KL Div: 1.2096
# Epoch 620/1000, Mean Reward: -2.4876, Mean KL Div: 1.2610
# Epoch 621/1000, Mean Reward: -2.2983, Mean KL Div: 1.2503
# Epoch 622/1000, Mean Reward: -2.3193, Mean KL Div: 1.1899
# Epoch 623/1000, Mean Reward: -2.3469, Mean KL Div: 1.2110
# Epoch 624/1000, Mean Reward: -2.1367, Mean KL Div: 1.2007
# Epoch 625/1000, Mean Reward: -2.2384, Mean KL Div: 1.2842
# Epoch 626/1000, Mean Reward: -2.4135, Mean KL Div: 1.2861
# Epoch 627/1000, Mean Reward: -2.6055, Mean KL Div: 1.2498
# Epoch 628/1000, Mean Reward: -2.5784, Mean KL Div: 1.2464
# Epoch 629/1000, Mean Reward: -2.2795, Mean KL Div: 1.2231
# Epoch 630/1000, Mean Reward: -2.4928, Mean KL Div: 1.1721
# Epoch 631/1000, Mean Reward: -2.2266, Mean KL Div: 1.1086
# Epoch 632/1000, Mean Reward: -2.5213, Mean KL Div: 1.3206
# Epoch 633/1000, Mean Reward: -2.5446, Mean KL Div: 1.2871
# Epoch 634/1000, Mean Reward: -2.2776, Mean KL Div: 1.2497
# Epoch 635/1000, Mean Reward: -2.3190, Mean KL Div: 1.3022
# Epoch 636/1000, Mean Reward: -2.3151, Mean KL Div: 1.2829
# Epoch 637/1000, Mean Reward: -2.4830, Mean KL Div: 1.3062
# Epoch 638/1000, Mean Reward: -2.6546, Mean KL Div: 1.4141
# Epoch 639/1000, Mean Reward: -2.2655, Mean KL Div: 1.3153
# Epoch 640/1000, Mean Reward: -2.1608, Mean KL Div: 1.3505
# Epoch 641/1000, Mean Reward: -2.3889, Mean KL Div: 1.3519
# Epoch 642/1000, Mean Reward: -2.3975, Mean KL Div: 1.3323
# Epoch 643/1000, Mean Reward: -2.4270, Mean KL Div: 1.4168
# Epoch 644/1000, Mean Reward: -2.3160, Mean KL Div: 1.3512
# Epoch 645/1000, Mean Reward: -2.1474, Mean KL Div: 1.2976
# Epoch 646/1000, Mean Reward: -2.1341, Mean KL Div: 1.2830
# Epoch 647/1000, Mean Reward: -2.2033, Mean KL Div: 1.2991
# Epoch 648/1000, Mean Reward: -2.3579, Mean KL Div: 1.4591
# Epoch 649/1000, Mean Reward: -2.5779, Mean KL Div: 1.3350
# Epoch 650/1000, Mean Reward: -2.3240, Mean KL Div: 1.3368
# Epoch 651/1000, Mean Reward: -2.5778, Mean KL Div: 1.4593
# Epoch 652/1000, Mean Reward: -2.0147, Mean KL Div: 1.2585
# Epoch 653/1000, Mean Reward: -2.0093, Mean KL Div: 1.2770
# Epoch 654/1000, Mean Reward: -2.7867, Mean KL Div: 1.4221
# Epoch 655/1000, Mean Reward: -2.4463, Mean KL Div: 1.4272
# Epoch 656/1000, Mean Reward: -2.7072, Mean KL Div: 1.6341
# Epoch 657/1000, Mean Reward: -2.6733, Mean KL Div: 1.3914
# Epoch 658/1000, Mean Reward: -2.3938, Mean KL Div: 1.4266
# Epoch 659/1000, Mean Reward: -2.4309, Mean KL Div: 1.4656
# Epoch 660/1000, Mean Reward: -2.4988, Mean KL Div: 1.4776
# Epoch 661/1000, Mean Reward: -2.3308, Mean KL Div: 1.5476
# Epoch 662/1000, Mean Reward: -2.3966, Mean KL Div: 1.4584
# Epoch 663/1000, Mean Reward: -2.7676, Mean KL Div: 1.4517
# Epoch 664/1000, Mean Reward: -2.2535, Mean KL Div: 1.5728
# Epoch 665/1000, Mean Reward: -2.2200, Mean KL Div: 1.3801
# Epoch 666/1000, Mean Reward: -2.6737, Mean KL Div: 1.5521
# Epoch 667/1000, Mean Reward: -2.6169, Mean KL Div: 1.5357
# Epoch 668/1000, Mean Reward: -2.3198, Mean KL Div: 1.3602
# Epoch 669/1000, Mean Reward: -2.5057, Mean KL Div: 1.4101
# Epoch 670/1000, Mean Reward: -2.6064, Mean KL Div: 1.4968
# Epoch 671/1000, Mean Reward: -2.5314, Mean KL Div: 1.4217
# Epoch 672/1000, Mean Reward: -2.7242, Mean KL Div: 1.5615
# Epoch 673/1000, Mean Reward: -2.3759, Mean KL Div: 1.4364
# Epoch 674/1000, Mean Reward: -2.4443, Mean KL Div: 1.5037
# Epoch 675/1000, Mean Reward: -2.5332, Mean KL Div: 1.5286
# Epoch 676/1000, Mean Reward: -2.4242, Mean KL Div: 1.5798
# Epoch 677/1000, Mean Reward: -2.4104, Mean KL Div: 1.4443
# Epoch 678/1000, Mean Reward: -2.3844, Mean KL Div: 1.4675
# Epoch 679/1000, Mean Reward: -2.3333, Mean KL Div: 1.4512
# Epoch 680/1000, Mean Reward: -2.2742, Mean KL Div: 1.4624
# Epoch 681/1000, Mean Reward: -2.4544, Mean KL Div: 1.5726
# Epoch 682/1000, Mean Reward: -2.4658, Mean KL Div: 1.4390
# Epoch 683/1000, Mean Reward: -2.3002, Mean KL Div: 1.5184
# Epoch 684/1000, Mean Reward: -2.1553, Mean KL Div: 1.5490
# Epoch 685/1000, Mean Reward: -2.6915, Mean KL Div: 1.5281
# Epoch 686/1000, Mean Reward: -2.3076, Mean KL Div: 1.5909
# Epoch 687/1000, Mean Reward: -2.4805, Mean KL Div: 1.5008
# Epoch 688/1000, Mean Reward: -2.2994, Mean KL Div: 1.6432
# Epoch 689/1000, Mean Reward: -2.2715, Mean KL Div: 1.5728
# Epoch 690/1000, Mean Reward: -2.5260, Mean KL Div: 1.4657
# Epoch 691/1000, Mean Reward: -2.3865, Mean KL Div: 1.4849
# Epoch 692/1000, Mean Reward: -2.6748, Mean KL Div: 1.5933
# Epoch 693/1000, Mean Reward: -2.6995, Mean KL Div: 1.6092
# Epoch 694/1000, Mean Reward: -2.4616, Mean KL Div: 1.5476
# Epoch 695/1000, Mean Reward: -2.1186, Mean KL Div: 1.4682
# Epoch 696/1000, Mean Reward: -2.2786, Mean KL Div: 1.5321
# Epoch 697/1000, Mean Reward: -2.2729, Mean KL Div: 1.5427
# Epoch 698/1000, Mean Reward: -2.4753, Mean KL Div: 1.6541
# Epoch 699/1000, Mean Reward: -2.1375, Mean KL Div: 1.5761
# Epoch 700/1000, Mean Reward: -2.6330, Mean KL Div: 1.4779
# Epoch 701/1000, Mean Reward: -2.6524, Mean KL Div: 1.7751
# Epoch 702/1000, Mean Reward: -2.3896, Mean KL Div: 1.6895
# Epoch 703/1000, Mean Reward: -2.6341, Mean KL Div: 1.6076
# Epoch 704/1000, Mean Reward: -2.4626, Mean KL Div: 1.6161
# Epoch 705/1000, Mean Reward: -2.5401, Mean KL Div: 1.7220
# Epoch 706/1000, Mean Reward: -3.0751, Mean KL Div: 1.8519
# Epoch 707/1000, Mean Reward: -2.2624, Mean KL Div: 1.6791
# Epoch 708/1000, Mean Reward: -2.5031, Mean KL Div: 1.6208
# Epoch 709/1000, Mean Reward: -2.4553, Mean KL Div: 1.5886
# Epoch 710/1000, Mean Reward: -2.0440, Mean KL Div: 1.5149
# Epoch 711/1000, Mean Reward: -2.4569, Mean KL Div: 1.6072
# Epoch 712/1000, Mean Reward: -2.5597, Mean KL Div: 1.6583
# Epoch 713/1000, Mean Reward: -2.3790, Mean KL Div: 1.5983
# Epoch 714/1000, Mean Reward: -2.6432, Mean KL Div: 1.5990
# Epoch 715/1000, Mean Reward: -2.4507, Mean KL Div: 1.5861
# Epoch 716/1000, Mean Reward: -2.6583, Mean KL Div: 1.6731
# Epoch 717/1000, Mean Reward: -2.3724, Mean KL Div: 1.6163
# Epoch 718/1000, Mean Reward: -2.5303, Mean KL Div: 1.5899
# Epoch 719/1000, Mean Reward: -2.3337, Mean KL Div: 1.6259
# Epoch 720/1000, Mean Reward: -2.3499, Mean KL Div: 1.6300
# Epoch 721/1000, Mean Reward: -2.4567, Mean KL Div: 1.7064
# Epoch 722/1000, Mean Reward: -2.1382, Mean KL Div: 1.6672
# Epoch 723/1000, Mean Reward: -2.1856, Mean KL Div: 1.5782
# Epoch 724/1000, Mean Reward: -2.5232, Mean KL Div: 1.7371
# Epoch 725/1000, Mean Reward: -2.1826, Mean KL Div: 1.5964
# Epoch 726/1000, Mean Reward: -2.2706, Mean KL Div: 1.6045
# Epoch 727/1000, Mean Reward: -2.5128, Mean KL Div: 1.6716
# Epoch 728/1000, Mean Reward: -2.4792, Mean KL Div: 1.6978
# Epoch 729/1000, Mean Reward: -2.4245, Mean KL Div: 1.5215
# Epoch 730/1000, Mean Reward: -2.5273, Mean KL Div: 1.7870
# Epoch 731/1000, Mean Reward: -2.3264, Mean KL Div: 1.8248
# Epoch 732/1000, Mean Reward: -2.5511, Mean KL Div: 1.7618
# Epoch 733/1000, Mean Reward: -2.2545, Mean KL Div: 1.7693
# Epoch 734/1000, Mean Reward: -2.5639, Mean KL Div: 1.7536
# Epoch 735/1000, Mean Reward: -2.5085, Mean KL Div: 1.8182
# Epoch 736/1000, Mean Reward: -2.5187, Mean KL Div: 1.7498
# Epoch 737/1000, Mean Reward: -2.4876, Mean KL Div: 1.9387
# Epoch 738/1000, Mean Reward: -2.1130, Mean KL Div: 1.6048
# Epoch 739/1000, Mean Reward: -2.2992, Mean KL Div: 1.8219
# Epoch 740/1000, Mean Reward: -2.3301, Mean KL Div: 1.5718
# Epoch 741/1000, Mean Reward: -2.5772, Mean KL Div: 1.7777
# Epoch 742/1000, Mean Reward: -2.5353, Mean KL Div: 1.7568
# Epoch 743/1000, Mean Reward: -2.0488, Mean KL Div: 1.5704
# Epoch 744/1000, Mean Reward: -2.5522, Mean KL Div: 1.7338
# Epoch 745/1000, Mean Reward: -2.6687, Mean KL Div: 1.9437
# Epoch 746/1000, Mean Reward: -2.5752, Mean KL Div: 1.7129
# Epoch 747/1000, Mean Reward: -2.3439, Mean KL Div: 1.7521
# Epoch 748/1000, Mean Reward: -2.2165, Mean KL Div: 1.6591
# Epoch 749/1000, Mean Reward: -2.6180, Mean KL Div: 1.8732
# Epoch 750/1000, Mean Reward: -2.5792, Mean KL Div: 1.6899
# Epoch 751/1000, Mean Reward: -2.5933, Mean KL Div: 1.8626
# Epoch 752/1000, Mean Reward: -2.7178, Mean KL Div: 1.8725
# Epoch 753/1000, Mean Reward: -2.5468, Mean KL Div: 1.8195
# Epoch 754/1000, Mean Reward: -2.3891, Mean KL Div: 1.9008
# Epoch 755/1000, Mean Reward: -2.2636, Mean KL Div: 1.7875
# Epoch 756/1000, Mean Reward: -2.2829, Mean KL Div: 1.8546
# Epoch 757/1000, Mean Reward: -2.3453, Mean KL Div: 1.8314
# Epoch 758/1000, Mean Reward: -2.5295, Mean KL Div: 1.7692
# Epoch 759/1000, Mean Reward: -3.1784, Mean KL Div: 2.1121
# Epoch 760/1000, Mean Reward: -2.9238, Mean KL Div: 2.1108
# Epoch 761/1000, Mean Reward: -2.6339, Mean KL Div: 2.0699
# Epoch 762/1000, Mean Reward: -2.5114, Mean KL Div: 1.8093
# Epoch 763/1000, Mean Reward: -2.2388, Mean KL Div: 1.7375
# Epoch 764/1000, Mean Reward: -2.3036, Mean KL Div: 1.6935
# Epoch 765/1000, Mean Reward: -2.4175, Mean KL Div: 2.0084
# Epoch 766/1000, Mean Reward: -2.6762, Mean KL Div: 2.0080
# Epoch 767/1000, Mean Reward: -2.6696, Mean KL Div: 1.7806
# Epoch 768/1000, Mean Reward: -2.1671, Mean KL Div: 1.8269
# Epoch 769/1000, Mean Reward: -2.6382, Mean KL Div: 2.0339
# Epoch 770/1000, Mean Reward: -2.5093, Mean KL Div: 1.9424
# Epoch 771/1000, Mean Reward: -2.3812, Mean KL Div: 1.8231
# Epoch 772/1000, Mean Reward: -2.5902, Mean KL Div: 1.9461
# Epoch 773/1000, Mean Reward: -2.5998, Mean KL Div: 1.9592
# Epoch 774/1000, Mean Reward: -2.4282, Mean KL Div: 1.9888
# Epoch 775/1000, Mean Reward: -2.6254, Mean KL Div: 2.0934
# Epoch 776/1000, Mean Reward: -2.3076, Mean KL Div: 1.9624
# Epoch 777/1000, Mean Reward: -2.3786, Mean KL Div: 1.9904
# Epoch 778/1000, Mean Reward: -2.5659, Mean KL Div: 2.0652
# Epoch 779/1000, Mean Reward: -2.7053, Mean KL Div: 1.9409
# Epoch 780/1000, Mean Reward: -2.4903, Mean KL Div: 1.8880
# Epoch 781/1000, Mean Reward: -2.2620, Mean KL Div: 1.9360
# Epoch 782/1000, Mean Reward: -2.2688, Mean KL Div: 1.9768
# Epoch 783/1000, Mean Reward: -2.6427, Mean KL Div: 1.9773
# Epoch 784/1000, Mean Reward: -2.2386, Mean KL Div: 2.0093
# Epoch 785/1000, Mean Reward: -2.4790, Mean KL Div: 1.9159
# Epoch 786/1000, Mean Reward: -2.5524, Mean KL Div: 1.9332
# Epoch 787/1000, Mean Reward: -2.4484, Mean KL Div: 1.9527
# Epoch 788/1000, Mean Reward: -2.2025, Mean KL Div: 1.8079
# Epoch 789/1000, Mean Reward: -2.6434, Mean KL Div: 1.8922
# Epoch 790/1000, Mean Reward: -2.6234, Mean KL Div: 1.9011
# Epoch 791/1000, Mean Reward: -2.7378, Mean KL Div: 2.0367
# Epoch 792/1000, Mean Reward: -2.2842, Mean KL Div: 1.9183
# Epoch 793/1000, Mean Reward: -2.2350, Mean KL Div: 2.1774
# Epoch 794/1000, Mean Reward: -2.5185, Mean KL Div: 1.9059
# Epoch 795/1000, Mean Reward: -2.5129, Mean KL Div: 1.9333
# Epoch 796/1000, Mean Reward: -2.5737, Mean KL Div: 2.0989
# Epoch 797/1000, Mean Reward: -2.6224, Mean KL Div: 2.0472
# Epoch 798/1000, Mean Reward: -2.5029, Mean KL Div: 2.0011
# Epoch 799/1000, Mean Reward: -2.3839, Mean KL Div: 2.0649
# Epoch 800/1000, Mean Reward: -2.5303, Mean KL Div: 2.3921
# Epoch 801/1000, Mean Reward: -2.7241, Mean KL Div: 1.9519
# Epoch 802/1000, Mean Reward: -2.2058, Mean KL Div: 1.9506
# Epoch 803/1000, Mean Reward: -2.3205, Mean KL Div: 2.1234
# Epoch 804/1000, Mean Reward: -2.4839, Mean KL Div: 1.9984
# Epoch 805/1000, Mean Reward: -2.6399, Mean KL Div: 1.9954
# Epoch 806/1000, Mean Reward: -2.5400, Mean KL Div: 1.8716
# Epoch 807/1000, Mean Reward: -2.5795, Mean KL Div: 2.0100
# Epoch 808/1000, Mean Reward: -2.4868, Mean KL Div: 2.0853
# Epoch 809/1000, Mean Reward: -2.2923, Mean KL Div: 1.9315
# Epoch 810/1000, Mean Reward: -2.6190, Mean KL Div: 1.9276
# Epoch 811/1000, Mean Reward: -2.2940, Mean KL Div: 1.8471
# Epoch 812/1000, Mean Reward: -2.9096, Mean KL Div: 2.2299
# Epoch 813/1000, Mean Reward: -2.5165, Mean KL Div: 1.8740
# Epoch 814/1000, Mean Reward: -2.2669, Mean KL Div: 1.8407
# Epoch 815/1000, Mean Reward: -2.3088, Mean KL Div: 1.9969
# Epoch 816/1000, Mean Reward: -2.5668, Mean KL Div: 1.9309
# Epoch 817/1000, Mean Reward: -2.4394, Mean KL Div: 1.9284
# Epoch 818/1000, Mean Reward: -2.2955, Mean KL Div: 1.9846
# Epoch 819/1000, Mean Reward: -2.5453, Mean KL Div: 1.9239
# Epoch 820/1000, Mean Reward: -2.5611, Mean KL Div: 1.9088
# Epoch 821/1000, Mean Reward: -2.6139, Mean KL Div: 1.9833
# Epoch 822/1000, Mean Reward: -2.4991, Mean KL Div: 2.2221
# Epoch 823/1000, Mean Reward: -2.8636, Mean KL Div: 2.1665
# Epoch 824/1000, Mean Reward: -2.2357, Mean KL Div: 1.7313
# Epoch 825/1000, Mean Reward: -2.6165, Mean KL Div: 2.0012
# Epoch 826/1000, Mean Reward: -2.3096, Mean KL Div: 1.8361
# Epoch 827/1000, Mean Reward: -2.6657, Mean KL Div: 1.9891
# Epoch 828/1000, Mean Reward: -2.4974, Mean KL Div: 1.9825
# Epoch 829/1000, Mean Reward: -2.4138, Mean KL Div: 2.1456
# Epoch 830/1000, Mean Reward: -2.5994, Mean KL Div: 1.9172
# Epoch 831/1000, Mean Reward: -2.2757, Mean KL Div: 1.9050
# Epoch 832/1000, Mean Reward: -2.2644, Mean KL Div: 1.9159
# Epoch 833/1000, Mean Reward: -2.5976, Mean KL Div: 1.8724
# Epoch 834/1000, Mean Reward: -2.2313, Mean KL Div: 1.8689
# Epoch 835/1000, Mean Reward: -2.2779, Mean KL Div: 1.9878
# Epoch 836/1000, Mean Reward: -2.5570, Mean KL Div: 1.9526
# Epoch 837/1000, Mean Reward: -2.5615, Mean KL Div: 2.0013
# Epoch 838/1000, Mean Reward: -2.3287, Mean KL Div: 1.9457
# Epoch 839/1000, Mean Reward: -2.3029, Mean KL Div: 2.0456
# Epoch 840/1000, Mean Reward: -2.6391, Mean KL Div: 2.1262
# Epoch 841/1000, Mean Reward: -2.4506, Mean KL Div: 1.9978
# Epoch 842/1000, Mean Reward: -2.5448, Mean KL Div: 2.1666
# Epoch 843/1000, Mean Reward: -2.4188, Mean KL Div: 2.0254
# Epoch 844/1000, Mean Reward: -2.4852, Mean KL Div: 2.0223
# Epoch 845/1000, Mean Reward: -2.3537, Mean KL Div: 2.0233
# Epoch 846/1000, Mean Reward: -2.3567, Mean KL Div: 1.9580
# Epoch 847/1000, Mean Reward: -2.2866, Mean KL Div: 2.0267
# Epoch 848/1000, Mean Reward: -2.3824, Mean KL Div: 2.1557
# Epoch 849/1000, Mean Reward: -2.4672, Mean KL Div: 2.0383
# Epoch 850/1000, Mean Reward: -2.5741, Mean KL Div: 2.0068
# Epoch 851/1000, Mean Reward: -2.6674, Mean KL Div: 2.0399
# Epoch 852/1000, Mean Reward: -2.6805, Mean KL Div: 2.1090
# Epoch 853/1000, Mean Reward: -2.3198, Mean KL Div: 2.2099
# Epoch 854/1000, Mean Reward: -2.4887, Mean KL Div: 1.9314
# Epoch 855/1000, Mean Reward: -2.3744, Mean KL Div: 1.9882
# Epoch 856/1000, Mean Reward: -2.8128, Mean KL Div: 2.3496
# Epoch 857/1000, Mean Reward: -2.4190, Mean KL Div: 2.0498
# Epoch 858/1000, Mean Reward: -2.4061, Mean KL Div: 2.3241
# Epoch 859/1000, Mean Reward: -2.1890, Mean KL Div: 2.0889
# Epoch 860/1000, Mean Reward: -2.5992, Mean KL Div: 2.1015
# Epoch 861/1000, Mean Reward: -2.3357, Mean KL Div: 2.1647
# Epoch 862/1000, Mean Reward: -2.3149, Mean KL Div: 2.1582
# Epoch 863/1000, Mean Reward: -2.5810, Mean KL Div: 2.2567
# Epoch 864/1000, Mean Reward: -2.5061, Mean KL Div: 2.2464
# Epoch 865/1000, Mean Reward: -2.2211, Mean KL Div: 2.1688
# Epoch 866/1000, Mean Reward: -2.3680, Mean KL Div: 1.9818
# Epoch 867/1000, Mean Reward: -2.4314, Mean KL Div: 2.1654
# Epoch 868/1000, Mean Reward: -2.4389, Mean KL Div: 2.0639
# Epoch 869/1000, Mean Reward: -2.2029, Mean KL Div: 2.1297
# Epoch 870/1000, Mean Reward: -2.5583, Mean KL Div: 2.1481
# Epoch 871/1000, Mean Reward: -2.2893, Mean KL Div: 2.2657
# Epoch 872/1000, Mean Reward: -2.4416, Mean KL Div: 2.2627
# Epoch 873/1000, Mean Reward: -2.5883, Mean KL Div: 2.4074
# Epoch 874/1000, Mean Reward: -2.2013, Mean KL Div: 2.0616
# Epoch 875/1000, Mean Reward: -2.1543, Mean KL Div: 1.9063
# Epoch 876/1000, Mean Reward: -2.0523, Mean KL Div: 1.9838
# Epoch 877/1000, Mean Reward: -2.6175, Mean KL Div: 2.4359
# Epoch 878/1000, Mean Reward: -2.5461, Mean KL Div: 2.0459
# Epoch 879/1000, Mean Reward: -2.3126, Mean KL Div: 2.0473
# Epoch 880/1000, Mean Reward: -2.0509, Mean KL Div: 1.9430
# Epoch 881/1000, Mean Reward: -2.4071, Mean KL Div: 2.1411
# Epoch 882/1000, Mean Reward: -2.8356, Mean KL Div: 2.2209
# Epoch 883/1000, Mean Reward: -2.4100, Mean KL Div: 2.3842
# Epoch 884/1000, Mean Reward: -2.7529, Mean KL Div: 2.4306
# Epoch 885/1000, Mean Reward: -2.2400, Mean KL Div: 2.1362
# Epoch 886/1000, Mean Reward: -2.4281, Mean KL Div: 2.0816
# Epoch 887/1000, Mean Reward: -2.7780, Mean KL Div: 2.2118
# Epoch 888/1000, Mean Reward: -2.4990, Mean KL Div: 2.3202
# Epoch 889/1000, Mean Reward: -2.3725, Mean KL Div: 2.1744
# Epoch 890/1000, Mean Reward: -2.2348, Mean KL Div: 2.2267
# Epoch 891/1000, Mean Reward: -2.6222, Mean KL Div: 2.3747
# Epoch 892/1000, Mean Reward: -2.5909, Mean KL Div: 2.3494
# Epoch 893/1000, Mean Reward: -2.2668, Mean KL Div: 2.4209
# Epoch 894/1000, Mean Reward: -2.7333, Mean KL Div: 2.4235
# Epoch 895/1000, Mean Reward: -2.6860, Mean KL Div: 2.3881
# Epoch 896/1000, Mean Reward: -2.4700, Mean KL Div: 2.5999
# Epoch 897/1000, Mean Reward: -2.1715, Mean KL Div: 2.2756
# Epoch 898/1000, Mean Reward: -2.1143, Mean KL Div: 2.3075
# Epoch 899/1000, Mean Reward: -2.7312, Mean KL Div: 2.3234
# Epoch 900/1000, Mean Reward: -2.5227, Mean KL Div: 2.4391
# Epoch 901/1000, Mean Reward: -2.5282, Mean KL Div: 2.3160
# Epoch 902/1000, Mean Reward: -2.3998, Mean KL Div: 2.5073
# Epoch 903/1000, Mean Reward: -2.3505, Mean KL Div: 2.4202
# Epoch 904/1000, Mean Reward: -2.5279, Mean KL Div: 2.3886
# Epoch 905/1000, Mean Reward: -2.6713, Mean KL Div: 2.7099
# Epoch 906/1000, Mean Reward: -2.5357, Mean KL Div: 2.4381
# Epoch 907/1000, Mean Reward: -2.1253, Mean KL Div: 2.3965
# Epoch 908/1000, Mean Reward: -2.4696, Mean KL Div: 2.5596
# Epoch 909/1000, Mean Reward: -2.5585, Mean KL Div: 2.6483
# Epoch 910/1000, Mean Reward: -2.7931, Mean KL Div: 2.7284
# Epoch 911/1000, Mean Reward: -2.6939, Mean KL Div: 2.8863
# Epoch 912/1000, Mean Reward: -2.7239, Mean KL Div: 2.6764
# Epoch 913/1000, Mean Reward: -2.2212, Mean KL Div: 2.5229
# Epoch 914/1000, Mean Reward: -2.6734, Mean KL Div: 2.7653
# Epoch 915/1000, Mean Reward: -2.7673, Mean KL Div: 2.8340
# Epoch 916/1000, Mean Reward: -2.8449, Mean KL Div: 2.6924
# Epoch 917/1000, Mean Reward: -2.3838, Mean KL Div: 2.4631
# Epoch 918/1000, Mean Reward: -2.2040, Mean KL Div: 2.2786
# Epoch 919/1000, Mean Reward: -2.5095, Mean KL Div: 2.4705
# Epoch 920/1000, Mean Reward: -2.8357, Mean KL Div: 2.7154
# Epoch 921/1000, Mean Reward: -2.4667, Mean KL Div: 2.6982
# Epoch 922/1000, Mean Reward: -2.2699, Mean KL Div: 2.6474
# Epoch 923/1000, Mean Reward: -2.5976, Mean KL Div: 2.7066
# Epoch 924/1000, Mean Reward: -2.3149, Mean KL Div: 2.7145
# Epoch 925/1000, Mean Reward: -2.9091, Mean KL Div: 2.8058
# Epoch 926/1000, Mean Reward: -2.7093, Mean KL Div: 2.8687
# Epoch 927/1000, Mean Reward: -2.5994, Mean KL Div: 2.7039
# Epoch 928/1000, Mean Reward: -2.5264, Mean KL Div: 2.7843
# Epoch 929/1000, Mean Reward: -2.9320, Mean KL Div: 3.1250
# Epoch 930/1000, Mean Reward: -2.3294, Mean KL Div: 2.6658
# Epoch 931/1000, Mean Reward: -2.6680, Mean KL Div: 2.9317
# Epoch 932/1000, Mean Reward: -2.6178, Mean KL Div: 2.9522
# Epoch 933/1000, Mean Reward: -2.6354, Mean KL Div: 2.7361
# Epoch 934/1000, Mean Reward: -2.7675, Mean KL Div: 2.7419
# Epoch 935/1000, Mean Reward: -2.5400, Mean KL Div: 2.6522
# Epoch 936/1000, Mean Reward: -2.4481, Mean KL Div: 2.6534
# Epoch 937/1000, Mean Reward: -2.4751, Mean KL Div: 2.7288
# Epoch 938/1000, Mean Reward: -2.0696, Mean KL Div: 2.3679
# Epoch 939/1000, Mean Reward: -2.7785, Mean KL Div: 2.7869
# Epoch 940/1000, Mean Reward: -2.6383, Mean KL Div: 2.6926
# Epoch 941/1000, Mean Reward: -2.5899, Mean KL Div: 2.6974
# Epoch 942/1000, Mean Reward: -2.3537, Mean KL Div: 2.4424
# Epoch 943/1000, Mean Reward: -2.4884, Mean KL Div: 2.4850
# Epoch 944/1000, Mean Reward: -2.4624, Mean KL Div: 2.6595
# Epoch 945/1000, Mean Reward: -2.4703, Mean KL Div: 2.7530
# Epoch 946/1000, Mean Reward: -2.5800, Mean KL Div: 2.6117
# Epoch 947/1000, Mean Reward: -2.8636, Mean KL Div: 2.6771
# Epoch 948/1000, Mean Reward: -2.3421, Mean KL Div: 2.5150
# Epoch 949/1000, Mean Reward: -2.5719, Mean KL Div: 2.8161
# Epoch 950/1000, Mean Reward: -2.4509, Mean KL Div: 2.5919
# Epoch 951/1000, Mean Reward: -2.8873, Mean KL Div: 2.7186
# Epoch 952/1000, Mean Reward: -2.7485, Mean KL Div: 2.7833
# Epoch 953/1000, Mean Reward: -2.4274, Mean KL Div: 2.5610
# Epoch 954/1000, Mean Reward: -2.3988, Mean KL Div: 2.7333
# Epoch 955/1000, Mean Reward: -2.5020, Mean KL Div: 2.4828
# Epoch 956/1000, Mean Reward: -2.6807, Mean KL Div: 2.7838
# Epoch 957/1000, Mean Reward: -2.7632, Mean KL Div: 2.6802
# Epoch 958/1000, Mean Reward: -2.5895, Mean KL Div: 2.7358
# Epoch 959/1000, Mean Reward: -2.5616, Mean KL Div: 2.8142
# Epoch 960/1000, Mean Reward: -2.3948, Mean KL Div: 2.6680
# Epoch 961/1000, Mean Reward: -2.7555, Mean KL Div: 2.6623
# Epoch 962/1000, Mean Reward: -2.5759, Mean KL Div: 2.4794
# Epoch 963/1000, Mean Reward: -2.7080, Mean KL Div: 2.7752
# Epoch 964/1000, Mean Reward: -2.8780, Mean KL Div: 2.6460
# Epoch 965/1000, Mean Reward: -2.4727, Mean KL Div: 2.6728
# Epoch 966/1000, Mean Reward: -3.0879, Mean KL Div: 2.8940
# Epoch 967/1000, Mean Reward: -2.7128, Mean KL Div: 3.0211
# Epoch 968/1000, Mean Reward: -2.5483, Mean KL Div: 2.6606
# Epoch 969/1000, Mean Reward: -2.2600, Mean KL Div: 2.7620
# Epoch 970/1000, Mean Reward: -2.7431, Mean KL Div: 2.6778
# Epoch 971/1000, Mean Reward: -2.7385, Mean KL Div: 2.9661
# Epoch 972/1000, Mean Reward: -2.8430, Mean KL Div: 2.9649
# Epoch 973/1000, Mean Reward: -2.4688, Mean KL Div: 2.5934
# Epoch 974/1000, Mean Reward: -2.5929, Mean KL Div: 2.7736
# Epoch 975/1000, Mean Reward: -2.3383, Mean KL Div: 2.5493
# Epoch 976/1000, Mean Reward: -2.4607, Mean KL Div: 2.6745
# Epoch 977/1000, Mean Reward: -2.4030, Mean KL Div: 2.4667
# Epoch 978/1000, Mean Reward: -2.6274, Mean KL Div: 2.5794
# Epoch 979/1000, Mean Reward: -2.6436, Mean KL Div: 2.4518
# Epoch 980/1000, Mean Reward: -2.3662, Mean KL Div: 2.5659
# Epoch 981/1000, Mean Reward: -2.6355, Mean KL Div: 2.7476
# Epoch 982/1000, Mean Reward: -2.6360, Mean KL Div: 3.0757
# Epoch 983/1000, Mean Reward: -2.6259, Mean KL Div: 2.6487
# Epoch 984/1000, Mean Reward: -2.3099, Mean KL Div: 2.8535
# Epoch 985/1000, Mean Reward: -2.7545, Mean KL Div: 2.7791
# Epoch 986/1000, Mean Reward: -2.5722, Mean KL Div: 2.9246
# Epoch 987/1000, Mean Reward: -2.6278, Mean KL Div: 2.8125
# Epoch 988/1000, Mean Reward: -2.4177, Mean KL Div: 2.8058
# Epoch 989/1000, Mean Reward: -2.5177, Mean KL Div: 2.8509
# Epoch 990/1000, Mean Reward: -2.5548, Mean KL Div: 2.9237
# Epoch 991/1000, Mean Reward: -2.8804, Mean KL Div: 2.8700
# Epoch 992/1000, Mean Reward: -2.6846, Mean KL Div: 2.9104
# Epoch 993/1000, Mean Reward: -2.3862, Mean KL Div: 2.8503
# Epoch 994/1000, Mean Reward: -2.5454, Mean KL Div: 2.6909
# Epoch 995/1000, Mean Reward: -2.6135, Mean KL Div: 2.7638
# Epoch 996/1000, Mean Reward: -1.9868, Mean KL Div: 2.5664
# Epoch 997/1000, Mean Reward: -2.6667, Mean KL Div: 2.6882
# Epoch 998/1000, Mean Reward: -2.3211, Mean KL Div: 2.7562
# Epoch 999/1000, Mean Reward: -2.2795, Mean KL Div: 2.7548
# Epoch 1000/1000, Mean Reward: -2.6862, Mean KL Div: 2.9097

# %%
rl_samples = ddim_sample(rl_model, scheduler, 10000, device)
rl_reward = compute_reward(rl_samples).mean().item()
rl_samples = rl_samples.cpu().numpy()

# %% [markdown]
# ## Direct Backpropagation fine-tuning with KL regularizaiton

# %%
# Copy pre-trained weights to fine-tune model
backprop_model = copy.deepcopy(pre_trained_model)
optimizer = optim.Adam(backprop_model.parameters(), lr=1e-5)

backprop_epochs = 300

# %%
# Fine-tuning loop

def fine_tune_step(pre_trained_model, fine_tune_model, scheduler, optimizer, kl_weight, max_grad_norm=1.0):
    optimizer.zero_grad()

    kl_loss = 0.0

    x_prev = torch.randn((256, 3)).to(device)
    batch_size = x_prev.shape[0]

    for t in scheduler.timesteps:
        t = torch.full((batch_size,), t, device=x_prev.device, dtype=torch.long)
        with torch.no_grad():
            pre_trained_noise_pred = pre_trained_model(x_prev, t.float() / scheduler.num_train_timesteps)
    
        fine_tune_noise_pred = fine_tune_model(x_prev, t.float() / scheduler.num_train_timesteps)
    
        x_prev, _, kl_div = ddim_step_KL(scheduler, fine_tune_noise_pred, pre_trained_noise_pred, t, x_prev, eta=1.0)
        kl_loss += kl_div

    reward = compute_reward(x_prev)
    
    loss = -reward.mean() + kl_weight * kl_loss.mean()
    
    loss.backward()

    # Clip gradients and perform optimization step
    nn.utils.clip_grad_norm_(fine_tune_model.parameters(), max_grad_norm)
    optimizer.step()
    
    return loss.item(), reward.mean().item(), kl_loss.mean().item()

for epoch in range(backprop_epochs):
    loss, reward, kl_div = fine_tune_step(pre_trained_model, backprop_model, scheduler, optimizer, kl_weight, max_grad_norm=5.0)
    if epoch % 10 == 0:
        print(f"Fine-tuning Epoch {epoch}, Loss: {loss:.4f}, Reward: {reward:.4f}, KL Div: {kl_div:.16f}")
# Out:
# Fine-tuning Epoch 0, Loss: 3.2236, Reward: -3.2236, KL Div: 0.0000000000000000
# Fine-tuning Epoch 10, Loss: 3.1282, Reward: -3.1252, KL Div: 0.0029867631383240
# Fine-tuning Epoch 20, Loss: 3.1338, Reward: -3.1233, KL Div: 0.0105044497177005
# Fine-tuning Epoch 30, Loss: 3.3254, Reward: -3.3030, KL Div: 0.0223784856498241
# Fine-tuning Epoch 40, Loss: 2.8316, Reward: -2.7916, KL Div: 0.0400366894900799
# Fine-tuning Epoch 50, Loss: 3.4183, Reward: -3.3551, KL Div: 0.0632170811295509
# Fine-tuning Epoch 60, Loss: 3.0472, Reward: -2.9618, KL Div: 0.0853686928749084
# Fine-tuning Epoch 70, Loss: 3.3390, Reward: -3.2193, KL Div: 0.1196414530277252
# Fine-tuning Epoch 80, Loss: 2.8409, Reward: -2.6798, KL Div: 0.1611099243164062
# Fine-tuning Epoch 90, Loss: 3.1012, Reward: -2.9030, KL Div: 0.1981469839811325
# Fine-tuning Epoch 100, Loss: 2.7860, Reward: -2.5468, KL Div: 0.2392529696226120
# Fine-tuning Epoch 110, Loss: 3.1226, Reward: -2.8138, KL Div: 0.3087962269783020
# Fine-tuning Epoch 120, Loss: 3.2434, Reward: -2.8603, KL Div: 0.3831393718719482
# Fine-tuning Epoch 130, Loss: 3.3274, Reward: -2.8517, KL Div: 0.4756954312324524
# Fine-tuning Epoch 140, Loss: 3.1363, Reward: -2.5881, KL Div: 0.5482103228569031
# Fine-tuning Epoch 150, Loss: 3.2943, Reward: -2.6226, KL Div: 0.6716838479042053
# Fine-tuning Epoch 160, Loss: 3.5289, Reward: -2.7173, KL Div: 0.8116224408149719
# Fine-tuning Epoch 170, Loss: 3.6521, Reward: -2.6949, KL Div: 0.9571094512939453
# Fine-tuning Epoch 180, Loss: 3.8441, Reward: -2.7268, KL Div: 1.1172645092010498
# Fine-tuning Epoch 190, Loss: 3.7270, Reward: -2.4188, KL Div: 1.3082058429718018
# Fine-tuning Epoch 200, Loss: 4.3546, Reward: -2.7924, KL Div: 1.5622214078903198
# Fine-tuning Epoch 210, Loss: 4.0962, Reward: -2.2957, KL Div: 1.8004990816116333
# Fine-tuning Epoch 220, Loss: 5.0140, Reward: -2.8240, KL Div: 2.1900091171264648
# Fine-tuning Epoch 230, Loss: 5.1971, Reward: -2.5801, KL Div: 2.6169581413269043
# Fine-tuning Epoch 240, Loss: 5.5495, Reward: -2.4975, KL Div: 3.0519709587097168
# Fine-tuning Epoch 250, Loss: 6.2899, Reward: -2.7747, KL Div: 3.5152454376220703
# Fine-tuning Epoch 260, Loss: 6.8278, Reward: -2.6324, KL Div: 4.1954035758972168
# Fine-tuning Epoch 270, Loss: 7.4621, Reward: -2.5414, KL Div: 4.9207277297973633
# Fine-tuning Epoch 280, Loss: 8.2127, Reward: -2.3805, KL Div: 5.8321952819824219
# Fine-tuning Epoch 290, Loss: 9.1522, Reward: -2.3058, KL Div: 6.8463792800903320

# %%
backprop_samples = ddim_sample(backprop_model, scheduler, 10000, device)
backprop_reward = compute_reward(backprop_samples).mean().item()
backprop_samples = backprop_samples.cpu().numpy()

# %% [markdown]
# ## Approximate Guidance

# %%
@torch.no_grad()
def guided_sampling(model, scheduler, n_samples, device, num_inference_steps=50, eta=0.0, rho=1):
    latents = torch.randn((n_samples, 3)).to(device)
    
    scheduler.set_timesteps(num_inference_steps)
    timesteps = scheduler.timesteps.to(device)

    for i, t in enumerate(timesteps):
        prev_timestep = t - scheduler.num_train_timesteps // num_inference_steps

        # Compute alpha_prod_t and alpha_prod_t_prev
        alpha_prod_t = scheduler.alphas_cumprod[t].to(device)
        alpha_prod_t_prev = torch.where(
            prev_timestep >= 0,
            scheduler.alphas_cumprod[prev_timestep],
            scheduler.final_alpha_cumprod
        )
        beta_prod_t = 1 - alpha_prod_t
        
        # Compute std_dev_t
        variance = (1 - alpha_prod_t_prev) / (1 - alpha_prod_t) * (1 - alpha_prod_t / alpha_prod_t_prev)
        std_dev_t = eta * variance.sqrt()

        with torch.enable_grad():
            latents = latents.detach().requires_grad_(True)
            time = torch.full((latents.shape[0],), t.item(), device=device, dtype=torch.float32)
            noise_pred = model(latents, time / scheduler.num_train_timesteps)

            pred_original_sample = (latents - beta_prod_t.sqrt() * noise_pred) / alpha_prod_t.sqrt()
            reward = compute_reward(pred_original_sample)
            
            approx_guidance = torch.autograd.grad(outputs=reward, inputs=latents, grad_outputs=torch.ones_like(reward))[0]
            
        approx_guidance = torch.nan_to_num(approx_guidance.detach())
        approx_guidance *= rho
        
        # Compute the predicted next sample mean
        pred_sample_direction = (1 - alpha_prod_t_prev - std_dev_t**2).sqrt() * noise_pred
        prev_sample_mean = alpha_prod_t_prev.sqrt() * pred_original_sample + pred_sample_direction
        
        # Add noise based on std_dev_t
        noise = torch.randn_like(latents)
        prev_sample = prev_sample_mean + std_dev_t * noise
        
        # Apply guidance
        prev_sample += approx_guidance
        latents = prev_sample

    return latents

# %%
rho = 1.0

# %%
guidance_samples = guided_sampling(
    pre_trained_model, scheduler, 10000, device, num_inference_steps=num_inference_steps, eta=1.0, rho=rho
)
guidance_reward = compute_reward(guidance_samples).mean().item()
guidance_samples = guidance_samples.cpu().numpy()

# %% [markdown]
# ## SMC

# %%
def smc_sampling(model, scheduler, n_samples, device, num_inference_steps=50, num_particles=100, 
                 resample_strategy='systematic', ess_threshold=0.5, 
                 tempering_gamma=1.,
                 eta=1.0, kl_coeff=1.0):
    latents = torch.randn((n_samples * num_particles, 3), device=device)
    scheduler.set_timesteps(num_inference_steps)
    timesteps = scheduler.timesteps

    log_w = torch.zeros(n_samples * num_particles, device=device)
    all_latents = []
    all_log_w = []
    all_resample_indices = []
    ess_trace = []
    tempering_trace = []
    rewards_trace = []

    resample_fn = resampling_function(resample_strategy=resample_strategy, ess_threshold=ess_threshold)

    for i, t in enumerate(timesteps):
        if i>0:
            log_twist_func_prev = log_twist_func.clone()
        prev_timestep = t - scheduler.num_train_timesteps // num_inference_steps

        # Compute alpha_prod_t and alpha_prod_t_prev
        alpha_prod_t = scheduler.alphas_cumprod[t].to(device)
        alpha_prod_t_prev = torch.where(
            prev_timestep >= 0,
            scheduler.alphas_cumprod[prev_timestep],
            scheduler.final_alpha_cumprod
        )
        beta_prod_t = 1 - alpha_prod_t
        
        # Compute std_dev_t
        variance = eta**2 * (1 - alpha_prod_t_prev) / (1 - alpha_prod_t) * (1 - alpha_prod_t / alpha_prod_t_prev)
        std_dev_t = variance.sqrt()

        # Calculate tempering factor
        tempering_factor = min((1 + tempering_gamma)**i - 1, 1.)

        # Predict noise and calculate reward
        t_input = torch.full((latents.shape[0],), t.item() / scheduler.num_train_timesteps, device=device, dtype=torch.float32)
        
        # latents.requires_grad_(True)
        # noise_pred = model(latents, t_input)
        # pred_original_sample = (latents - (1 - scheduler.alphas_cumprod[t]).sqrt() * noise_pred) / scheduler.alphas_cumprod[t].sqrt()
        # rewards = compute_reward(pred_original_sample)

        # # Calculate approximate guidance
        # approx_guidance = torch.autograd.grad(rewards.sum(), latents, create_graph=False, retain_graph=False)[0]
        # approx_guidance_1 = approx_guidance.detach().clone()
        # latents = latents.detach()

        latents.requires_grad_(True)
        noise_pred = model(latents, t_input)
        pred_original_sample = (latents - (1 - scheduler.alphas_cumprod[t]).sqrt() * noise_pred) / scheduler.alphas_cumprod[t].sqrt()
        rewards = compute_reward(pred_original_sample)

        # Calculate approximate guidance
        approx_guidance = torch.autograd.grad(outputs=rewards, inputs=latents, grad_outputs=torch.ones_like(rewards))[0]
        latents = latents.detach()

        approx_guidance = torch.nan_to_num(approx_guidance) / kl_coeff

        # Apply tempering
        approx_guidance *= tempering_factor

        # Update log weights
        log_twist_func = tempering_factor * rewards / kl_coeff
        log_w += log_twist_func - log_twist_func_prev + log_prob_diffusion - log_prob_proposal if i>0 else 0.

        # Resample if necessary
        ess = compute_ess_from_log_w(log_w.view(n_samples, -1))
        ess_trace.append(ess.cpu())

        # Detach log_w before resampling
        resample_indices, is_resampled, new_log_w = resample_fn(log_w.detach().view(n_samples, -1))
        # print(resample_indices.shape)
        log_w = new_log_w.view(-1).to(device)

        latents = latents.view(n_samples, num_particles, 3)[torch.arange(n_samples, device=device).unsqueeze(1), resample_indices].view(-1, 3)
        noise_pred = noise_pred.view(n_samples, num_particles, 3)[torch.arange(n_samples, device=device).unsqueeze(1), resample_indices].view(-1, 3)

        all_resample_indices.append(resample_indices)

        # Store latents and update rewards trace
        all_latents.append(latents.cpu())
        rewards_trace.append(rewards.view(n_samples, -1).max(dim=1)[0].cpu())

        # Sample from proposal distribution
        pred_sample_direction = (1 - alpha_prod_t_prev - std_dev_t**2).sqrt() * noise_pred
        prev_sample_mean = alpha_prod_t_prev.sqrt() * pred_original_sample + pred_sample_direction
        latents = prev_sample_mean + std_dev_t * torch.randn_like(noise_pred)
        latents += variance * approx_guidance

        log_prob_diffusion = -0.5 * (latents - prev_sample_mean).pow(2) / variance - torch.log(std_dev_t) - torch.log(torch.sqrt(2 * torch.as_tensor(math.pi)))
        log_prob_diffusion = log_prob_diffusion.sum(dim=-1) 
        log_prob_proposal = -0.5 * (latents - prev_sample_mean - variance * approx_guidance).pow(2) / variance - torch.log(std_dev_t) - torch.log(torch.sqrt(2 * torch.as_tensor(math.pi)))
        log_prob_proposal = log_prob_proposal.sum(dim=-1)

    # Final weight update
    final_rewards = compute_reward(latents)
    log_w += final_rewards / kl_coeff - log_twist_func + log_prob_diffusion - log_prob_proposal
    normalized_w = normalize_weights(log_w.view(n_samples, -1), dim=-1).view(-1)
    resample_indices, is_resampled, new_log_w = resample_fn(log_w.detach().view(n_samples, -1))
    latents = latents.view(n_samples, num_particles, 3)[torch.arange(n_samples, device=device).unsqueeze(1), resample_indices[:, torch.randperm(resample_indices.size(1))[:10]]].view(-1, 3)
    # latents = latents.view(n_samples, num_particles, 3)[:, torch.argmax(normalized_w.view(n_samples, num_particles), dim=-1)[1], :]

    ess_trace = torch.stack(ess_trace, dim=1) if ess_trace else torch.tensor([])
    tempering_trace = torch.tensor(tempering_trace, device=device)
    rewards_trace = torch.stack(rewards_trace, dim=1) if rewards_trace else torch.tensor([])

    return latents.detach()

# %%
num_particles = 100

# %%
smc_samples = smc_sampling(
    pre_trained_model, scheduler, n_samples=1000, device=device, num_inference_steps=num_inference_steps,
    num_particles=num_particles, resample_strategy='ssp', ess_threshold=.5,
    tempering_gamma=0.008,
    eta=1.0, kl_coeff=kl_weight
)

# %%
smc_reward = compute_reward(smc_samples).mean().item()
smc_samples = smc_samples.cpu().numpy()

# %% [markdown]
# # Visualize Samples and Rewards

# %%
plt.figure(figsize=(35, 4))

# Set common axis limits
x_min, x_max = -7, 7
y_min, y_max = -7, 7
z_min, z_max = -7, 7

def create_3d_subplot(position, data, title, reward):
    ax = plt.subplot(1, 7, position, projection='3d')
    ax.scatter(data[:, 0], data[:, 1], data[:, 2], alpha=0.5, s=1)
    ax.set_title(f'{title} | reward: {reward:.2f}')
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    ax.set_xlim(x_min, x_max)
    ax.set_ylim(y_min, y_max)
    ax.set_zlim(z_min, z_max)
    ax.view_init(elev=20, azim=45)

create_3d_subplot(1, base_samples, 'Base Distribution', base_reward)
create_3d_subplot(2, pre_trained_samples, 'Pre-trained Model Distribution', pre_trained_reward)
create_3d_subplot(3, target_samples, 'Target Distribution', target_reward)
create_3d_subplot(4, rl_samples, 'RL', rl_reward)
create_3d_subplot(5, backprop_samples, 'Direct Backpropagation', backprop_reward)
create_3d_subplot(6, guidance_samples, 'Approximate Guidance', guidance_reward)
create_3d_subplot(7, smc_samples, 'SMC', smc_reward)

plt.tight_layout()

# Save the figure
plt.savefig('swiss_roll.png', dpi=300, bbox_inches='tight')

plt.show()
plt.close()

print("Figure saved as 'swiss_roll.png'")
# Out:
# Figure saved as 'swiss_roll.png'

# %% [markdown]
# ## EMD

# %%
from scipy.stats import wasserstein_distance_nd as WD
from numpy.random import choice

rl_emd = WD(rl_samples[choice(np.arange(len(rl_samples)), 500)], target_samples[choice(np.arange(len(target_samples)), 500)])
backprop_emd = WD(backprop_samples[choice(np.arange(len(backprop_samples)), 500)], target_samples[choice(np.arange(len(target_samples)), 500)])
guidance_emd = WD(guidance_samples[choice(np.arange(len(guidance_samples)), 500)], target_samples[choice(np.arange(len(target_samples)), 500)])
smc_emd = WD(smc_samples[choice(np.arange(len(smc_samples)), 500)], target_samples[choice(np.arange(len(target_samples)), 500)])
