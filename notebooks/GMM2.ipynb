# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from typing import Optional, Union, Tuple
import copy
from scipy.stats import multivariate_normal
from types import SimpleNamespace
import math
from das.smc_utils import compute_ess_from_log_w, normalize_log_weights, resampling_function, normalize_weights, adaptive_tempering

import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

import torch
import random
import torch.backends.cudnn as cudnn

torch.manual_seed(42)
torch.cuda.manual_seed(42)
torch.cuda.manual_seed_all(42)
np.random.seed(42)
cudnn.benchmark = False
cudnn.deterministic = True
random.seed(42)
# Out:
# Using device: cuda

# %% [markdown]
# ## Define Functions and Classes for Diffusion

# %%
class SimpleUNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(3, 64),  # 2D input + time
            nn.ReLU(),
            # nn.Linear(64, 128),
            # nn.ReLU(),
            # nn.Linear(128, 64),
            nn.Linear(64, 64),
            nn.ReLU(),
            nn.Linear(64, 2)  # 2D output
        )

    def forward(self, x, t):
        x = torch.cat([x, t.unsqueeze(-1)], dim=-1)
        return self.net(x)

# %%
def linear_beta_schedule(timesteps, start=0.0001, end=0.02):
    return torch.linspace(start, end, timesteps)

class DDIMScheduler:
    def __init__(self, num_train_timesteps=1000, beta_start=0.0001, beta_end=0.02, device='cpu'):
        self.num_train_timesteps = num_train_timesteps
        
        self.betas = linear_beta_schedule(num_train_timesteps, beta_start, beta_end).to(device)
        self.alphas = 1.0 - self.betas
        self.alphas_cumprod = torch.cumprod(self.alphas, dim=0)
        
        self.final_alpha_cumprod = self.alphas_cumprod[0]
        self.num_inference_steps = None
        
    def set_timesteps(self, num_inference_steps):
        self.num_inference_steps = num_inference_steps
        self.timesteps = torch.linspace(self.num_train_timesteps - 1, 0, num_inference_steps, dtype=torch.long)
        
    def _get_variance(self, timestep, prev_timestep):
        alpha_prod_t = self.alphas_cumprod[timestep]
        alpha_prod_t_prev = torch.where(
            prev_timestep >= 0,
            self.alphas_cumprod[prev_timestep],
            self.final_alpha_cumprod
        )
        beta_prod_t = 1 - alpha_prod_t
        beta_prod_t_prev = 1 - alpha_prod_t_prev
        
        variance = (beta_prod_t_prev / beta_prod_t) * (1 - alpha_prod_t / alpha_prod_t_prev)
        return variance

# %%
def ddim_step_with_logprob(
    scheduler,
    model_output: torch.FloatTensor,
    timestep: int,
    sample: torch.FloatTensor,
    eta: float = 0.0,
    prev_sample: Optional[torch.FloatTensor] = None,
) -> Tuple[torch.FloatTensor, torch.FloatTensor]:
    """
    Perform a single DDIM step with log probability calculation.
    
    Args:
        scheduler: The DDIMScheduler object.
        model_output: The output from the UNet model.
        timestep: The current timestep.
        sample: The current sample (x_t).
        eta: The eta parameter for adding noise (0 for DDIM, 1 for DDPM).
        prev_sample: Optional; the previous sample (x_{t-1}) if available.
    
    Returns:
        A tuple containing:
        - The previous sample (x_{t-1})
        - The log probability of the step
    """
    # 1. get previous step value (=t-1)
    prev_timestep = timestep - scheduler.num_train_timesteps // scheduler.num_inference_steps

    # 2. compute alphas, betas
    alpha_prod_t = scheduler.alphas_cumprod[timestep]
    alpha_prod_t_prev = torch.where(
        prev_timestep >= 0,
        scheduler.alphas_cumprod[prev_timestep],
        scheduler.final_alpha_cumprod
    )

    beta_prod_t = 1 - alpha_prod_t

    # 3. compute predicted original sample from predicted noise
    pred_original_sample = (sample - beta_prod_t.sqrt().unsqueeze(-1) * model_output) / alpha_prod_t.sqrt().unsqueeze(-1)
    
    # 4. compute variance
    variance = scheduler._get_variance(timestep, prev_timestep)
    std_dev_t = eta * variance.sqrt()

    # 5. compute "direction pointing to x_t" of formula (12) from https://arxiv.org/pdf/fontsize10.02502.pdf
    pred_sample_direction = (1 - alpha_prod_t_prev - std_dev_t**2).sqrt().unsqueeze(-1) * model_output

    # 6. compute x_t without "random noise" of formula (12) from https://arxiv.org/pdf/2010.02502.pdf
    prev_sample_mean = alpha_prod_t_prev.sqrt().unsqueeze(-1) * pred_original_sample + pred_sample_direction

    # 6. Add noise
    if prev_sample is None:
        noise = torch.randn(model_output.shape, device=device, dtype=model_output.dtype)
        prev_sample = prev_sample_mean + std_dev_t.unsqueeze(-1) * noise
    
    # 7. Compute log probability
    log_prob = _compute_gaussian_log_prob(prev_sample, prev_sample_mean, std_dev_t.unsqueeze(-1)).mean(-1)

    return prev_sample, log_prob

def _compute_gaussian_log_prob(x, mean, std):
    """Compute log probability for Gaussian distribution."""
    log_scale = torch.log(std)
    return -((x - mean) ** 2) / (2 * std ** 2) - log_scale - math.log(math.sqrt(2 * math.pi))

# %%
def ddim_step_KL(
    scheduler: DDIMScheduler,
    model_output: torch.FloatTensor,
    old_model_output: torch.FloatTensor,
    timestep: torch.LongTensor,
    sample: torch.FloatTensor,
    eta: float = 0.0,
    generator=None,
    variance_noise: Optional[torch.FloatTensor] = None,
) -> Union[Tuple[torch.FloatTensor, torch.FloatTensor], Tuple]:
    
    # 1. get previous step value (=t-1)
    prev_timestep = timestep - scheduler.num_train_timesteps // scheduler.num_inference_steps

    # 2. compute alphas, betas
    alpha_prod_t = scheduler.alphas_cumprod[timestep]
    alpha_prod_t_prev = torch.where(
        prev_timestep >= 0,
        scheduler.alphas_cumprod[prev_timestep],
        scheduler.final_alpha_cumprod
    )

    beta_prod_t = 1 - alpha_prod_t

    # 3. compute predicted original sample from predicted noise
    pred_original_sample = (sample - beta_prod_t.sqrt().unsqueeze(-1) * model_output) / alpha_prod_t.sqrt().unsqueeze(-1)
    old_pred_original_sample = (sample - beta_prod_t.sqrt().unsqueeze(-1) * old_model_output) / alpha_prod_t.sqrt().unsqueeze(-1)

    # 4. compute variance
    variance = scheduler._get_variance(timestep, prev_timestep)
    std_dev_t = eta * variance.sqrt()

    # 5. compute "direction pointing to x_t" of formula (12) from https://arxiv.org/pdf/2010.02502.pdf
    pred_sample_direction = (1 - alpha_prod_t_prev - std_dev_t**2).sqrt().unsqueeze(-1) * model_output
    old_pred_sample_direction = (1 - alpha_prod_t_prev - std_dev_t**2).sqrt().unsqueeze(-1) * old_model_output

    # 6. compute x_t without "random noise" of formula (12) from https://arxiv.org/pdf/2010.02502.pdf
    prev_sample_mean = alpha_prod_t_prev.sqrt().unsqueeze(-1) * pred_original_sample + pred_sample_direction
    old_prev_sample_mean = alpha_prod_t_prev.sqrt().unsqueeze(-1) * old_pred_original_sample + old_pred_sample_direction

    if eta > 0 and timestep[0] > 0:
        device = model_output.device
        noise = torch.randn(model_output.shape, generator=generator, device=device, dtype=model_output.dtype)
        variance = std_dev_t.unsqueeze(-1) * noise

        prev_sample = prev_sample_mean + variance
        # print((prev_sample_mean - old_prev_sample_mean))
        kl_terms = (prev_sample_mean - old_prev_sample_mean)**2 / (2 * (std_dev_t**2).unsqueeze(-1))
        kl_terms = kl_terms.sum(dim=-1)  # Sum over the 2D dimensions
        # print(kl_terms)
    else:
        prev_sample = prev_sample_mean
        kl_terms = torch.zeros(prev_sample_mean.size(0), device=prev_sample_mean.device)

    # 7. Compute log probability
    log_prob = _compute_gaussian_log_prob(prev_sample, prev_sample_mean, std_dev_t.unsqueeze(-1)).mean(-1)

    return prev_sample, log_prob, kl_terms

# %%
@torch.no_grad()
def ddim_sample(model, scheduler, n, device, eta=1.0):
    x = torch.randn((n, 2)).to(device)
    
    for i, t in enumerate(scheduler.timesteps):
        t_tensor = torch.full((n,), scheduler.timesteps[i], device=device) # torch.full((n,), t, device=device).long()
        model_output = model(x, t_tensor / scheduler.num_train_timesteps)
        x, _, _ = ddim_step_KL(scheduler, model_output, 0., t_tensor, x, eta)
    
    return x

# %% [markdown]
# ## Define Data Distribution (Mixture of Gaussians)

# %%
# Generate data from mixture of 2D Gaussians
def sample_gaussian_mixture(n_samples, means, covs):
    n_gaussians = len(means)
    samples = []
    for _ in range(n_samples):
        idx = np.random.randint(0, n_gaussians)
        sample = np.random.multivariate_normal(means[idx], covs[idx])
        samples.append(sample)
    return np.array(samples)

n_samples = 100000
# means = [(-2, -2), (2, 2), (-2, 2), (2, -2)]
means = [
    (-4, 0), (-2*math.sqrt(2), 2*math.sqrt(2)), (0, 4), (2*math.sqrt(2), 2*math.sqrt(2)),
    (4, 0), (2*math.sqrt(2), -2*math.sqrt(2)), (0, -4), (-2*math.sqrt(2), -2*math.sqrt(2)),
]
# means = [
#     (-6, 0), (-3*math.sqrt(3), 3), (-3, 3*math.sqrt(3)),
#     (0, 6), (3, 3*math.sqrt(3)), (3*math.sqrt(3), 3),
#     (6, 0), (3*math.sqrt(3), -3), (3, -3*math.sqrt(3)),
#     (0, -6), (-3, -3*math.sqrt(3)), (-3*math.sqrt(3), -3),
# ]
covs = [[[0.3, 0], [0, 0.3]] for _ in range(len(means))]
data = sample_gaussian_mixture(n_samples, means, covs)
data = torch.FloatTensor(data).to(device)

# %% [markdown]
# ## Pre-training

# %%
# Hyperparameters
num_train_timesteps = 1000

# Initialize scheduler
scheduler = DDIMScheduler(num_train_timesteps=num_train_timesteps, device=device)

# Initialize models and optimizer
pre_trained_model = SimpleUNet().to(device)
optimizer = optim.Adam(pre_trained_model.parameters(), lr=1e-3)

# %%
# Pre-training loop
epochs = 1000
for epoch in range(epochs):
    optimizer.zero_grad()
    t = torch.randint(0, num_train_timesteps, (n_samples,), device=device).long()
    noise = torch.randn_like(data)
    noisy_data = scheduler.alphas_cumprod[t].sqrt().unsqueeze(-1) * data + \
                 (1 - scheduler.alphas_cumprod[t]).sqrt().unsqueeze(-1) * noise
    predicted_noise = pre_trained_model(noisy_data, t.float() / num_train_timesteps)
    loss = F.mse_loss(predicted_noise, noise)
    loss.backward()
    optimizer.step()
    if epoch % 100 == 0:
        print(f"Pre-training Epoch {epoch}, Loss: {loss.item()}")
# Out:
# Pre-training Epoch 0, Loss: 1.0308789014816284
# Pre-training Epoch 100, Loss: 0.5676619410514832
# Pre-training Epoch 200, Loss: 0.44893917441368103
# Pre-training Epoch 300, Loss: 0.39812591671943665
# Pre-training Epoch 400, Loss: 0.38895663619041443
# Pre-training Epoch 500, Loss: 0.3808199465274811
# Pre-training Epoch 600, Loss: 0.38041260838508606
# Pre-training Epoch 700, Loss: 0.3808133602142334
# Pre-training Epoch 800, Loss: 0.37919092178344727
# Pre-training Epoch 900, Loss: 0.37822139263153076

# %%
# Set the number of inference steps before fine-tuning and sampling
num_inference_steps = 100
scheduler.set_timesteps(num_inference_steps)

# %% [markdown]
# ## Define Reward, KL penalty coefficient, and Corresponding Target Distribution

# %%
def compute_reward(x):
    if isinstance(x, torch.Tensor):
        x_squared = torch.clamp((x - torch.tensor([0, 1]).to(device))**2, max=10000)
        return - x_squared[:, 0] - x_squared[:, 1] / 10
    else:
        x_squared = (x - np.array([0, 1]))**2
        x_squared = np.where(x_squared > 10000, 10000, x_squared)
        return - x_squared[:, 0] - x_squared[:, 1] / 10

kl_weight = 1.

# %%
def gaussian_mixture_pdf(x, means, covs, weights=None):
    n_gaussians = len(means)
    if weights is None:
        weights = np.ones(n_gaussians) / n_gaussians
    
    pdf = np.zeros(x.shape[0])
    for mean, cov, weight in zip(means, covs, weights):
        pdf += weight * multivariate_normal.pdf(x, mean=mean, cov=cov)
    
    return pdf

def target_distribution_pdf(x, means, covs, kl_weight):
    gmm_pdf = gaussian_mixture_pdf(x, means, covs)
    reward = compute_reward(x)
    return gmm_pdf * np.exp(reward / kl_weight)

# Generate target distribution samples
def sample_target_distribution(n_samples, means, covs, kl_weight):
    samples = []
    weights = []
    x_range = np.linspace(-8, 8, 1000)
    y_range = np.linspace(-8, 8, 1000)
    xx, yy = np.meshgrid(x_range, y_range)
    grid_points = np.column_stack([xx.ravel(), yy.ravel()])
    
    pdf_values = target_distribution_pdf(grid_points, means, covs, kl_weight)
    pdf_values /= np.sum(pdf_values)
    
    indices = np.random.choice(len(grid_points), size=n_samples, p=pdf_values)
    samples = grid_points[indices]
    
    return samples

target_samples = sample_target_distribution(10000, means, covs, kl_weight)

target_reward = compute_reward(target_samples).mean()
print(target_reward)
# Out:
# -1.336566092739386

# %%
# Generate pre-trained samples
pre_trained_samples = ddim_sample(pre_trained_model, scheduler, 10000, device)
pre_trained_reward = compute_reward(pre_trained_samples).mean().item()
pre_trained_samples = pre_trained_samples.cpu().numpy()

# %% [markdown]
# ## RL fine-tuning with KL regularization

# %%
class DDPO:
    def __init__(self, model, scheduler, config):
        self.model = model
        self.scheduler = scheduler
        self.config = config
        self.optimizer = optim.Adam(self.model.parameters(), lr=config.learning_rate)

    def train_step(self, old_log_probs, states, actions, advantages):
        for _ in range(self.config.ppo_epochs):
            for batch in self.get_batches(old_log_probs, states, actions, advantages):
                batch_old_log_probs, batch_states, batch_actions, batch_advantages = batch
                self.optimizer.zero_grad()
                total_loss = 0

                for j in range(self.scheduler.num_inference_steps - 1):
                    t_tensor = torch.full((batch_states.shape[0],), self.scheduler.timesteps[j], device=batch_states.device)
                    
                    # Compute model output
                    model_output = self.model(batch_states[:, j], t_tensor.float() / self.scheduler.num_train_timesteps)
                    
                    _, log_probs = ddim_step_with_logprob(
                        self.scheduler, 
                        model_output, 
                        t_tensor, 
                        batch_states[:, j], 
                        eta=self.config.eta,
                        prev_sample=batch_actions[:, j]
                    )
                    if torch.isnan(log_probs).any() or torch.isnan(batch_old_log_probs[:, j]).any():
                        print(j)
                        print(t_tensor[0])
                        print(log_probs)
                        print(batch_old_log_probs[:, j])
                        raise e

                    # Compute loss
                    ratio = torch.exp(log_probs - batch_old_log_probs[:, j])
                    # print(ratio)
                    unclipped_loss = - ratio * batch_advantages[:, j]
                    clipped_loss = - torch.clamp(ratio, 1.0 - self.config.clip_range, 1.0 + self.config.clip_range) * batch_advantages[:, j]
                    loss = torch.max(unclipped_loss, clipped_loss).mean()
                    # print(unclipped_loss)
                    # print(clipped_loss)
                    # print(loss)
                    # total_loss += loss

                    loss.backward()
                    # Clip gradients and perform optimization step
                    nn.utils.clip_grad_norm_(self.model.parameters(), self.config.max_grad_norm)
                    # Calculate mean and max of the gradients
                    total_norm = 0.0
                    num_params = 0
                    max_grad = 0.0
                    grad_sum = 0.0
                    norm_sum = 0.0
                    for param in self.model.parameters():
                        if param.grad is not None:
                            grad_norm = param.grad.data.norm(2)  # L2 norm of the gradients
                            grad_sum += grad_norm.item()
                            max_grad = max(max_grad, grad_norm.item())
                            norm_sum += param.data.norm(2).item()
                            num_params += 1
                    # print(f"Mean gradient norm: {grad_sum / num_params}, Max gradient norm: {max_grad}")
                    # print(f"Mean parameter norm: {norm_sum / num_params}")

                    self.optimizer.step()
                    self.optimizer.zero_grad()
                # total_loss.backward()
                # optimizer.step()
                # optimizer.zero_grad()

    def get_batches(self, old_log_probs, states, actions, advantages):
        batch_size = self.config.batch_size
        indices = np.random.permutation(old_log_probs.shape[0])
        for start_idx in range(0, old_log_probs.shape[0], batch_size):
            end_idx = start_idx + batch_size
            batch_indices = indices[start_idx:end_idx]
            yield (old_log_probs[batch_indices], states[batch_indices],
                   actions[batch_indices], advantages[batch_indices])

    def fine_tune(self, reward_fn, num_epochs, samples_per_epoch, device):
        for epoch in range(num_epochs):
            # Sample trajectories
            with torch.no_grad():
                latents, old_log_probs, kl_divs = self.sample_trajectories(samples_per_epoch, device)

                # Compute rewards
                rewards = reward_fn(latents[:, -1])

            states = latents[:, :-1]
            actions = latents[:, 1:]

            # Compute advantages using the original DDPO method
            advantages = ((rewards - rewards.mean()) / (rewards.std() + 1e-8)).repeat(self.scheduler.num_inference_steps, 1).transpose(0, 1) + self.config.kl_weight * kl_divs

            # Update policy
            self.train_step(old_log_probs, states, actions, advantages)

            # Log progress
            print(f"Epoch {epoch + 1}/{num_epochs}, Mean Reward: {rewards.mean().item():.4f}, Mean KL Div: {kl_divs.sum(dim=1).mean().item():.4f}")

    def sample_trajectories(self, num_samples, device):
        latents = torch.randn((num_samples, 2)).to(device)
        all_latents = [latents]
        all_log_probs = []
        all_kl_divs = []

        # Assuming states is of shape (num_samples, 2)
        for i, t in enumerate(self.scheduler.timesteps):
            t_tensor = torch.full((num_samples,), self.scheduler.timesteps[i], device=device)
            model_output = self.model(latents, t_tensor / self.scheduler.num_train_timesteps)
            with torch.no_grad():
                pre_trained_model_output = pre_trained_model(latents, t_tensor / self.scheduler.num_train_timesteps)
            latents, log_prob, kl_div = ddim_step_KL(self.scheduler, model_output, pre_trained_model_output, t_tensor, latents, eta=self.config.eta)
            
            all_latents.append(latents)
            all_log_probs.append(log_prob)
            all_kl_divs.append(kl_div)

        return torch.stack(all_latents, dim=1), torch.stack(all_log_probs, dim=1), torch.stack(all_kl_divs, dim=1)

# %% [markdown]
# ### RL training

# %%
# Hyperparameters
config = SimpleNamespace(
    learning_rate=1e-4,
    eta=1.0,
    clip_range=1e-4,
    ppo_epochs=1,
    batch_size=256,
    max_grad_norm=1.,
    kl_weight=1.
)

# Copy pre-trained weights to fine-tune model
rl_model = copy.deepcopy(pre_trained_model).to(device)

# Initialize DDPO for fine-tuning
ddpo = DDPO(rl_model, scheduler, config)

# Fine-tune with DDPO
rl_epochs = 1000
samples_per_epoch = 256
ddpo.fine_tune(compute_reward, rl_epochs, samples_per_epoch, device)
# Out:
# Epoch 1/1000, Mean Reward: -9.3920, Mean KL Div: 0.0000
# Epoch 2/1000, Mean Reward: -9.2085, Mean KL Div: 0.0006
# Epoch 3/1000, Mean Reward: -9.3149, Mean KL Div: 0.0012
# Epoch 4/1000, Mean Reward: -9.3700, Mean KL Div: 0.0024
# Epoch 5/1000, Mean Reward: -9.6546, Mean KL Div: 0.0052
# Epoch 6/1000, Mean Reward: -9.3323, Mean KL Div: 0.0078
# Epoch 7/1000, Mean Reward: -8.6478, Mean KL Div: 0.0065
# Epoch 8/1000, Mean Reward: -9.7782, Mean KL Div: 0.0117
# Epoch 9/1000, Mean Reward: -9.3227, Mean KL Div: 0.0144
# Epoch 10/1000, Mean Reward: -9.4669, Mean KL Div: 0.0166
# Epoch 11/1000, Mean Reward: -9.3909, Mean KL Div: 0.0156
# Epoch 12/1000, Mean Reward: -9.0211, Mean KL Div: 0.0151
# Epoch 13/1000, Mean Reward: -8.8485, Mean KL Div: 0.0148
# Epoch 14/1000, Mean Reward: -8.9800, Mean KL Div: 0.0189
# Epoch 15/1000, Mean Reward: -8.8295, Mean KL Div: 0.0127
# Epoch 16/1000, Mean Reward: -9.0144, Mean KL Div: 0.0150
# Epoch 17/1000, Mean Reward: -8.9095, Mean KL Div: 0.0137
# Epoch 18/1000, Mean Reward: -8.9381, Mean KL Div: 0.0168
# Epoch 19/1000, Mean Reward: -9.6344, Mean KL Div: 0.0209
# Epoch 20/1000, Mean Reward: -9.0847, Mean KL Div: 0.0178
# Epoch 21/1000, Mean Reward: -9.3763, Mean KL Div: 0.0213
# Epoch 22/1000, Mean Reward: -8.8190, Mean KL Div: 0.0257
# Epoch 23/1000, Mean Reward: -9.2400, Mean KL Div: 0.0373
# Epoch 24/1000, Mean Reward: -9.3741, Mean KL Div: 0.0316
# Epoch 25/1000, Mean Reward: -9.1527, Mean KL Div: 0.0317
# Epoch 26/1000, Mean Reward: -9.7181, Mean KL Div: 0.0359
# Epoch 27/1000, Mean Reward: -8.9653, Mean KL Div: 0.0331
# Epoch 28/1000, Mean Reward: -9.2861, Mean KL Div: 0.0302
# Epoch 29/1000, Mean Reward: -9.1759, Mean KL Div: 0.0396
# Epoch 30/1000, Mean Reward: -9.0891, Mean KL Div: 0.0342
# Epoch 31/1000, Mean Reward: -9.2066, Mean KL Div: 0.0444
# Epoch 32/1000, Mean Reward: -9.2203, Mean KL Div: 0.0413
# Epoch 33/1000, Mean Reward: -9.2258, Mean KL Div: 0.0486
# Epoch 34/1000, Mean Reward: -8.6458, Mean KL Div: 0.0412
# Epoch 35/1000, Mean Reward: -9.3226, Mean KL Div: 0.0394
# Epoch 36/1000, Mean Reward: -9.5681, Mean KL Div: 0.0466
# Epoch 37/1000, Mean Reward: -8.3210, Mean KL Div: 0.0365
# Epoch 38/1000, Mean Reward: -9.1878, Mean KL Div: 0.0377
# Epoch 39/1000, Mean Reward: -9.0317, Mean KL Div: 0.0299
# Epoch 40/1000, Mean Reward: -9.5565, Mean KL Div: 0.0362
# Epoch 41/1000, Mean Reward: -8.4863, Mean KL Div: 0.0291
# Epoch 42/1000, Mean Reward: -8.5945, Mean KL Div: 0.0333
# Epoch 43/1000, Mean Reward: -9.3576, Mean KL Div: 0.0377
# Epoch 44/1000, Mean Reward: -8.4246, Mean KL Div: 0.0379
# Epoch 45/1000, Mean Reward: -9.1860, Mean KL Div: 0.0447
# Epoch 46/1000, Mean Reward: -8.0161, Mean KL Div: 0.0352
# Epoch 47/1000, Mean Reward: -8.6975, Mean KL Div: 0.0419
# Epoch 48/1000, Mean Reward: -8.5223, Mean KL Div: 0.0453
# Epoch 49/1000, Mean Reward: -9.3989, Mean KL Div: 0.0543
# Epoch 50/1000, Mean Reward: -8.4738, Mean KL Div: 0.0554
# Epoch 51/1000, Mean Reward: -8.5773, Mean KL Div: 0.0518
# Epoch 52/1000, Mean Reward: -8.3702, Mean KL Div: 0.0492
# Epoch 53/1000, Mean Reward: -8.6324, Mean KL Div: 0.0591
# Epoch 54/1000, Mean Reward: -8.8797, Mean KL Div: 0.0541
# Epoch 55/1000, Mean Reward: -9.1414, Mean KL Div: 0.0612
# Epoch 56/1000, Mean Reward: -9.1498, Mean KL Div: 0.0593
# Epoch 57/1000, Mean Reward: -9.0109, Mean KL Div: 0.0603
# Epoch 58/1000, Mean Reward: -8.6231, Mean KL Div: 0.0581
# Epoch 59/1000, Mean Reward: -8.6307, Mean KL Div: 0.0606
# Epoch 60/1000, Mean Reward: -8.8740, Mean KL Div: 0.0661
# Epoch 61/1000, Mean Reward: -8.7446, Mean KL Div: 0.0715
# Epoch 62/1000, Mean Reward: -8.9237, Mean KL Div: 0.0794
# Epoch 63/1000, Mean Reward: -8.7722, Mean KL Div: 0.0720
# Epoch 64/1000, Mean Reward: -8.6666, Mean KL Div: 0.0747
# Epoch 65/1000, Mean Reward: -8.5265, Mean KL Div: 0.0730
# Epoch 66/1000, Mean Reward: -8.4922, Mean KL Div: 0.0782
# Epoch 67/1000, Mean Reward: -8.2328, Mean KL Div: 0.0800
# Epoch 68/1000, Mean Reward: -8.4897, Mean KL Div: 0.0695
# Epoch 69/1000, Mean Reward: -8.4116, Mean KL Div: 0.0663
# Epoch 70/1000, Mean Reward: -8.7839, Mean KL Div: 0.0702
# Epoch 71/1000, Mean Reward: -8.4992, Mean KL Div: 0.0720
# Epoch 72/1000, Mean Reward: -8.1360, Mean KL Div: 0.0726
# Epoch 73/1000, Mean Reward: -8.5921, Mean KL Div: 0.0765
# Epoch 74/1000, Mean Reward: -8.4494, Mean KL Div: 0.0761
# Epoch 75/1000, Mean Reward: -8.1973, Mean KL Div: 0.0768
# Epoch 76/1000, Mean Reward: -8.8951, Mean KL Div: 0.0822
# Epoch 77/1000, Mean Reward: -8.7636, Mean KL Div: 0.0791
# Epoch 78/1000, Mean Reward: -8.5306, Mean KL Div: 0.0749
# Epoch 79/1000, Mean Reward: -8.7660, Mean KL Div: 0.0753
# Epoch 80/1000, Mean Reward: -8.6115, Mean KL Div: 0.0776
# Epoch 81/1000, Mean Reward: -8.2202, Mean KL Div: 0.0778
# Epoch 82/1000, Mean Reward: -8.3857, Mean KL Div: 0.0809
# Epoch 83/1000, Mean Reward: -8.6692, Mean KL Div: 0.0834
# Epoch 84/1000, Mean Reward: -8.0994, Mean KL Div: 0.0889
# Epoch 85/1000, Mean Reward: -8.7444, Mean KL Div: 0.0952
# Epoch 86/1000, Mean Reward: -8.2948, Mean KL Div: 0.0941
# Epoch 87/1000, Mean Reward: -8.6691, Mean KL Div: 0.1021
# Epoch 88/1000, Mean Reward: -8.8019, Mean KL Div: 0.1075
# Epoch 89/1000, Mean Reward: -8.8910, Mean KL Div: 0.1098
# Epoch 90/1000, Mean Reward: -8.5775, Mean KL Div: 0.1098
# Epoch 91/1000, Mean Reward: -8.4492, Mean KL Div: 0.1302
# Epoch 92/1000, Mean Reward: -8.0132, Mean KL Div: 0.1369
# Epoch 93/1000, Mean Reward: -8.8419, Mean KL Div: 0.1333
# Epoch 94/1000, Mean Reward: -8.0054, Mean KL Div: 0.1400
# Epoch 95/1000, Mean Reward: -8.5145, Mean KL Div: 0.1399
# Epoch 96/1000, Mean Reward: -9.1437, Mean KL Div: 0.1638
# Epoch 97/1000, Mean Reward: -8.4278, Mean KL Div: 0.1630
# Epoch 98/1000, Mean Reward: -8.2149, Mean KL Div: 0.1648
# Epoch 99/1000, Mean Reward: -8.5975, Mean KL Div: 0.1553
# Epoch 100/1000, Mean Reward: -8.0532, Mean KL Div: 0.1598
# Epoch 101/1000, Mean Reward: -8.8664, Mean KL Div: 0.1744
# Epoch 102/1000, Mean Reward: -8.6847, Mean KL Div: 0.1823
# Epoch 103/1000, Mean Reward: -8.4868, Mean KL Div: 0.1840
# Epoch 104/1000, Mean Reward: -8.5217, Mean KL Div: 0.1710
# Epoch 105/1000, Mean Reward: -8.4446, Mean KL Div: 0.1850
# Epoch 106/1000, Mean Reward: -8.7548, Mean KL Div: 0.1844
# Epoch 107/1000, Mean Reward: -8.3044, Mean KL Div: 0.1858
# Epoch 108/1000, Mean Reward: -7.9320, Mean KL Div: 0.1706
# Epoch 109/1000, Mean Reward: -8.0935, Mean KL Div: 0.2035
# Epoch 110/1000, Mean Reward: -8.3898, Mean KL Div: 0.1832
# Epoch 111/1000, Mean Reward: -7.4166, Mean KL Div: 0.1979
# Epoch 112/1000, Mean Reward: -8.3470, Mean KL Div: 0.2137
# Epoch 113/1000, Mean Reward: -8.0533, Mean KL Div: 0.2126
# Epoch 114/1000, Mean Reward: -8.4069, Mean KL Div: 0.2016
# Epoch 115/1000, Mean Reward: -8.3057, Mean KL Div: 0.2213
# Epoch 116/1000, Mean Reward: -7.8012, Mean KL Div: 0.2094
# Epoch 117/1000, Mean Reward: -8.5196, Mean KL Div: 0.2056
# Epoch 118/1000, Mean Reward: -8.1043, Mean KL Div: 0.2158
# Epoch 119/1000, Mean Reward: -8.2097, Mean KL Div: 0.2062
# Epoch 120/1000, Mean Reward: -8.0559, Mean KL Div: 0.2101
# Epoch 121/1000, Mean Reward: -8.3656, Mean KL Div: 0.2189
# Epoch 122/1000, Mean Reward: -9.0176, Mean KL Div: 0.2209
# Epoch 123/1000, Mean Reward: -8.1846, Mean KL Div: 0.2319
# Epoch 124/1000, Mean Reward: -8.4928, Mean KL Div: 0.2551
# Epoch 125/1000, Mean Reward: -8.3382, Mean KL Div: 0.2595
# Epoch 126/1000, Mean Reward: -8.4849, Mean KL Div: 0.2431
# Epoch 127/1000, Mean Reward: -7.9344, Mean KL Div: 0.2684
# Epoch 128/1000, Mean Reward: -8.1953, Mean KL Div: 0.2593
# Epoch 129/1000, Mean Reward: -7.6721, Mean KL Div: 0.2895
# Epoch 130/1000, Mean Reward: -7.9708, Mean KL Div: 0.2643
# Epoch 131/1000, Mean Reward: -8.0719, Mean KL Div: 0.3030
# Epoch 132/1000, Mean Reward: -7.8726, Mean KL Div: 0.2809
# Epoch 133/1000, Mean Reward: -8.2815, Mean KL Div: 0.2713
# Epoch 134/1000, Mean Reward: -7.5069, Mean KL Div: 0.2935
# Epoch 135/1000, Mean Reward: -7.4126, Mean KL Div: 0.3046
# Epoch 136/1000, Mean Reward: -8.1003, Mean KL Div: 0.3139
# Epoch 137/1000, Mean Reward: -7.5988, Mean KL Div: 0.3089
# Epoch 138/1000, Mean Reward: -7.5812, Mean KL Div: 0.2889
# Epoch 139/1000, Mean Reward: -7.6127, Mean KL Div: 0.2898
# Epoch 140/1000, Mean Reward: -8.1765, Mean KL Div: 0.2739
# Epoch 141/1000, Mean Reward: -7.9771, Mean KL Div: 0.3022
# Epoch 142/1000, Mean Reward: -8.8619, Mean KL Div: 0.2977
# Epoch 143/1000, Mean Reward: -7.4988, Mean KL Div: 0.2864
# Epoch 144/1000, Mean Reward: -6.8697, Mean KL Div: 0.2894
# Epoch 145/1000, Mean Reward: -7.9548, Mean KL Div: 0.2938
# Epoch 146/1000, Mean Reward: -7.6841, Mean KL Div: 0.2840
# Epoch 147/1000, Mean Reward: -7.7872, Mean KL Div: 0.2927
# Epoch 148/1000, Mean Reward: -7.3227, Mean KL Div: 0.2824
# Epoch 149/1000, Mean Reward: -7.6074, Mean KL Div: 0.2832
# Epoch 150/1000, Mean Reward: -7.8126, Mean KL Div: 0.2871
# Epoch 151/1000, Mean Reward: -8.5430, Mean KL Div: 0.3026
# Epoch 152/1000, Mean Reward: -7.2340, Mean KL Div: 0.3086
# Epoch 153/1000, Mean Reward: -8.4160, Mean KL Div: 0.3218
# Epoch 154/1000, Mean Reward: -8.0473, Mean KL Div: 0.3192
# Epoch 155/1000, Mean Reward: -7.5984, Mean KL Div: 0.3485
# Epoch 156/1000, Mean Reward: -7.1303, Mean KL Div: 0.3127
# Epoch 157/1000, Mean Reward: -7.6171, Mean KL Div: 0.3271
# Epoch 158/1000, Mean Reward: -8.0313, Mean KL Div: 0.3500
# Epoch 159/1000, Mean Reward: -7.9556, Mean KL Div: 0.3525
# Epoch 160/1000, Mean Reward: -7.4296, Mean KL Div: 0.3645
# Epoch 161/1000, Mean Reward: -7.3697, Mean KL Div: 0.3573
# Epoch 162/1000, Mean Reward: -7.3570, Mean KL Div: 0.3818
# Epoch 163/1000, Mean Reward: -7.7091, Mean KL Div: 0.3448
# Epoch 164/1000, Mean Reward: -6.8764, Mean KL Div: 0.3383
# Epoch 165/1000, Mean Reward: -7.9118, Mean KL Div: 0.3963
# Epoch 166/1000, Mean Reward: -7.6397, Mean KL Div: 0.3462
# Epoch 167/1000, Mean Reward: -7.5168, Mean KL Div: 0.3564
# Epoch 168/1000, Mean Reward: -7.6684, Mean KL Div: 0.3855
# Epoch 169/1000, Mean Reward: -8.0909, Mean KL Div: 0.4014
# Epoch 170/1000, Mean Reward: -6.9408, Mean KL Div: 0.3877
# Epoch 171/1000, Mean Reward: -7.2764, Mean KL Div: 0.3627
# Epoch 172/1000, Mean Reward: -7.1171, Mean KL Div: 0.3615
# Epoch 173/1000, Mean Reward: -7.3993, Mean KL Div: 0.3725
# Epoch 174/1000, Mean Reward: -7.7186, Mean KL Div: 0.3830
# Epoch 175/1000, Mean Reward: -6.7038, Mean KL Div: 0.4241
# Epoch 176/1000, Mean Reward: -7.3026, Mean KL Div: 0.4149
# Epoch 177/1000, Mean Reward: -7.7734, Mean KL Div: 0.4139
# Epoch 178/1000, Mean Reward: -7.6295, Mean KL Div: 0.4080
# Epoch 179/1000, Mean Reward: -6.8028, Mean KL Div: 0.3877
# Epoch 180/1000, Mean Reward: -6.7814, Mean KL Div: 0.4065
# Epoch 181/1000, Mean Reward: -6.8154, Mean KL Div: 0.4451
# Epoch 182/1000, Mean Reward: -6.6740, Mean KL Div: 0.4331
# Epoch 183/1000, Mean Reward: -7.1509, Mean KL Div: 0.4500
# Epoch 184/1000, Mean Reward: -6.7941, Mean KL Div: 0.4784
# Epoch 185/1000, Mean Reward: -6.9198, Mean KL Div: 0.4656
# Epoch 186/1000, Mean Reward: -6.9167, Mean KL Div: 0.4559
# Epoch 187/1000, Mean Reward: -6.6085, Mean KL Div: 0.4701
# Epoch 188/1000, Mean Reward: -7.7506, Mean KL Div: 0.5095
# Epoch 189/1000, Mean Reward: -7.0398, Mean KL Div: 0.5326
# Epoch 190/1000, Mean Reward: -6.7348, Mean KL Div: 0.4948
# Epoch 191/1000, Mean Reward: -7.6131, Mean KL Div: 0.5357
# Epoch 192/1000, Mean Reward: -7.8105, Mean KL Div: 0.5190
# Epoch 193/1000, Mean Reward: -7.2630, Mean KL Div: 0.5109
# Epoch 194/1000, Mean Reward: -6.4616, Mean KL Div: 0.5098
# Epoch 195/1000, Mean Reward: -6.3964, Mean KL Div: 0.4926
# Epoch 196/1000, Mean Reward: -7.2395, Mean KL Div: 0.4836
# Epoch 197/1000, Mean Reward: -7.0446, Mean KL Div: 0.4705
# Epoch 198/1000, Mean Reward: -7.3596, Mean KL Div: 0.5181
# Epoch 199/1000, Mean Reward: -6.9581, Mean KL Div: 0.4669
# Epoch 200/1000, Mean Reward: -6.8947, Mean KL Div: 0.4681
# Epoch 201/1000, Mean Reward: -6.9334, Mean KL Div: 0.4608
# Epoch 202/1000, Mean Reward: -7.2494, Mean KL Div: 0.4638
# Epoch 203/1000, Mean Reward: -7.0929, Mean KL Div: 0.4911
# Epoch 204/1000, Mean Reward: -6.8968, Mean KL Div: 0.4921
# Epoch 205/1000, Mean Reward: -7.2013, Mean KL Div: 0.4741
# Epoch 206/1000, Mean Reward: -6.9421, Mean KL Div: 0.5137
# Epoch 207/1000, Mean Reward: -6.4030, Mean KL Div: 0.4700
# Epoch 208/1000, Mean Reward: -6.3728, Mean KL Div: 0.5055
# Epoch 209/1000, Mean Reward: -6.3028, Mean KL Div: 0.5364
# Epoch 210/1000, Mean Reward: -6.8186, Mean KL Div: 0.5576
# Epoch 211/1000, Mean Reward: -7.3186, Mean KL Div: 0.5444
# Epoch 212/1000, Mean Reward: -6.4871, Mean KL Div: 0.5143
# Epoch 213/1000, Mean Reward: -6.8056, Mean KL Div: 0.5055
# Epoch 214/1000, Mean Reward: -6.2142, Mean KL Div: 0.5190
# Epoch 215/1000, Mean Reward: -6.7283, Mean KL Div: 0.5288
# Epoch 216/1000, Mean Reward: -6.7760, Mean KL Div: 0.5508
# Epoch 217/1000, Mean Reward: -7.2083, Mean KL Div: 0.5674
# Epoch 218/1000, Mean Reward: -6.5661, Mean KL Div: 0.5438
# Epoch 219/1000, Mean Reward: -6.1158, Mean KL Div: 0.5280
# Epoch 220/1000, Mean Reward: -6.6578, Mean KL Div: 0.5480
# Epoch 221/1000, Mean Reward: -6.3456, Mean KL Div: 0.5098
# Epoch 222/1000, Mean Reward: -6.9159, Mean KL Div: 0.5126
# Epoch 223/1000, Mean Reward: -6.7594, Mean KL Div: 0.5502
# Epoch 224/1000, Mean Reward: -6.9224, Mean KL Div: 0.5289
# Epoch 225/1000, Mean Reward: -6.7252, Mean KL Div: 0.5463
# Epoch 226/1000, Mean Reward: -6.9212, Mean KL Div: 0.5430
# Epoch 227/1000, Mean Reward: -6.5336, Mean KL Div: 0.5953
# Epoch 228/1000, Mean Reward: -6.6636, Mean KL Div: 0.5803
# Epoch 229/1000, Mean Reward: -6.0097, Mean KL Div: 0.5519
# Epoch 230/1000, Mean Reward: -6.4445, Mean KL Div: 0.5701
# Epoch 231/1000, Mean Reward: -7.0857, Mean KL Div: 0.6332
# Epoch 232/1000, Mean Reward: -6.6695, Mean KL Div: 0.5972
# Epoch 233/1000, Mean Reward: -6.2074, Mean KL Div: 0.6035
# Epoch 234/1000, Mean Reward: -7.0357, Mean KL Div: 0.6719
# Epoch 235/1000, Mean Reward: -6.8934, Mean KL Div: 0.6168
# Epoch 236/1000, Mean Reward: -6.8979, Mean KL Div: 0.6511
# Epoch 237/1000, Mean Reward: -6.6180, Mean KL Div: 0.6879
# Epoch 238/1000, Mean Reward: -6.4176, Mean KL Div: 0.7047
# Epoch 239/1000, Mean Reward: -5.9244, Mean KL Div: 0.6995
# Epoch 240/1000, Mean Reward: -6.5614, Mean KL Div: 0.7509
# Epoch 241/1000, Mean Reward: -6.0905, Mean KL Div: 0.6750
# Epoch 242/1000, Mean Reward: -6.6161, Mean KL Div: 0.7672
# Epoch 243/1000, Mean Reward: -6.1088, Mean KL Div: 0.7445
# Epoch 244/1000, Mean Reward: -5.7555, Mean KL Div: 0.7330
# Epoch 245/1000, Mean Reward: -6.2266, Mean KL Div: 0.7585
# Epoch 246/1000, Mean Reward: -6.6129, Mean KL Div: 0.7577
# Epoch 247/1000, Mean Reward: -6.4911, Mean KL Div: 0.7503
# Epoch 248/1000, Mean Reward: -6.5100, Mean KL Div: 0.7491
# Epoch 249/1000, Mean Reward: -5.8990, Mean KL Div: 0.7836
# Epoch 250/1000, Mean Reward: -5.6535, Mean KL Div: 0.7590
# Epoch 251/1000, Mean Reward: -5.9909, Mean KL Div: 0.7335
# Epoch 252/1000, Mean Reward: -5.7160, Mean KL Div: 0.7388
# Epoch 253/1000, Mean Reward: -6.7139, Mean KL Div: 0.7676
# Epoch 254/1000, Mean Reward: -6.2420, Mean KL Div: 0.7741
# Epoch 255/1000, Mean Reward: -6.0615, Mean KL Div: 0.7478
# Epoch 256/1000, Mean Reward: -5.8726, Mean KL Div: 0.8185
# Epoch 257/1000, Mean Reward: -6.4634, Mean KL Div: 0.7848
# Epoch 258/1000, Mean Reward: -6.3457, Mean KL Div: 0.7833
# Epoch 259/1000, Mean Reward: -5.9559, Mean KL Div: 0.8085
# Epoch 260/1000, Mean Reward: -5.2561, Mean KL Div: 0.7946
# Epoch 261/1000, Mean Reward: -5.6461, Mean KL Div: 0.7640
# Epoch 262/1000, Mean Reward: -5.9314, Mean KL Div: 0.8785
# Epoch 263/1000, Mean Reward: -6.2360, Mean KL Div: 0.8457
# Epoch 264/1000, Mean Reward: -5.7425, Mean KL Div: 0.8068
# Epoch 265/1000, Mean Reward: -6.4499, Mean KL Div: 0.8045
# Epoch 266/1000, Mean Reward: -5.6235, Mean KL Div: 0.7941
# Epoch 267/1000, Mean Reward: -6.0391, Mean KL Div: 0.8107
# Epoch 268/1000, Mean Reward: -5.7630, Mean KL Div: 0.8320
# Epoch 269/1000, Mean Reward: -5.3560, Mean KL Div: 0.8193
# Epoch 270/1000, Mean Reward: -6.1823, Mean KL Div: 0.8681
# Epoch 271/1000, Mean Reward: -5.9029, Mean KL Div: 0.8393
# Epoch 272/1000, Mean Reward: -5.5028, Mean KL Div: 0.8463
# Epoch 273/1000, Mean Reward: -5.1279, Mean KL Div: 0.7946
# Epoch 274/1000, Mean Reward: -5.4944, Mean KL Div: 0.8541
# Epoch 275/1000, Mean Reward: -5.8699, Mean KL Div: 0.8902
# Epoch 276/1000, Mean Reward: -5.7298, Mean KL Div: 0.9033
# Epoch 277/1000, Mean Reward: -5.6048, Mean KL Div: 0.8545
# Epoch 278/1000, Mean Reward: -5.3907, Mean KL Div: 0.8396
# Epoch 279/1000, Mean Reward: -5.4927, Mean KL Div: 0.9469
# Epoch 280/1000, Mean Reward: -5.5806, Mean KL Div: 0.9059
# Epoch 281/1000, Mean Reward: -5.3292, Mean KL Div: 0.9486
# Epoch 282/1000, Mean Reward: -5.3868, Mean KL Div: 0.9276
# Epoch 283/1000, Mean Reward: -5.5343, Mean KL Div: 0.8824
# Epoch 284/1000, Mean Reward: -5.6446, Mean KL Div: 0.8946
# Epoch 285/1000, Mean Reward: -5.7577, Mean KL Div: 0.9451
# Epoch 286/1000, Mean Reward: -6.1598, Mean KL Div: 0.9376
# Epoch 287/1000, Mean Reward: -4.9807, Mean KL Div: 0.8656
# Epoch 288/1000, Mean Reward: -5.6344, Mean KL Div: 0.9555
# Epoch 289/1000, Mean Reward: -5.5206, Mean KL Div: 0.8557
# Epoch 290/1000, Mean Reward: -5.7377, Mean KL Div: 0.9309
# Epoch 291/1000, Mean Reward: -5.3136, Mean KL Div: 0.9021
# Epoch 292/1000, Mean Reward: -5.4807, Mean KL Div: 0.9662
# Epoch 293/1000, Mean Reward: -5.2459, Mean KL Div: 0.9518
# Epoch 294/1000, Mean Reward: -5.4530, Mean KL Div: 0.9692
# Epoch 295/1000, Mean Reward: -4.7482, Mean KL Div: 0.9484
# Epoch 296/1000, Mean Reward: -5.6735, Mean KL Div: 0.9528
# Epoch 297/1000, Mean Reward: -4.9405, Mean KL Div: 0.9140
# Epoch 298/1000, Mean Reward: -4.7763, Mean KL Div: 0.8850
# Epoch 299/1000, Mean Reward: -4.9647, Mean KL Div: 0.9073
# Epoch 300/1000, Mean Reward: -5.0747, Mean KL Div: 0.9462
# Epoch 301/1000, Mean Reward: -5.1636, Mean KL Div: 1.0414
# Epoch 302/1000, Mean Reward: -5.2035, Mean KL Div: 0.9676
# Epoch 303/1000, Mean Reward: -5.7113, Mean KL Div: 0.9936
# Epoch 304/1000, Mean Reward: -5.3026, Mean KL Div: 0.9629
# Epoch 305/1000, Mean Reward: -5.2700, Mean KL Div: 1.0481
# Epoch 306/1000, Mean Reward: -5.0423, Mean KL Div: 1.0396
# Epoch 307/1000, Mean Reward: -5.3972, Mean KL Div: 1.0238
# Epoch 308/1000, Mean Reward: -5.4759, Mean KL Div: 1.0874
# Epoch 309/1000, Mean Reward: -5.2376, Mean KL Div: 1.0695
# Epoch 310/1000, Mean Reward: -4.8739, Mean KL Div: 0.9967
# Epoch 311/1000, Mean Reward: -5.2539, Mean KL Div: 0.9839
# Epoch 312/1000, Mean Reward: -5.3878, Mean KL Div: 1.0365
# Epoch 313/1000, Mean Reward: -4.7940, Mean KL Div: 1.0616
# Epoch 314/1000, Mean Reward: -5.1242, Mean KL Div: 0.9958
# Epoch 315/1000, Mean Reward: -5.4312, Mean KL Div: 1.0193
# Epoch 316/1000, Mean Reward: -5.3835, Mean KL Div: 0.9956
# Epoch 317/1000, Mean Reward: -5.2059, Mean KL Div: 1.0714
# Epoch 318/1000, Mean Reward: -4.8679, Mean KL Div: 0.9757
# Epoch 319/1000, Mean Reward: -4.9294, Mean KL Div: 0.9301
# Epoch 320/1000, Mean Reward: -4.9973, Mean KL Div: 1.0128
# Epoch 321/1000, Mean Reward: -5.3042, Mean KL Div: 1.0875
# Epoch 322/1000, Mean Reward: -5.4869, Mean KL Div: 1.0020
# Epoch 323/1000, Mean Reward: -5.6104, Mean KL Div: 1.0777
# Epoch 324/1000, Mean Reward: -5.2229, Mean KL Div: 1.1189
# Epoch 325/1000, Mean Reward: -4.9198, Mean KL Div: 1.0921
# Epoch 326/1000, Mean Reward: -5.0002, Mean KL Div: 1.0684
# Epoch 327/1000, Mean Reward: -5.2150, Mean KL Div: 1.1790
# Epoch 328/1000, Mean Reward: -5.4785, Mean KL Div: 1.1199
# Epoch 329/1000, Mean Reward: -5.7798, Mean KL Div: 1.1650
# Epoch 330/1000, Mean Reward: -5.1322, Mean KL Div: 1.2355
# Epoch 331/1000, Mean Reward: -5.0360, Mean KL Div: 1.1869
# Epoch 332/1000, Mean Reward: -4.8443, Mean KL Div: 1.1985
# Epoch 333/1000, Mean Reward: -5.7916, Mean KL Div: 1.1513
# Epoch 334/1000, Mean Reward: -5.2527, Mean KL Div: 1.1620
# Epoch 335/1000, Mean Reward: -5.2365, Mean KL Div: 1.2072
# Epoch 336/1000, Mean Reward: -5.2215, Mean KL Div: 1.1866
# Epoch 337/1000, Mean Reward: -4.7657, Mean KL Div: 1.1541
# Epoch 338/1000, Mean Reward: -4.5026, Mean KL Div: 1.1759
# Epoch 339/1000, Mean Reward: -4.8590, Mean KL Div: 1.2318
# Epoch 340/1000, Mean Reward: -4.9322, Mean KL Div: 1.2075
# Epoch 341/1000, Mean Reward: -4.9264, Mean KL Div: 1.2017
# Epoch 342/1000, Mean Reward: -5.2808, Mean KL Div: 1.2863
# Epoch 343/1000, Mean Reward: -4.9264, Mean KL Div: 1.2379
# Epoch 344/1000, Mean Reward: -5.0293, Mean KL Div: 1.2499
# Epoch 345/1000, Mean Reward: -4.7335, Mean KL Div: 1.2836
# Epoch 346/1000, Mean Reward: -4.6397, Mean KL Div: 1.3176
# Epoch 347/1000, Mean Reward: -4.9746, Mean KL Div: 1.2314
# Epoch 348/1000, Mean Reward: -4.8327, Mean KL Div: 1.2454
# Epoch 349/1000, Mean Reward: -4.9201, Mean KL Div: 1.3798
# Epoch 350/1000, Mean Reward: -5.0177, Mean KL Div: 1.3259
# Epoch 351/1000, Mean Reward: -4.6736, Mean KL Div: 1.3372
# Epoch 352/1000, Mean Reward: -4.8062, Mean KL Div: 1.3934
# Epoch 353/1000, Mean Reward: -5.2272, Mean KL Div: 1.3265
# Epoch 354/1000, Mean Reward: -4.4814, Mean KL Div: 1.3469
# Epoch 355/1000, Mean Reward: -5.2355, Mean KL Div: 1.3947
# Epoch 356/1000, Mean Reward: -4.6949, Mean KL Div: 1.4592
# Epoch 357/1000, Mean Reward: -4.9173, Mean KL Div: 1.4712
# Epoch 358/1000, Mean Reward: -4.3525, Mean KL Div: 1.4159
# Epoch 359/1000, Mean Reward: -4.3924, Mean KL Div: 1.3022
# Epoch 360/1000, Mean Reward: -4.4503, Mean KL Div: 1.4094
# Epoch 361/1000, Mean Reward: -4.5768, Mean KL Div: 1.3596
# Epoch 362/1000, Mean Reward: -4.6157, Mean KL Div: 1.3969
# Epoch 363/1000, Mean Reward: -4.7114, Mean KL Div: 1.4409
# Epoch 364/1000, Mean Reward: -4.6126, Mean KL Div: 1.4900
# Epoch 365/1000, Mean Reward: -4.4542, Mean KL Div: 1.3436
# Epoch 366/1000, Mean Reward: -4.8349, Mean KL Div: 1.4323
# Epoch 367/1000, Mean Reward: -4.6131, Mean KL Div: 1.4915
# Epoch 368/1000, Mean Reward: -4.2661, Mean KL Div: 1.3188
# Epoch 369/1000, Mean Reward: -4.4508, Mean KL Div: 1.4614
# Epoch 370/1000, Mean Reward: -4.8787, Mean KL Div: 1.4851
# Epoch 371/1000, Mean Reward: -4.0678, Mean KL Div: 1.4564
# Epoch 372/1000, Mean Reward: -4.2643, Mean KL Div: 1.5177
# Epoch 373/1000, Mean Reward: -4.9283, Mean KL Div: 1.4735
# Epoch 374/1000, Mean Reward: -4.4597, Mean KL Div: 1.4530
# Epoch 375/1000, Mean Reward: -4.5167, Mean KL Div: 1.4289
# Epoch 376/1000, Mean Reward: -4.3598, Mean KL Div: 1.5220
# Epoch 377/1000, Mean Reward: -4.5432, Mean KL Div: 1.6267
# Epoch 378/1000, Mean Reward: -4.3622, Mean KL Div: 1.5066
# Epoch 379/1000, Mean Reward: -4.6178, Mean KL Div: 1.4303
# Epoch 380/1000, Mean Reward: -4.7462, Mean KL Div: 1.5051
# Epoch 381/1000, Mean Reward: -4.1895, Mean KL Div: 1.5269
# Epoch 382/1000, Mean Reward: -4.3651, Mean KL Div: 1.5844
# Epoch 383/1000, Mean Reward: -4.4713, Mean KL Div: 1.5705
# Epoch 384/1000, Mean Reward: -4.3165, Mean KL Div: 1.4575
# Epoch 385/1000, Mean Reward: -4.5297, Mean KL Div: 1.6150
# Epoch 386/1000, Mean Reward: -4.3813, Mean KL Div: 1.5923
# Epoch 387/1000, Mean Reward: -4.2455, Mean KL Div: 1.5323
# Epoch 388/1000, Mean Reward: -4.4854, Mean KL Div: 1.6287
# Epoch 389/1000, Mean Reward: -4.5673, Mean KL Div: 1.6469
# Epoch 390/1000, Mean Reward: -4.3010, Mean KL Div: 1.6011
# Epoch 391/1000, Mean Reward: -4.2264, Mean KL Div: 1.7552
# Epoch 392/1000, Mean Reward: -3.7677, Mean KL Div: 1.6014
# Epoch 393/1000, Mean Reward: -4.2156, Mean KL Div: 1.5793
# Epoch 394/1000, Mean Reward: -4.2175, Mean KL Div: 1.5089
# Epoch 395/1000, Mean Reward: -4.2237, Mean KL Div: 1.6953
# Epoch 396/1000, Mean Reward: -4.2458, Mean KL Div: 1.6669
# Epoch 397/1000, Mean Reward: -3.9947, Mean KL Div: 1.6003
# Epoch 398/1000, Mean Reward: -4.5324, Mean KL Div: 1.5507
# Epoch 399/1000, Mean Reward: -4.4774, Mean KL Div: 1.5818
# Epoch 400/1000, Mean Reward: -4.4131, Mean KL Div: 1.5060
# Epoch 401/1000, Mean Reward: -4.3861, Mean KL Div: 1.6159
# Epoch 402/1000, Mean Reward: -4.2887, Mean KL Div: 1.6060
# Epoch 403/1000, Mean Reward: -4.5059, Mean KL Div: 1.5868
# Epoch 404/1000, Mean Reward: -4.0809, Mean KL Div: 1.7417
# Epoch 405/1000, Mean Reward: -4.0439, Mean KL Div: 1.5567
# Epoch 406/1000, Mean Reward: -4.0620, Mean KL Div: 1.6401
# Epoch 407/1000, Mean Reward: -4.1135, Mean KL Div: 1.6002
# Epoch 408/1000, Mean Reward: -3.8656, Mean KL Div: 1.5429
# Epoch 409/1000, Mean Reward: -4.0559, Mean KL Div: 1.6462
# Epoch 410/1000, Mean Reward: -3.8886, Mean KL Div: 1.6516
# Epoch 411/1000, Mean Reward: -4.0320, Mean KL Div: 1.6760
# Epoch 412/1000, Mean Reward: -4.1911, Mean KL Div: 1.7741
# Epoch 413/1000, Mean Reward: -4.5994, Mean KL Div: 1.6823
# Epoch 414/1000, Mean Reward: -3.8826, Mean KL Div: 1.6114
# Epoch 415/1000, Mean Reward: -4.3345, Mean KL Div: 1.5679
# Epoch 416/1000, Mean Reward: -4.7421, Mean KL Div: 1.8185
# Epoch 417/1000, Mean Reward: -3.7253, Mean KL Div: 1.6080
# Epoch 418/1000, Mean Reward: -3.4192, Mean KL Div: 1.5418
# Epoch 419/1000, Mean Reward: -4.2144, Mean KL Div: 1.7338
# Epoch 420/1000, Mean Reward: -4.3121, Mean KL Div: 1.7714
# Epoch 421/1000, Mean Reward: -4.2778, Mean KL Div: 1.8365
# Epoch 422/1000, Mean Reward: -4.2151, Mean KL Div: 1.7769
# Epoch 423/1000, Mean Reward: -4.3209, Mean KL Div: 1.7622
# Epoch 424/1000, Mean Reward: -3.6815, Mean KL Div: 1.7579
# Epoch 425/1000, Mean Reward: -4.5081, Mean KL Div: 1.8371
# Epoch 426/1000, Mean Reward: -4.2042, Mean KL Div: 1.7504
# Epoch 427/1000, Mean Reward: -3.7650, Mean KL Div: 1.6348
# Epoch 428/1000, Mean Reward: -4.3169, Mean KL Div: 1.7761
# Epoch 429/1000, Mean Reward: -3.9712, Mean KL Div: 1.7595
# Epoch 430/1000, Mean Reward: -3.8328, Mean KL Div: 1.7661
# Epoch 431/1000, Mean Reward: -3.9642, Mean KL Div: 1.7470
# Epoch 432/1000, Mean Reward: -4.0627, Mean KL Div: 1.7578
# Epoch 433/1000, Mean Reward: -3.6332, Mean KL Div: 1.8733
# Epoch 434/1000, Mean Reward: -4.6719, Mean KL Div: 1.9391
# Epoch 435/1000, Mean Reward: -3.8647, Mean KL Div: 1.7434
# Epoch 436/1000, Mean Reward: -4.1380, Mean KL Div: 1.9759
# Epoch 437/1000, Mean Reward: -3.6727, Mean KL Div: 1.8263
# Epoch 438/1000, Mean Reward: -4.3643, Mean KL Div: 1.9367
# Epoch 439/1000, Mean Reward: -3.6365, Mean KL Div: 1.8920
# Epoch 440/1000, Mean Reward: -3.7603, Mean KL Div: 1.8665
# Epoch 441/1000, Mean Reward: -3.5184, Mean KL Div: 1.9161
# Epoch 442/1000, Mean Reward: -4.3215, Mean KL Div: 1.9696
# Epoch 443/1000, Mean Reward: -4.4751, Mean KL Div: 1.9945
# Epoch 444/1000, Mean Reward: -4.3089, Mean KL Div: 2.0548
# Epoch 445/1000, Mean Reward: -3.5383, Mean KL Div: 1.7864
# Epoch 446/1000, Mean Reward: -3.9104, Mean KL Div: 1.9336
# Epoch 447/1000, Mean Reward: -4.3417, Mean KL Div: 1.9793
# Epoch 448/1000, Mean Reward: -3.9225, Mean KL Div: 2.0615
# Epoch 449/1000, Mean Reward: -3.6869, Mean KL Div: 1.8294
# Epoch 450/1000, Mean Reward: -3.9262, Mean KL Div: 1.9918
# Epoch 451/1000, Mean Reward: -3.9529, Mean KL Div: 1.8298
# Epoch 452/1000, Mean Reward: -3.5893, Mean KL Div: 1.9597
# Epoch 453/1000, Mean Reward: -4.1470, Mean KL Div: 1.9027
# Epoch 454/1000, Mean Reward: -4.3024, Mean KL Div: 2.0142
# Epoch 455/1000, Mean Reward: -4.2236, Mean KL Div: 1.9426
# Epoch 456/1000, Mean Reward: -4.2178, Mean KL Div: 2.0598
# Epoch 457/1000, Mean Reward: -4.0905, Mean KL Div: 1.9154
# Epoch 458/1000, Mean Reward: -3.9421, Mean KL Div: 1.8608
# Epoch 459/1000, Mean Reward: -3.9157, Mean KL Div: 1.9300
# Epoch 460/1000, Mean Reward: -4.0093, Mean KL Div: 2.0511
# Epoch 461/1000, Mean Reward: -3.8969, Mean KL Div: 2.0116
# Epoch 462/1000, Mean Reward: -3.9523, Mean KL Div: 1.8757
# Epoch 463/1000, Mean Reward: -3.4792, Mean KL Div: 2.0372
# Epoch 464/1000, Mean Reward: -4.1579, Mean KL Div: 1.9466
# Epoch 465/1000, Mean Reward: -4.0077, Mean KL Div: 2.0246
# Epoch 466/1000, Mean Reward: -4.0489, Mean KL Div: 2.2692
# Epoch 467/1000, Mean Reward: -3.9173, Mean KL Div: 2.0455
# Epoch 468/1000, Mean Reward: -3.8874, Mean KL Div: 2.0647
# Epoch 469/1000, Mean Reward: -3.8520, Mean KL Div: 2.0643
# Epoch 470/1000, Mean Reward: -3.5815, Mean KL Div: 2.1877
# Epoch 471/1000, Mean Reward: -3.7605, Mean KL Div: 2.1150
# Epoch 472/1000, Mean Reward: -3.9187, Mean KL Div: 2.0433
# Epoch 473/1000, Mean Reward: -3.2776, Mean KL Div: 1.9660
# Epoch 474/1000, Mean Reward: -3.7896, Mean KL Div: 2.0607
# Epoch 475/1000, Mean Reward: -3.2323, Mean KL Div: 2.2729
# Epoch 476/1000, Mean Reward: -3.3030, Mean KL Div: 2.1394
# Epoch 477/1000, Mean Reward: -3.7389, Mean KL Div: 2.2558
# Epoch 478/1000, Mean Reward: -3.6600, Mean KL Div: 2.1663
# Epoch 479/1000, Mean Reward: -3.7403, Mean KL Div: 2.1407
# Epoch 480/1000, Mean Reward: -3.7423, Mean KL Div: 2.2665
# Epoch 481/1000, Mean Reward: -4.2146, Mean KL Div: 2.3337
# Epoch 482/1000, Mean Reward: -3.6086, Mean KL Div: 2.3083
# Epoch 483/1000, Mean Reward: -3.5954, Mean KL Div: 2.2414
# Epoch 484/1000, Mean Reward: -3.9143, Mean KL Div: 2.3586
# Epoch 485/1000, Mean Reward: -3.5856, Mean KL Div: 2.2411
# Epoch 486/1000, Mean Reward: -4.0552, Mean KL Div: 2.2747
# Epoch 487/1000, Mean Reward: -3.5930, Mean KL Div: 2.2631
# Epoch 488/1000, Mean Reward: -3.2561, Mean KL Div: 2.2722
# Epoch 489/1000, Mean Reward: -3.5349, Mean KL Div: 2.0756
# Epoch 490/1000, Mean Reward: -3.7433, Mean KL Div: 2.2562
# Epoch 491/1000, Mean Reward: -3.5588, Mean KL Div: 2.3607
# Epoch 492/1000, Mean Reward: -3.5371, Mean KL Div: 2.2903
# Epoch 493/1000, Mean Reward: -3.5911, Mean KL Div: 2.3328
# Epoch 494/1000, Mean Reward: -3.5296, Mean KL Div: 2.3798
# Epoch 495/1000, Mean Reward: -3.4980, Mean KL Div: 2.2207
# Epoch 496/1000, Mean Reward: -3.4988, Mean KL Div: 2.1472
# Epoch 497/1000, Mean Reward: -3.6417, Mean KL Div: 2.3617
# Epoch 498/1000, Mean Reward: -3.1936, Mean KL Div: 2.2308
# Epoch 499/1000, Mean Reward: -3.2487, Mean KL Div: 2.3069
# Epoch 500/1000, Mean Reward: -3.6071, Mean KL Div: 2.4761
# Epoch 501/1000, Mean Reward: -3.4535, Mean KL Div: 2.3163
# Epoch 502/1000, Mean Reward: -3.3557, Mean KL Div: 2.3921
# Epoch 503/1000, Mean Reward: -3.0698, Mean KL Div: 2.4528
# Epoch 504/1000, Mean Reward: -3.3731, Mean KL Div: 2.6497
# Epoch 505/1000, Mean Reward: -2.8278, Mean KL Div: 2.4493
# Epoch 506/1000, Mean Reward: -2.9828, Mean KL Div: 2.4381
# Epoch 507/1000, Mean Reward: -3.8312, Mean KL Div: 2.5346
# Epoch 508/1000, Mean Reward: -3.1270, Mean KL Div: 2.3485
# Epoch 509/1000, Mean Reward: -3.1322, Mean KL Div: 2.4783
# Epoch 510/1000, Mean Reward: -3.5569, Mean KL Div: 2.6598
# Epoch 511/1000, Mean Reward: -3.6037, Mean KL Div: 2.5608
# Epoch 512/1000, Mean Reward: -3.3610, Mean KL Div: 2.5678
# Epoch 513/1000, Mean Reward: -3.7753, Mean KL Div: 2.6486
# Epoch 514/1000, Mean Reward: -3.6093, Mean KL Div: 2.6765
# Epoch 515/1000, Mean Reward: -3.0988, Mean KL Div: 2.5527
# Epoch 516/1000, Mean Reward: -3.0248, Mean KL Div: 2.4791
# Epoch 517/1000, Mean Reward: -3.2392, Mean KL Div: 2.5237
# Epoch 518/1000, Mean Reward: -3.4153, Mean KL Div: 2.6895
# Epoch 519/1000, Mean Reward: -3.0726, Mean KL Div: 2.4264
# Epoch 520/1000, Mean Reward: -3.5816, Mean KL Div: 2.5486
# Epoch 521/1000, Mean Reward: -3.5096, Mean KL Div: 2.5784
# Epoch 522/1000, Mean Reward: -3.8747, Mean KL Div: 2.7463
# Epoch 523/1000, Mean Reward: -3.7204, Mean KL Div: 2.6527
# Epoch 524/1000, Mean Reward: -3.6435, Mean KL Div: 2.5564
# Epoch 525/1000, Mean Reward: -3.4334, Mean KL Div: 2.7372
# Epoch 526/1000, Mean Reward: -3.3483, Mean KL Div: 2.6114
# Epoch 527/1000, Mean Reward: -3.5184, Mean KL Div: 2.7112
# Epoch 528/1000, Mean Reward: -3.4779, Mean KL Div: 2.6052
# Epoch 529/1000, Mean Reward: -3.4082, Mean KL Div: 2.5968
# Epoch 530/1000, Mean Reward: -3.5696, Mean KL Div: 2.6548
# Epoch 531/1000, Mean Reward: -3.4362, Mean KL Div: 2.5378
# Epoch 532/1000, Mean Reward: -3.5068, Mean KL Div: 2.6249
# Epoch 533/1000, Mean Reward: -3.0077, Mean KL Div: 2.6533
# Epoch 534/1000, Mean Reward: -3.2385, Mean KL Div: 2.6378
# Epoch 535/1000, Mean Reward: -3.2534, Mean KL Div: 2.4703
# Epoch 536/1000, Mean Reward: -3.7820, Mean KL Div: 3.0034
# Epoch 537/1000, Mean Reward: -3.3456, Mean KL Div: 2.5701
# Epoch 538/1000, Mean Reward: -3.0600, Mean KL Div: 2.6071
# Epoch 539/1000, Mean Reward: -3.1803, Mean KL Div: 2.5698
# Epoch 540/1000, Mean Reward: -3.5462, Mean KL Div: 2.8113
# Epoch 541/1000, Mean Reward: -3.3281, Mean KL Div: 2.6742
# Epoch 542/1000, Mean Reward: -2.9783, Mean KL Div: 2.6425
# Epoch 543/1000, Mean Reward: -3.1254, Mean KL Div: 2.7762
# Epoch 544/1000, Mean Reward: -3.3929, Mean KL Div: 2.8372
# Epoch 545/1000, Mean Reward: -3.2626, Mean KL Div: 2.7641
# Epoch 546/1000, Mean Reward: -3.6162, Mean KL Div: 3.0342
# Epoch 547/1000, Mean Reward: -3.1755, Mean KL Div: 2.9917
# Epoch 548/1000, Mean Reward: -3.4361, Mean KL Div: 3.0307
# Epoch 549/1000, Mean Reward: -2.8002, Mean KL Div: 2.8577
# Epoch 550/1000, Mean Reward: -3.1145, Mean KL Div: 3.1866
# Epoch 551/1000, Mean Reward: -3.0567, Mean KL Div: 3.0499
# Epoch 552/1000, Mean Reward: -2.9126, Mean KL Div: 3.0220
# Epoch 553/1000, Mean Reward: -3.3798, Mean KL Div: 3.0418
# Epoch 554/1000, Mean Reward: -2.8726, Mean KL Div: 2.9417
# Epoch 555/1000, Mean Reward: -3.3078, Mean KL Div: 3.2733
# Epoch 556/1000, Mean Reward: -3.2609, Mean KL Div: 3.2354
# Epoch 557/1000, Mean Reward: -2.9599, Mean KL Div: 3.0305
# Epoch 558/1000, Mean Reward: -2.7457, Mean KL Div: 3.0467
# Epoch 559/1000, Mean Reward: -2.9433, Mean KL Div: 3.3129
# Epoch 560/1000, Mean Reward: -3.0339, Mean KL Div: 3.2944
# Epoch 561/1000, Mean Reward: -2.7515, Mean KL Div: 2.9832
# Epoch 562/1000, Mean Reward: -2.7499, Mean KL Div: 3.2000
# Epoch 563/1000, Mean Reward: -3.0180, Mean KL Div: 3.2529
# Epoch 564/1000, Mean Reward: -2.9507, Mean KL Div: 3.0309
# Epoch 565/1000, Mean Reward: -3.0526, Mean KL Div: 3.0248
# Epoch 566/1000, Mean Reward: -2.9703, Mean KL Div: 3.1887
# Epoch 567/1000, Mean Reward: -3.1215, Mean KL Div: 3.1196
# Epoch 568/1000, Mean Reward: -2.8402, Mean KL Div: 3.2262
# Epoch 569/1000, Mean Reward: -2.8245, Mean KL Div: 3.0421
# Epoch 570/1000, Mean Reward: -2.9674, Mean KL Div: 3.1259
# Epoch 571/1000, Mean Reward: -2.8264, Mean KL Div: 3.2817
# Epoch 572/1000, Mean Reward: -2.9501, Mean KL Div: 3.4193
# Epoch 573/1000, Mean Reward: -3.0170, Mean KL Div: 3.4134
# Epoch 574/1000, Mean Reward: -3.1271, Mean KL Div: 3.3983
# Epoch 575/1000, Mean Reward: -3.0309, Mean KL Div: 3.3247
# Epoch 576/1000, Mean Reward: -3.4520, Mean KL Div: 3.4772
# Epoch 577/1000, Mean Reward: -3.3343, Mean KL Div: 3.4814
# Epoch 578/1000, Mean Reward: -3.3152, Mean KL Div: 3.4406
# Epoch 579/1000, Mean Reward: -2.9669, Mean KL Div: 3.4522
# Epoch 580/1000, Mean Reward: -3.0555, Mean KL Div: 3.6564
# Epoch 581/1000, Mean Reward: -3.5640, Mean KL Div: 3.6673
# Epoch 582/1000, Mean Reward: -3.0216, Mean KL Div: 3.5186
# Epoch 583/1000, Mean Reward: -2.6842, Mean KL Div: 3.5306
# Epoch 584/1000, Mean Reward: -3.2451, Mean KL Div: 3.6696
# Epoch 585/1000, Mean Reward: -3.3974, Mean KL Div: 3.6315
# Epoch 586/1000, Mean Reward: -3.1216, Mean KL Div: 3.6308
# Epoch 587/1000, Mean Reward: -3.0047, Mean KL Div: 3.8281
# Epoch 588/1000, Mean Reward: -2.8235, Mean KL Div: 3.8361
# Epoch 589/1000, Mean Reward: -2.9945, Mean KL Div: 3.7378
# Epoch 590/1000, Mean Reward: -3.0030, Mean KL Div: 3.8085
# Epoch 591/1000, Mean Reward: -2.8704, Mean KL Div: 3.5856
# Epoch 592/1000, Mean Reward: -2.8711, Mean KL Div: 3.5506
# Epoch 593/1000, Mean Reward: -2.7848, Mean KL Div: 3.5650
# Epoch 594/1000, Mean Reward: -3.1084, Mean KL Div: 3.8729
# Epoch 595/1000, Mean Reward: -3.1496, Mean KL Div: 3.8992
# Epoch 596/1000, Mean Reward: -2.9645, Mean KL Div: 3.7642
# Epoch 597/1000, Mean Reward: -3.2587, Mean KL Div: 3.9100
# Epoch 598/1000, Mean Reward: -2.8693, Mean KL Div: 3.7074
# Epoch 599/1000, Mean Reward: -3.0701, Mean KL Div: 3.9846
# Epoch 600/1000, Mean Reward: -3.2577, Mean KL Div: 3.9715
# Epoch 601/1000, Mean Reward: -2.6465, Mean KL Div: 3.5707
# Epoch 602/1000, Mean Reward: -2.6958, Mean KL Div: 3.6366
# Epoch 603/1000, Mean Reward: -3.0212, Mean KL Div: 4.1266
# Epoch 604/1000, Mean Reward: -2.8720, Mean KL Div: 3.8528
# Epoch 605/1000, Mean Reward: -2.8245, Mean KL Div: 3.9803
# Epoch 606/1000, Mean Reward: -2.6349, Mean KL Div: 3.6025
# Epoch 607/1000, Mean Reward: -2.9167, Mean KL Div: 3.9101
# Epoch 608/1000, Mean Reward: -2.6310, Mean KL Div: 3.7587
# Epoch 609/1000, Mean Reward: -3.1610, Mean KL Div: 4.0966
# Epoch 610/1000, Mean Reward: -2.7733, Mean KL Div: 3.8389
# Epoch 611/1000, Mean Reward: -2.9247, Mean KL Div: 4.2229
# Epoch 612/1000, Mean Reward: -2.7809, Mean KL Div: 3.8094
# Epoch 613/1000, Mean Reward: -2.7074, Mean KL Div: 4.1360
# Epoch 614/1000, Mean Reward: -2.9383, Mean KL Div: 3.9586
# Epoch 615/1000, Mean Reward: -3.0824, Mean KL Div: 4.1662
# Epoch 616/1000, Mean Reward: -2.8709, Mean KL Div: 3.9929
# Epoch 617/1000, Mean Reward: -2.7692, Mean KL Div: 3.9640
# Epoch 618/1000, Mean Reward: -3.0295, Mean KL Div: 4.2698
# Epoch 619/1000, Mean Reward: -2.8093, Mean KL Div: 4.0981
# Epoch 620/1000, Mean Reward: -2.7212, Mean KL Div: 4.0202
# Epoch 621/1000, Mean Reward: -3.1485, Mean KL Div: 4.2226
# Epoch 622/1000, Mean Reward: -2.6293, Mean KL Div: 3.6521
# Epoch 623/1000, Mean Reward: -2.7013, Mean KL Div: 3.7183
# Epoch 624/1000, Mean Reward: -2.7745, Mean KL Div: 3.7321
# Epoch 625/1000, Mean Reward: -2.8026, Mean KL Div: 3.8841
# Epoch 626/1000, Mean Reward: -2.8704, Mean KL Div: 3.6129
# Epoch 627/1000, Mean Reward: -2.8280, Mean KL Div: 3.9242
# Epoch 628/1000, Mean Reward: -2.9904, Mean KL Div: 3.8856
# Epoch 629/1000, Mean Reward: -3.0390, Mean KL Div: 4.0259
# Epoch 630/1000, Mean Reward: -2.5841, Mean KL Div: 3.8030
# Epoch 631/1000, Mean Reward: -2.7647, Mean KL Div: 4.1200
# Epoch 632/1000, Mean Reward: -2.6126, Mean KL Div: 3.9157
# Epoch 633/1000, Mean Reward: -2.6591, Mean KL Div: 3.7913
# Epoch 634/1000, Mean Reward: -3.1028, Mean KL Div: 4.3667
# Epoch 635/1000, Mean Reward: -2.3930, Mean KL Div: 3.8307
# Epoch 636/1000, Mean Reward: -2.6355, Mean KL Div: 4.0113
# Epoch 637/1000, Mean Reward: -2.8844, Mean KL Div: 4.0555
# Epoch 638/1000, Mean Reward: -2.5214, Mean KL Div: 3.9429
# Epoch 639/1000, Mean Reward: -2.7642, Mean KL Div: 4.0845
# Epoch 640/1000, Mean Reward: -2.5243, Mean KL Div: 3.9726
# Epoch 641/1000, Mean Reward: -3.0431, Mean KL Div: 4.0506
# Epoch 642/1000, Mean Reward: -2.5382, Mean KL Div: 3.9933
# Epoch 643/1000, Mean Reward: -2.8040, Mean KL Div: 4.0652
# Epoch 644/1000, Mean Reward: -2.6234, Mean KL Div: 3.8860
# Epoch 645/1000, Mean Reward: -2.6572, Mean KL Div: 4.0233
# Epoch 646/1000, Mean Reward: -2.8398, Mean KL Div: 4.1622
# Epoch 647/1000, Mean Reward: -2.3372, Mean KL Div: 3.8835
# Epoch 648/1000, Mean Reward: -2.9288, Mean KL Div: 4.4007
# Epoch 649/1000, Mean Reward: -2.4612, Mean KL Div: 4.0222
# Epoch 650/1000, Mean Reward: -2.6530, Mean KL Div: 4.1509
# Epoch 651/1000, Mean Reward: -2.4881, Mean KL Div: 4.0411
# Epoch 652/1000, Mean Reward: -2.8278, Mean KL Div: 4.3560
# Epoch 653/1000, Mean Reward: -2.7924, Mean KL Div: 4.5909
# Epoch 654/1000, Mean Reward: -2.3109, Mean KL Div: 4.1736
# Epoch 655/1000, Mean Reward: -2.6121, Mean KL Div: 4.2145
# Epoch 656/1000, Mean Reward: -2.9258, Mean KL Div: 4.2710
# Epoch 657/1000, Mean Reward: -2.7018, Mean KL Div: 4.4793
# Epoch 658/1000, Mean Reward: -2.8398, Mean KL Div: 4.3007
# Epoch 659/1000, Mean Reward: -2.2847, Mean KL Div: 4.1428
# Epoch 660/1000, Mean Reward: -3.1484, Mean KL Div: 4.6674
# Epoch 661/1000, Mean Reward: -2.4149, Mean KL Div: 4.1873
# Epoch 662/1000, Mean Reward: -2.6019, Mean KL Div: 4.1909
# Epoch 663/1000, Mean Reward: -3.0384, Mean KL Div: 4.5826
# Epoch 664/1000, Mean Reward: -2.5266, Mean KL Div: 4.2278
# Epoch 665/1000, Mean Reward: -2.8619, Mean KL Div: 4.2290
# Epoch 666/1000, Mean Reward: -2.5738, Mean KL Div: 4.0869
# Epoch 667/1000, Mean Reward: -2.4148, Mean KL Div: 4.1311
# Epoch 668/1000, Mean Reward: -2.5819, Mean KL Div: 4.2001
# Epoch 669/1000, Mean Reward: -2.8044, Mean KL Div: 4.6006
# Epoch 670/1000, Mean Reward: -2.6467, Mean KL Div: 4.3945
# Epoch 671/1000, Mean Reward: -2.4656, Mean KL Div: 4.2450
# Epoch 672/1000, Mean Reward: -2.4178, Mean KL Div: 4.3346
# Epoch 673/1000, Mean Reward: -2.5441, Mean KL Div: 4.1676
# Epoch 674/1000, Mean Reward: -2.6452, Mean KL Div: 4.2343
# Epoch 675/1000, Mean Reward: -2.4669, Mean KL Div: 4.1568
# Epoch 676/1000, Mean Reward: -2.4650, Mean KL Div: 4.2909
# Epoch 677/1000, Mean Reward: -2.5541, Mean KL Div: 4.3474
# Epoch 678/1000, Mean Reward: -2.5699, Mean KL Div: 4.4886
# Epoch 679/1000, Mean Reward: -2.3984, Mean KL Div: 4.0490
# Epoch 680/1000, Mean Reward: -2.4081, Mean KL Div: 4.0838
# Epoch 681/1000, Mean Reward: -2.2072, Mean KL Div: 4.0493
# Epoch 682/1000, Mean Reward: -2.4202, Mean KL Div: 4.2119
# Epoch 683/1000, Mean Reward: -2.4440, Mean KL Div: 4.3481
# Epoch 684/1000, Mean Reward: -2.4723, Mean KL Div: 4.1559
# Epoch 685/1000, Mean Reward: -2.4103, Mean KL Div: 4.2941
# Epoch 686/1000, Mean Reward: -2.1829, Mean KL Div: 4.1745
# Epoch 687/1000, Mean Reward: -2.4230, Mean KL Div: 4.3796
# Epoch 688/1000, Mean Reward: -2.1111, Mean KL Div: 4.2055
# Epoch 689/1000, Mean Reward: -2.3287, Mean KL Div: 4.2692
# Epoch 690/1000, Mean Reward: -2.3170, Mean KL Div: 4.2774
# Epoch 691/1000, Mean Reward: -2.2791, Mean KL Div: 4.3822
# Epoch 692/1000, Mean Reward: -2.2374, Mean KL Div: 4.3482
# Epoch 693/1000, Mean Reward: -2.4680, Mean KL Div: 4.5727
# Epoch 694/1000, Mean Reward: -2.2007, Mean KL Div: 4.5506
# Epoch 695/1000, Mean Reward: -2.2588, Mean KL Div: 4.3446
# Epoch 696/1000, Mean Reward: -2.1479, Mean KL Div: 4.2304
# Epoch 697/1000, Mean Reward: -2.2620, Mean KL Div: 4.6836
# Epoch 698/1000, Mean Reward: -2.1058, Mean KL Div: 4.4816
# Epoch 699/1000, Mean Reward: -2.0269, Mean KL Div: 4.2888
# Epoch 700/1000, Mean Reward: -1.8920, Mean KL Div: 4.3953
# Epoch 701/1000, Mean Reward: -1.9845, Mean KL Div: 4.6098
# Epoch 702/1000, Mean Reward: -1.9535, Mean KL Div: 4.5475
# Epoch 703/1000, Mean Reward: -1.9487, Mean KL Div: 4.6501
# Epoch 704/1000, Mean Reward: -1.9231, Mean KL Div: 4.3824
# Epoch 705/1000, Mean Reward: -2.2852, Mean KL Div: 4.6037
# Epoch 706/1000, Mean Reward: -2.3450, Mean KL Div: 4.9230
# Epoch 707/1000, Mean Reward: -2.1867, Mean KL Div: 4.6631
# Epoch 708/1000, Mean Reward: -2.1048, Mean KL Div: 4.5761
# Epoch 709/1000, Mean Reward: -2.0229, Mean KL Div: 4.8037
# Epoch 710/1000, Mean Reward: -2.0224, Mean KL Div: 4.7045
# Epoch 711/1000, Mean Reward: -2.1276, Mean KL Div: 4.8372
# Epoch 712/1000, Mean Reward: -1.8339, Mean KL Div: 4.3390
# Epoch 713/1000, Mean Reward: -2.6100, Mean KL Div: 5.2590
# Epoch 714/1000, Mean Reward: -1.9324, Mean KL Div: 4.5363
# Epoch 715/1000, Mean Reward: -1.9043, Mean KL Div: 4.6018
# Epoch 716/1000, Mean Reward: -1.8597, Mean KL Div: 4.6513
# Epoch 717/1000, Mean Reward: -2.1831, Mean KL Div: 4.6992
# Epoch 718/1000, Mean Reward: -1.8345, Mean KL Div: 4.6930
# Epoch 719/1000, Mean Reward: -2.0586, Mean KL Div: 4.8845
# Epoch 720/1000, Mean Reward: -1.7963, Mean KL Div: 4.8209
# Epoch 721/1000, Mean Reward: -2.0565, Mean KL Div: 5.0291
# Epoch 722/1000, Mean Reward: -1.8776, Mean KL Div: 4.7792
# Epoch 723/1000, Mean Reward: -2.1498, Mean KL Div: 4.9574
# Epoch 724/1000, Mean Reward: -1.7930, Mean KL Div: 4.9754
# Epoch 725/1000, Mean Reward: -2.0175, Mean KL Div: 4.9437
# Epoch 726/1000, Mean Reward: -2.1977, Mean KL Div: 5.6470
# Epoch 727/1000, Mean Reward: -1.8949, Mean KL Div: 4.9299
# Epoch 728/1000, Mean Reward: -1.7867, Mean KL Div: 4.7904
# Epoch 729/1000, Mean Reward: -1.8363, Mean KL Div: 4.9759
# Epoch 730/1000, Mean Reward: -1.7345, Mean KL Div: 5.0052
# Epoch 731/1000, Mean Reward: -2.0906, Mean KL Div: 5.4249
# Epoch 732/1000, Mean Reward: -1.8698, Mean KL Div: 5.2702
# Epoch 733/1000, Mean Reward: -1.7396, Mean KL Div: 5.1674
# Epoch 734/1000, Mean Reward: -1.5552, Mean KL Div: 4.9325
# Epoch 735/1000, Mean Reward: -1.7104, Mean KL Div: 5.3321
# Epoch 736/1000, Mean Reward: -1.8996, Mean KL Div: 5.4009
# Epoch 737/1000, Mean Reward: -1.9383, Mean KL Div: 5.5858
# Epoch 738/1000, Mean Reward: -1.7830, Mean KL Div: 5.3996
# Epoch 739/1000, Mean Reward: -1.7531, Mean KL Div: 5.0911
# Epoch 740/1000, Mean Reward: -1.7470, Mean KL Div: 5.2722
# Epoch 741/1000, Mean Reward: -1.8512, Mean KL Div: 5.5200
# Epoch 742/1000, Mean Reward: -1.6516, Mean KL Div: 5.0313
# Epoch 743/1000, Mean Reward: -1.5980, Mean KL Div: 5.3435
# Epoch 744/1000, Mean Reward: -1.5504, Mean KL Div: 5.0386
# Epoch 745/1000, Mean Reward: -1.6888, Mean KL Div: 5.5083
# Epoch 746/1000, Mean Reward: -1.6355, Mean KL Div: 5.3016
# Epoch 747/1000, Mean Reward: -1.7974, Mean KL Div: 5.3951
# Epoch 748/1000, Mean Reward: -1.6435, Mean KL Div: 4.9561
# Epoch 749/1000, Mean Reward: -1.5006, Mean KL Div: 4.9862
# Epoch 750/1000, Mean Reward: -1.5942, Mean KL Div: 5.3534
# Epoch 751/1000, Mean Reward: -1.6659, Mean KL Div: 5.2129
# Epoch 752/1000, Mean Reward: -1.7114, Mean KL Div: 5.0976
# Epoch 753/1000, Mean Reward: -1.6472, Mean KL Div: 5.2290
# Epoch 754/1000, Mean Reward: -1.6018, Mean KL Div: 5.6434
# Epoch 755/1000, Mean Reward: -1.5063, Mean KL Div: 5.7120
# Epoch 756/1000, Mean Reward: -1.6231, Mean KL Div: 5.5497
# Epoch 757/1000, Mean Reward: -1.4604, Mean KL Div: 5.6411
# Epoch 758/1000, Mean Reward: -1.6568, Mean KL Div: 5.8026
# Epoch 759/1000, Mean Reward: -1.4383, Mean KL Div: 5.4384
# Epoch 760/1000, Mean Reward: -1.5522, Mean KL Div: 5.8715
# Epoch 761/1000, Mean Reward: -1.7075, Mean KL Div: 5.8900
# Epoch 762/1000, Mean Reward: -1.5994, Mean KL Div: 6.0365
# Epoch 763/1000, Mean Reward: -1.6436, Mean KL Div: 6.2327
# Epoch 764/1000, Mean Reward: -1.7062, Mean KL Div: 6.2049
# Epoch 765/1000, Mean Reward: -1.3959, Mean KL Div: 5.7281
# Epoch 766/1000, Mean Reward: -1.4641, Mean KL Div: 6.0599
# Epoch 767/1000, Mean Reward: -1.4684, Mean KL Div: 6.3590
# Epoch 768/1000, Mean Reward: -1.4130, Mean KL Div: 6.2481
# Epoch 769/1000, Mean Reward: -1.5176, Mean KL Div: 6.0439
# Epoch 770/1000, Mean Reward: -1.4877, Mean KL Div: 6.1874
# Epoch 771/1000, Mean Reward: -1.3361, Mean KL Div: 5.7975
# Epoch 772/1000, Mean Reward: -1.5822, Mean KL Div: 5.8643
# Epoch 773/1000, Mean Reward: -1.4594, Mean KL Div: 6.0052
# Epoch 774/1000, Mean Reward: -1.6190, Mean KL Div: 6.5170
# Epoch 775/1000, Mean Reward: -1.5285, Mean KL Div: 6.1471
# Epoch 776/1000, Mean Reward: -1.5509, Mean KL Div: 6.3285
# Epoch 777/1000, Mean Reward: -1.4310, Mean KL Div: 6.2361
# Epoch 778/1000, Mean Reward: -1.4138, Mean KL Div: 5.9264
# Epoch 779/1000, Mean Reward: -1.3704, Mean KL Div: 6.1236
# Epoch 780/1000, Mean Reward: -1.4773, Mean KL Div: 6.2442
# Epoch 781/1000, Mean Reward: -1.4858, Mean KL Div: 6.1566
# Epoch 782/1000, Mean Reward: -1.4573, Mean KL Div: 6.5251
# Epoch 783/1000, Mean Reward: -1.5472, Mean KL Div: 6.5597
# Epoch 784/1000, Mean Reward: -1.3841, Mean KL Div: 6.2366
# Epoch 785/1000, Mean Reward: -1.4689, Mean KL Div: 6.2784
# Epoch 786/1000, Mean Reward: -1.5211, Mean KL Div: 6.4325
# Epoch 787/1000, Mean Reward: -1.4401, Mean KL Div: 6.3918
# Epoch 788/1000, Mean Reward: -1.4962, Mean KL Div: 6.8100
# Epoch 789/1000, Mean Reward: -1.3363, Mean KL Div: 6.6459
# Epoch 790/1000, Mean Reward: -1.3478, Mean KL Div: 6.9952
# Epoch 791/1000, Mean Reward: -1.3423, Mean KL Div: 6.8428
# Epoch 792/1000, Mean Reward: -1.2493, Mean KL Div: 6.8868
# Epoch 793/1000, Mean Reward: -1.3691, Mean KL Div: 6.8032
# Epoch 794/1000, Mean Reward: -1.2792, Mean KL Div: 6.5172
# Epoch 795/1000, Mean Reward: -1.3597, Mean KL Div: 6.8163
# Epoch 796/1000, Mean Reward: -1.3165, Mean KL Div: 6.8546
# Epoch 797/1000, Mean Reward: -1.5075, Mean KL Div: 7.2253
# Epoch 798/1000, Mean Reward: -1.3957, Mean KL Div: 7.1638
# Epoch 799/1000, Mean Reward: -1.2408, Mean KL Div: 6.8941
# Epoch 800/1000, Mean Reward: -1.3728, Mean KL Div: 7.0841
# Epoch 801/1000, Mean Reward: -1.3344, Mean KL Div: 7.0874
# Epoch 802/1000, Mean Reward: -1.2708, Mean KL Div: 7.1718
# Epoch 803/1000, Mean Reward: -1.2329, Mean KL Div: 6.7411
# Epoch 804/1000, Mean Reward: -1.2888, Mean KL Div: 6.9216
# Epoch 805/1000, Mean Reward: -1.3594, Mean KL Div: 7.2343
# Epoch 806/1000, Mean Reward: -1.3473, Mean KL Div: 7.1529
# Epoch 807/1000, Mean Reward: -1.3262, Mean KL Div: 7.1588
# Epoch 808/1000, Mean Reward: -1.3640, Mean KL Div: 7.0315
# Epoch 809/1000, Mean Reward: -1.3348, Mean KL Div: 7.4752
# Epoch 810/1000, Mean Reward: -1.3381, Mean KL Div: 7.4379
# Epoch 811/1000, Mean Reward: -1.3233, Mean KL Div: 7.7142
# Epoch 812/1000, Mean Reward: -1.4186, Mean KL Div: 7.3597
# Epoch 813/1000, Mean Reward: -1.3177, Mean KL Div: 7.2878
# Epoch 814/1000, Mean Reward: -1.2991, Mean KL Div: 7.3301
# Epoch 815/1000, Mean Reward: -1.2591, Mean KL Div: 7.1023
# Epoch 816/1000, Mean Reward: -1.3082, Mean KL Div: 7.2772
# Epoch 817/1000, Mean Reward: -1.3378, Mean KL Div: 7.2584
# Epoch 818/1000, Mean Reward: -1.4567, Mean KL Div: 7.0777
# Epoch 819/1000, Mean Reward: -1.3136, Mean KL Div: 7.8897
# Epoch 820/1000, Mean Reward: -1.2431, Mean KL Div: 7.3267
# Epoch 821/1000, Mean Reward: -1.2356, Mean KL Div: 7.4026
# Epoch 822/1000, Mean Reward: -1.3412, Mean KL Div: 7.6700
# Epoch 823/1000, Mean Reward: -1.2950, Mean KL Div: 7.4529
# Epoch 824/1000, Mean Reward: -1.2667, Mean KL Div: 7.2522
# Epoch 825/1000, Mean Reward: -1.2437, Mean KL Div: 7.0980
# Epoch 826/1000, Mean Reward: -1.2587, Mean KL Div: 7.5441
# Epoch 827/1000, Mean Reward: -1.2637, Mean KL Div: 7.3952
# Epoch 828/1000, Mean Reward: -1.3212, Mean KL Div: 7.8959
# Epoch 829/1000, Mean Reward: -1.2254, Mean KL Div: 7.7404
# Epoch 830/1000, Mean Reward: -1.4186, Mean KL Div: 7.8104
# Epoch 831/1000, Mean Reward: -1.2350, Mean KL Div: 7.5902
# Epoch 832/1000, Mean Reward: -1.2888, Mean KL Div: 7.3675
# Epoch 833/1000, Mean Reward: -1.2910, Mean KL Div: 7.8407
# Epoch 834/1000, Mean Reward: -1.3125, Mean KL Div: 7.7544
# Epoch 835/1000, Mean Reward: -1.2868, Mean KL Div: 8.2393
# Epoch 836/1000, Mean Reward: -1.1991, Mean KL Div: 7.6594
# Epoch 837/1000, Mean Reward: -1.3556, Mean KL Div: 8.2150
# Epoch 838/1000, Mean Reward: -1.2431, Mean KL Div: 7.6565
# Epoch 839/1000, Mean Reward: -1.3072, Mean KL Div: 7.8024
# Epoch 840/1000, Mean Reward: -1.2418, Mean KL Div: 8.0623
# Epoch 841/1000, Mean Reward: -1.4203, Mean KL Div: 8.0604
# Epoch 842/1000, Mean Reward: -1.2108, Mean KL Div: 7.8392
# Epoch 843/1000, Mean Reward: -1.2100, Mean KL Div: 7.9507
# Epoch 844/1000, Mean Reward: -1.2179, Mean KL Div: 7.8531
# Epoch 845/1000, Mean Reward: -1.2557, Mean KL Div: 7.5994
# Epoch 846/1000, Mean Reward: -1.3978, Mean KL Div: 8.2938
# Epoch 847/1000, Mean Reward: -1.3733, Mean KL Div: 7.8257
# Epoch 848/1000, Mean Reward: -1.3140, Mean KL Div: 7.8224
# Epoch 849/1000, Mean Reward: -1.2700, Mean KL Div: 8.0300
# Epoch 850/1000, Mean Reward: -1.3202, Mean KL Div: 8.1426
# Epoch 851/1000, Mean Reward: -1.2385, Mean KL Div: 8.0696
# Epoch 852/1000, Mean Reward: -1.2229, Mean KL Div: 7.5332
# Epoch 853/1000, Mean Reward: -1.3024, Mean KL Div: 8.0389
# Epoch 854/1000, Mean Reward: -1.3232, Mean KL Div: 7.7026
# Epoch 855/1000, Mean Reward: -1.3473, Mean KL Div: 7.6164
# Epoch 856/1000, Mean Reward: -1.2954, Mean KL Div: 7.4725
# Epoch 857/1000, Mean Reward: -1.3947, Mean KL Div: 7.6277
# Epoch 858/1000, Mean Reward: -1.2405, Mean KL Div: 7.2951
# Epoch 859/1000, Mean Reward: -1.2886, Mean KL Div: 7.7494
# Epoch 860/1000, Mean Reward: -1.3017, Mean KL Div: 8.1236
# Epoch 861/1000, Mean Reward: -1.2512, Mean KL Div: 8.0391
# Epoch 862/1000, Mean Reward: -1.2771, Mean KL Div: 8.0394
# Epoch 863/1000, Mean Reward: -1.2638, Mean KL Div: 8.0787
# Epoch 864/1000, Mean Reward: -1.2131, Mean KL Div: 8.2681
# Epoch 865/1000, Mean Reward: -1.1674, Mean KL Div: 8.6163
# Epoch 866/1000, Mean Reward: -1.1798, Mean KL Div: 8.4350
# Epoch 867/1000, Mean Reward: -1.2289, Mean KL Div: 8.3122
# Epoch 868/1000, Mean Reward: -1.2348, Mean KL Div: 8.2691
# Epoch 869/1000, Mean Reward: -1.1805, Mean KL Div: 8.8001
# Epoch 870/1000, Mean Reward: -1.1736, Mean KL Div: 8.7156
# Epoch 871/1000, Mean Reward: -1.2191, Mean KL Div: 8.6937
# Epoch 872/1000, Mean Reward: -1.2540, Mean KL Div: 8.8260
# Epoch 873/1000, Mean Reward: -1.1807, Mean KL Div: 8.7760
# Epoch 874/1000, Mean Reward: -1.1480, Mean KL Div: 8.8407
# Epoch 875/1000, Mean Reward: -1.2969, Mean KL Div: 9.0603
# Epoch 876/1000, Mean Reward: -1.1398, Mean KL Div: 8.8237
# Epoch 877/1000, Mean Reward: -1.2251, Mean KL Div: 8.8295
# Epoch 878/1000, Mean Reward: -1.1699, Mean KL Div: 8.6201
# Epoch 879/1000, Mean Reward: -1.2509, Mean KL Div: 8.7315
# Epoch 880/1000, Mean Reward: -1.1850, Mean KL Div: 8.7877
# Epoch 881/1000, Mean Reward: -1.1488, Mean KL Div: 8.9352
# Epoch 882/1000, Mean Reward: -1.2504, Mean KL Div: 8.8211
# Epoch 883/1000, Mean Reward: -1.1810, Mean KL Div: 9.1517
# Epoch 884/1000, Mean Reward: -1.1440, Mean KL Div: 8.6986
# Epoch 885/1000, Mean Reward: -1.2586, Mean KL Div: 8.8480
# Epoch 886/1000, Mean Reward: -1.1738, Mean KL Div: 8.9088
# Epoch 887/1000, Mean Reward: -1.1094, Mean KL Div: 8.8780
# Epoch 888/1000, Mean Reward: -1.2945, Mean KL Div: 9.4942
# Epoch 889/1000, Mean Reward: -1.1428, Mean KL Div: 9.0604
# Epoch 890/1000, Mean Reward: -1.2123, Mean KL Div: 9.2064
# Epoch 891/1000, Mean Reward: -1.1933, Mean KL Div: 9.0901
# Epoch 892/1000, Mean Reward: -1.1860, Mean KL Div: 9.0720
# Epoch 893/1000, Mean Reward: -1.1299, Mean KL Div: 9.2372
# Epoch 894/1000, Mean Reward: -1.1250, Mean KL Div: 8.7556
# Epoch 895/1000, Mean Reward: -1.2695, Mean KL Div: 8.9953
# Epoch 896/1000, Mean Reward: -1.1348, Mean KL Div: 9.1551
# Epoch 897/1000, Mean Reward: -1.1748, Mean KL Div: 8.8233
# Epoch 898/1000, Mean Reward: -1.1776, Mean KL Div: 8.8268
# Epoch 899/1000, Mean Reward: -1.1852, Mean KL Div: 9.1452
# Epoch 900/1000, Mean Reward: -1.2713, Mean KL Div: 9.2693
# Epoch 901/1000, Mean Reward: -1.1321, Mean KL Div: 9.2922
# Epoch 902/1000, Mean Reward: -1.1015, Mean KL Div: 9.2177
# Epoch 903/1000, Mean Reward: -1.1365, Mean KL Div: 9.2426
# Epoch 904/1000, Mean Reward: -1.0888, Mean KL Div: 8.8301
# Epoch 905/1000, Mean Reward: -1.0862, Mean KL Div: 9.1467
# Epoch 906/1000, Mean Reward: -1.1852, Mean KL Div: 9.4558
# Epoch 907/1000, Mean Reward: -1.1247, Mean KL Div: 9.3705
# Epoch 908/1000, Mean Reward: -1.3618, Mean KL Div: 9.3533
# Epoch 909/1000, Mean Reward: -1.0748, Mean KL Div: 9.0370
# Epoch 910/1000, Mean Reward: -1.1604, Mean KL Div: 9.1806
# Epoch 911/1000, Mean Reward: -1.0870, Mean KL Div: 9.0258
# Epoch 912/1000, Mean Reward: -1.0532, Mean KL Div: 9.1598
# Epoch 913/1000, Mean Reward: -1.0871, Mean KL Div: 9.3767
# Epoch 914/1000, Mean Reward: -1.1825, Mean KL Div: 9.3134
# Epoch 915/1000, Mean Reward: -1.1625, Mean KL Div: 9.2704
# Epoch 916/1000, Mean Reward: -1.1170, Mean KL Div: 9.4996
# Epoch 917/1000, Mean Reward: -1.1001, Mean KL Div: 9.2842
# Epoch 918/1000, Mean Reward: -1.1361, Mean KL Div: 9.5481
# Epoch 919/1000, Mean Reward: -1.1048, Mean KL Div: 9.2853
# Epoch 920/1000, Mean Reward: -1.1125, Mean KL Div: 9.4829
# Epoch 921/1000, Mean Reward: -1.1270, Mean KL Div: 9.5706
# Epoch 922/1000, Mean Reward: -1.1114, Mean KL Div: 9.7355
# Epoch 923/1000, Mean Reward: -1.1528, Mean KL Div: 10.1430
# Epoch 924/1000, Mean Reward: -1.1542, Mean KL Div: 9.8801
# Epoch 925/1000, Mean Reward: -1.0946, Mean KL Div: 9.5849
# Epoch 926/1000, Mean Reward: -1.0613, Mean KL Div: 9.8677
# Epoch 927/1000, Mean Reward: -1.1356, Mean KL Div: 9.8987
# Epoch 928/1000, Mean Reward: -1.0758, Mean KL Div: 9.8338
# Epoch 929/1000, Mean Reward: -1.1067, Mean KL Div: 10.0451
# Epoch 930/1000, Mean Reward: -1.0870, Mean KL Div: 10.1341
# Epoch 931/1000, Mean Reward: -1.0751, Mean KL Div: 10.1152
# Epoch 932/1000, Mean Reward: -1.0956, Mean KL Div: 10.1167
# Epoch 933/1000, Mean Reward: -1.1329, Mean KL Div: 10.1020
# Epoch 934/1000, Mean Reward: -1.1917, Mean KL Div: 10.2092
# Epoch 935/1000, Mean Reward: -1.0946, Mean KL Div: 10.0684
# Epoch 936/1000, Mean Reward: -1.1888, Mean KL Div: 10.3013
# Epoch 937/1000, Mean Reward: -1.1329, Mean KL Div: 10.4139
# Epoch 938/1000, Mean Reward: -1.1303, Mean KL Div: 10.1716
# Epoch 939/1000, Mean Reward: -1.1246, Mean KL Div: 10.6026
# Epoch 940/1000, Mean Reward: -1.1334, Mean KL Div: 10.5945
# Epoch 941/1000, Mean Reward: -1.1991, Mean KL Div: 10.4433
# Epoch 942/1000, Mean Reward: -1.0863, Mean KL Div: 10.5568
# Epoch 943/1000, Mean Reward: -1.1763, Mean KL Div: 10.5236
# Epoch 944/1000, Mean Reward: -1.0800, Mean KL Div: 10.3991
# Epoch 945/1000, Mean Reward: -1.1020, Mean KL Div: 10.6352
# Epoch 946/1000, Mean Reward: -1.1440, Mean KL Div: 10.4412
# Epoch 947/1000, Mean Reward: -1.0911, Mean KL Div: 10.3859
# Epoch 948/1000, Mean Reward: -1.0912, Mean KL Div: 10.4698
# Epoch 949/1000, Mean Reward: -1.1191, Mean KL Div: 10.2904
# Epoch 950/1000, Mean Reward: -1.1027, Mean KL Div: 10.5696
# Epoch 951/1000, Mean Reward: -1.0721, Mean KL Div: 10.4618
# Epoch 952/1000, Mean Reward: -1.0694, Mean KL Div: 10.5766
# Epoch 953/1000, Mean Reward: -1.0890, Mean KL Div: 10.7717
# Epoch 954/1000, Mean Reward: -1.1640, Mean KL Div: 10.6326
# Epoch 955/1000, Mean Reward: -1.1214, Mean KL Div: 10.8996
# Epoch 956/1000, Mean Reward: -1.0415, Mean KL Div: 10.6561
# Epoch 957/1000, Mean Reward: -1.0918, Mean KL Div: 10.7956
# Epoch 958/1000, Mean Reward: -1.1177, Mean KL Div: 10.8507
# Epoch 959/1000, Mean Reward: -1.0397, Mean KL Div: 10.6072
# Epoch 960/1000, Mean Reward: -1.0740, Mean KL Div: 11.1219
# Epoch 961/1000, Mean Reward: -1.0854, Mean KL Div: 11.0739
# Epoch 962/1000, Mean Reward: -1.1154, Mean KL Div: 10.8770
# Epoch 963/1000, Mean Reward: -1.0949, Mean KL Div: 10.8957
# Epoch 964/1000, Mean Reward: -1.0837, Mean KL Div: 10.9017
# Epoch 965/1000, Mean Reward: -1.0758, Mean KL Div: 10.9727
# Epoch 966/1000, Mean Reward: -1.0619, Mean KL Div: 10.9981
# Epoch 967/1000, Mean Reward: -1.0567, Mean KL Div: 10.8907
# Epoch 968/1000, Mean Reward: -1.1249, Mean KL Div: 11.1185
# Epoch 969/1000, Mean Reward: -1.0484, Mean KL Div: 10.8566
# Epoch 970/1000, Mean Reward: -1.0539, Mean KL Div: 10.9796
# Epoch 971/1000, Mean Reward: -1.0497, Mean KL Div: 11.1040
# Epoch 972/1000, Mean Reward: -1.0892, Mean KL Div: 11.1694
# Epoch 973/1000, Mean Reward: -1.0494, Mean KL Div: 10.8154
# Epoch 974/1000, Mean Reward: -1.0562, Mean KL Div: 11.0741
# Epoch 975/1000, Mean Reward: -1.0752, Mean KL Div: 11.3119
# Epoch 976/1000, Mean Reward: -1.0639, Mean KL Div: 11.0961
# Epoch 977/1000, Mean Reward: -1.0547, Mean KL Div: 11.1093
# Epoch 978/1000, Mean Reward: -1.0497, Mean KL Div: 10.7859
# Epoch 979/1000, Mean Reward: -1.0307, Mean KL Div: 11.0718
# Epoch 980/1000, Mean Reward: -1.0951, Mean KL Div: 11.3438
# Epoch 981/1000, Mean Reward: -1.0627, Mean KL Div: 11.4273
# Epoch 982/1000, Mean Reward: -1.0479, Mean KL Div: 11.2905
# Epoch 983/1000, Mean Reward: -1.0324, Mean KL Div: 11.0954
# Epoch 984/1000, Mean Reward: -1.0376, Mean KL Div: 10.9287
# Epoch 985/1000, Mean Reward: -1.0576, Mean KL Div: 11.1835
# Epoch 986/1000, Mean Reward: -1.0407, Mean KL Div: 11.5133
# Epoch 987/1000, Mean Reward: -1.0773, Mean KL Div: 11.1927
# Epoch 988/1000, Mean Reward: -1.0546, Mean KL Div: 10.9814
# Epoch 989/1000, Mean Reward: -1.0240, Mean KL Div: 10.9941
# Epoch 990/1000, Mean Reward: -1.0043, Mean KL Div: 11.2936
# Epoch 991/1000, Mean Reward: -1.0642, Mean KL Div: 11.0867
# Epoch 992/1000, Mean Reward: -1.0218, Mean KL Div: 11.0047
# Epoch 993/1000, Mean Reward: -1.0399, Mean KL Div: 11.0353
# Epoch 994/1000, Mean Reward: -1.0731, Mean KL Div: 11.1883
# Epoch 995/1000, Mean Reward: -1.1258, Mean KL Div: 11.3578
# Epoch 996/1000, Mean Reward: -1.0043, Mean KL Div: 11.1971
# Epoch 997/1000, Mean Reward: -1.0161, Mean KL Div: 10.9713
# Epoch 998/1000, Mean Reward: -1.0710, Mean KL Div: 11.0539
# Epoch 999/1000, Mean Reward: -1.0324, Mean KL Div: 11.0592
# Epoch 1000/1000, Mean Reward: -1.0023, Mean KL Div: 11.3613

# %%
rl_samples = ddim_sample(rl_model, scheduler, 10000, device)
rl_reward = compute_reward(rl_samples).mean()
rl_samples = rl_samples.cpu().numpy()

# %% [markdown]
# ## Direct Backpropagation fine-tuning with KL regularizaiton

# %%
# Copy pre-trained weights to fine-tune model
backprop_model = copy.deepcopy(pre_trained_model)
optimizer = optim.Adam(backprop_model.parameters(), lr=3e-5)

backprop_epochs = 500

# %%
# Fine-tuning loop

def fine_tune_step(pre_trained_model, fine_tune_model, scheduler, optimizer, kl_weight, max_grad_norm=1.0):
    optimizer.zero_grad()

    kl_loss = 0.0

    x_prev = torch.randn((256, 2)).to(device)
    batch_size = x_prev.shape[0]

    for t in scheduler.timesteps:
        t = torch.full((batch_size,), t, device=x_prev.device, dtype=torch.long)
        with torch.no_grad():
            pre_trained_noise_pred = pre_trained_model(x_prev, t.float() / scheduler.num_train_timesteps)
    
        fine_tune_noise_pred = fine_tune_model(x_prev, t.float() / scheduler.num_train_timesteps)
    
        x_prev, _, kl_div = ddim_step_KL(scheduler, fine_tune_noise_pred, pre_trained_noise_pred, t, x_prev, eta=1.0)
        kl_loss += kl_div

    reward = compute_reward(x_prev)
    
    loss = -reward.mean() + kl_weight * kl_loss.mean()
    
    loss.backward()

    # Clip gradients and perform optimization step
    nn.utils.clip_grad_norm_(fine_tune_model.parameters(), max_grad_norm)
    optimizer.step()
    
    return loss.item(), reward.mean().item(), kl_loss.mean().item()

for epoch in range(backprop_epochs):
    loss, reward, kl_div = fine_tune_step(pre_trained_model, backprop_model, scheduler, optimizer, kl_weight, max_grad_norm=5.0)
    if epoch % 10 == 0:
        print(f"Fine-tuning Epoch {epoch}, Loss: {loss:.4f}, Reward: {reward:.4f}, KL Div: {kl_div:.16f}")
# Out:
# Fine-tuning Epoch 0, Loss: 8.5387, Reward: -8.5387, KL Div: 0.0000000000000000
# Fine-tuning Epoch 10, Loss: 8.7352, Reward: -8.6797, KL Div: 0.0555233135819435
# Fine-tuning Epoch 20, Loss: 8.3396, Reward: -8.1329, KL Div: 0.2067385017871857
# Fine-tuning Epoch 30, Loss: 8.0747, Reward: -7.6465, KL Div: 0.4282434582710266
# Fine-tuning Epoch 40, Loss: 6.9581, Reward: -6.3514, KL Div: 0.6067738533020020
# Fine-tuning Epoch 50, Loss: 6.8680, Reward: -5.9841, KL Div: 0.8838304877281189
# Fine-tuning Epoch 60, Loss: 7.3129, Reward: -6.0742, KL Div: 1.2386596202850342
# Fine-tuning Epoch 70, Loss: 7.4486, Reward: -5.8972, KL Div: 1.5513668060302734
# Fine-tuning Epoch 80, Loss: 7.3199, Reward: -5.5465, KL Div: 1.7734230756759644
# Fine-tuning Epoch 90, Loss: 7.1386, Reward: -5.1057, KL Div: 2.0329780578613281
# Fine-tuning Epoch 100, Loss: 7.8255, Reward: -5.3054, KL Div: 2.5200738906860352
# Fine-tuning Epoch 110, Loss: 7.4202, Reward: -4.7266, KL Div: 2.6935632228851318
# Fine-tuning Epoch 120, Loss: 7.1184, Reward: -4.2911, KL Div: 2.8272831439971924
# Fine-tuning Epoch 130, Loss: 7.3010, Reward: -4.1602, KL Div: 3.1407408714294434
# Fine-tuning Epoch 140, Loss: 7.4444, Reward: -4.0556, KL Div: 3.3887975215911865
# Fine-tuning Epoch 150, Loss: 8.4188, Reward: -4.4903, KL Div: 3.9284873008728027
# Fine-tuning Epoch 160, Loss: 7.5859, Reward: -3.7403, KL Div: 3.8455557823181152
# Fine-tuning Epoch 170, Loss: 7.9779, Reward: -3.7742, KL Div: 4.2037410736083984
# Fine-tuning Epoch 180, Loss: 7.8168, Reward: -3.5216, KL Div: 4.2951884269714355
# Fine-tuning Epoch 190, Loss: 8.4556, Reward: -3.6960, KL Div: 4.7596607208251953
# Fine-tuning Epoch 200, Loss: 8.2693, Reward: -3.4176, KL Div: 4.8516817092895508
# Fine-tuning Epoch 210, Loss: 8.3685, Reward: -3.3741, KL Div: 4.9944171905517578
# Fine-tuning Epoch 220, Loss: 8.8105, Reward: -3.4372, KL Div: 5.3732819557189941
# Fine-tuning Epoch 230, Loss: 8.4356, Reward: -3.0656, KL Div: 5.3700866699218750
# Fine-tuning Epoch 240, Loss: 9.3177, Reward: -3.3662, KL Div: 5.9514884948730469
# Fine-tuning Epoch 250, Loss: 9.1945, Reward: -3.2001, KL Div: 5.9943523406982422
# Fine-tuning Epoch 260, Loss: 9.4868, Reward: -3.2856, KL Div: 6.2011766433715820
# Fine-tuning Epoch 270, Loss: 9.6127, Reward: -3.1693, KL Div: 6.4433960914611816
# Fine-tuning Epoch 280, Loss: 9.0043, Reward: -2.8065, KL Div: 6.1977882385253906
# Fine-tuning Epoch 290, Loss: 9.5286, Reward: -2.9859, KL Div: 6.5427312850952148
# Fine-tuning Epoch 300, Loss: 9.9446, Reward: -3.0438, KL Div: 6.9007854461669922
# Fine-tuning Epoch 310, Loss: 9.8140, Reward: -2.9354, KL Div: 6.8786029815673828
# Fine-tuning Epoch 320, Loss: 9.8212, Reward: -2.9515, KL Div: 6.8697633743286133
# Fine-tuning Epoch 330, Loss: 9.9998, Reward: -2.8520, KL Div: 7.1477851867675781
# Fine-tuning Epoch 340, Loss: 9.4594, Reward: -2.7224, KL Div: 6.7370381355285645
# Fine-tuning Epoch 350, Loss: 10.2035, Reward: -2.9373, KL Div: 7.2661581039428711
# Fine-tuning Epoch 360, Loss: 9.6683, Reward: -2.7088, KL Div: 6.9594759941101074
# Fine-tuning Epoch 370, Loss: 10.3712, Reward: -2.9607, KL Div: 7.4105243682861328
# Fine-tuning Epoch 380, Loss: 10.3220, Reward: -2.9050, KL Div: 7.4169321060180664
# Fine-tuning Epoch 390, Loss: 10.0996, Reward: -2.7783, KL Div: 7.3212761878967285
# Fine-tuning Epoch 400, Loss: 9.9302, Reward: -2.6397, KL Div: 7.2904577255249023
# Fine-tuning Epoch 410, Loss: 9.9213, Reward: -2.6266, KL Div: 7.2947511672973633
# Fine-tuning Epoch 420, Loss: 10.0155, Reward: -2.6921, KL Div: 7.3234157562255859
# Fine-tuning Epoch 430, Loss: 10.0500, Reward: -2.6409, KL Div: 7.4090862274169922
# Fine-tuning Epoch 440, Loss: 11.2061, Reward: -3.0369, KL Div: 8.1691951751708984
# Fine-tuning Epoch 450, Loss: 10.1759, Reward: -2.6095, KL Div: 7.5663442611694336
# Fine-tuning Epoch 460, Loss: 10.0982, Reward: -2.5766, KL Div: 7.5216579437255859
# Fine-tuning Epoch 470, Loss: 10.3898, Reward: -2.6456, KL Div: 7.7441220283508301
# Fine-tuning Epoch 480, Loss: 10.3413, Reward: -2.5830, KL Div: 7.7583351135253906
# Fine-tuning Epoch 490, Loss: 10.4340, Reward: -2.4668, KL Div: 7.9671487808227539

# %%
backprop_samples = ddim_sample(backprop_model, scheduler, 10000, device)
backprop_reward = compute_reward(backprop_samples).mean().item()
backprop_samples = backprop_samples.cpu().numpy()

# %% [markdown]
# ## Approximate Guidance

# %%
@torch.no_grad()
def guided_sampling(model, scheduler, n_samples, device, num_inference_steps=50, eta=0.0, rho=1):
    latents = torch.randn((n_samples, 2)).to(device)
    
    scheduler.set_timesteps(num_inference_steps)
    timesteps = scheduler.timesteps.to(device)

    for i, t in enumerate(timesteps):
        prev_timestep = t - scheduler.num_train_timesteps // num_inference_steps

        # Compute alpha_prod_t and alpha_prod_t_prev
        alpha_prod_t = scheduler.alphas_cumprod[t].to(device)
        alpha_prod_t_prev = torch.where(
            prev_timestep >= 0,
            scheduler.alphas_cumprod[prev_timestep],
            scheduler.final_alpha_cumprod
        )
        beta_prod_t = 1 - alpha_prod_t
        
        # Compute std_dev_t
        variance = (1 - alpha_prod_t_prev) / (1 - alpha_prod_t) * (1 - alpha_prod_t / alpha_prod_t_prev)
        std_dev_t = eta * variance.sqrt()

        with torch.enable_grad():
            latents = latents.detach().requires_grad_(True)
            time = torch.full((latents.shape[0],), t.item(), device=device, dtype=torch.float32)
            noise_pred = model(latents, time / scheduler.num_train_timesteps)

            pred_original_sample = (latents - beta_prod_t.sqrt() * noise_pred) / alpha_prod_t.sqrt()
            reward = compute_reward(pred_original_sample)
            
            approx_guidance = torch.autograd.grad(outputs=reward, inputs=latents, grad_outputs=torch.ones_like(reward))[0]
            
        approx_guidance = torch.nan_to_num(approx_guidance.detach())
        approx_guidance *= rho

        # Compute the predicted next sample mean
        pred_sample_direction = (1 - alpha_prod_t_prev - std_dev_t**2).sqrt() * noise_pred
        prev_sample_mean = alpha_prod_t_prev.sqrt() * pred_original_sample + pred_sample_direction
        
        # Add noise based on std_dev_t
        noise = torch.randn_like(latents)
        prev_sample = prev_sample_mean + std_dev_t * noise
        
        # Apply guidance
        prev_sample += approx_guidance
        latents = prev_sample

    return latents

# %%
rho = 1.0

# %%
guidance_samples = guided_sampling(
    pre_trained_model, scheduler, 10000, device, num_inference_steps=num_inference_steps, eta=1.0, rho=rho
)
guidance_reward = compute_reward(guidance_samples).mean().item()
guidance_samples = guidance_samples.cpu().numpy()

# %% [markdown]
# ## SMC

# %%
def smc_sampling(model, scheduler, n_samples, device, num_inference_steps=50, num_particles=100, 
                 resample_strategy='systematic', ess_threshold=0.5, 
                 tempering_gamma=1.,
                 eta=1.0, kl_coeff=1.0):
    latents = torch.randn((n_samples * num_particles, 2), device=device)
    scheduler.set_timesteps(num_inference_steps)
    timesteps = scheduler.timesteps

    log_w = torch.zeros(n_samples * num_particles, device=device)
    all_latents = []
    all_log_w = []
    all_resample_indices = []
    ess_trace = []
    tempering_trace = []
    rewards_trace = []

    resample_fn = resampling_function(resample_strategy=resample_strategy, ess_threshold=ess_threshold)

    for i, t in enumerate(timesteps):
        if i>0:
            log_twist_func_prev = log_twist_func.clone()
        prev_timestep = t - scheduler.num_train_timesteps // num_inference_steps

        # Compute alpha_prod_t and alpha_prod_t_prev
        alpha_prod_t = scheduler.alphas_cumprod[t].to(device)
        alpha_prod_t_prev = torch.where(
            prev_timestep >= 0,
            scheduler.alphas_cumprod[prev_timestep],
            scheduler.final_alpha_cumprod
        )
        beta_prod_t = 1 - alpha_prod_t
        
        # Compute std_dev_t
        variance = eta**2 * (1 - alpha_prod_t_prev) / (1 - alpha_prod_t) * (1 - alpha_prod_t / alpha_prod_t_prev)
        std_dev_t = variance.sqrt()

        # Calculate tempering factor
        tempering_factor = min((1 + tempering_gamma)**i - 1, 1.)

        # Predict noise and calculate reward
        t_input = torch.full((latents.shape[0],), t.item() / scheduler.num_train_timesteps, device=device, dtype=torch.float32)
        
        # latents.requires_grad_(True)
        # noise_pred = model(latents, t_input)
        # pred_original_sample = (latents - (1 - scheduler.alphas_cumprod[t]).sqrt() * noise_pred) / scheduler.alphas_cumprod[t].sqrt()
        # rewards = compute_reward(pred_original_sample)

        # # Calculate approximate guidance
        # approx_guidance = torch.autograd.grad(rewards.sum(), latents, create_graph=False, retain_graph=False)[0]
        # approx_guidance_1 = approx_guidance.detach().clone()
        # latents = latents.detach()

        latents.requires_grad_(True)
        noise_pred = model(latents, t_input)
        pred_original_sample = (latents - (1 - scheduler.alphas_cumprod[t]).sqrt() * noise_pred) / scheduler.alphas_cumprod[t].sqrt()
        rewards = compute_reward(pred_original_sample)

        # Calculate approximate guidance
        approx_guidance = torch.autograd.grad(outputs=rewards, inputs=latents, grad_outputs=torch.ones_like(rewards))[0]
        latents = latents.detach()

        approx_guidance = torch.nan_to_num(approx_guidance) / kl_coeff

        # Apply tempering
        approx_guidance *= tempering_factor

        # Update log weights
        log_twist_func = tempering_factor * rewards / kl_coeff
        log_w += log_twist_func - log_twist_func_prev + log_prob_diffusion - log_prob_proposal if i>0 else 0.

        # Resample if necessary
        ess = compute_ess_from_log_w(log_w.view(n_samples, -1))
        ess_trace.append(ess.cpu())

        # Detach log_w before resampling
        resample_indices, is_resampled, new_log_w = resample_fn(log_w.detach().view(n_samples, -1))
        # print(resample_indices.shape)
        log_w = new_log_w.view(-1).to(device)

        latents = latents.view(n_samples, num_particles, 2)[torch.arange(n_samples, device=device).unsqueeze(1), resample_indices].view(-1, 2)
        noise_pred = noise_pred.view(n_samples, num_particles, 2)[torch.arange(n_samples, device=device).unsqueeze(1), resample_indices].view(-1, 2)

        all_resample_indices.append(resample_indices)

        # Store latents and update rewards trace
        all_latents.append(latents.cpu())
        rewards_trace.append(rewards.view(n_samples, -1).max(dim=1)[0].cpu())

        # Sample from proposal distribution
        pred_sample_direction = (1 - alpha_prod_t_prev - std_dev_t**2).sqrt() * noise_pred
        prev_sample_mean = alpha_prod_t_prev.sqrt() * pred_original_sample + pred_sample_direction
        latents = prev_sample_mean + std_dev_t * torch.randn_like(noise_pred)
        latents += variance * approx_guidance

        log_prob_diffusion = -0.5 * (latents - prev_sample_mean).pow(2) / variance - torch.log(std_dev_t) - torch.log(torch.sqrt(2 * torch.as_tensor(math.pi)))
        log_prob_diffusion = log_prob_diffusion.sum(dim=-1) 
        log_prob_proposal = -0.5 * (latents - prev_sample_mean - variance * approx_guidance).pow(2) / variance - torch.log(std_dev_t) - torch.log(torch.sqrt(2 * torch.as_tensor(math.pi)))
        log_prob_proposal = log_prob_proposal.sum(dim=-1)

    # Final weight update
    final_rewards = compute_reward(latents)
    log_w += final_rewards / kl_coeff - log_twist_func + log_prob_diffusion - log_prob_proposal
    normalized_w = normalize_weights(log_w.view(n_samples, -1), dim=-1).view(-1)
    resample_indices, is_resampled, new_log_w = resample_fn(log_w.detach().view(n_samples, -1))
    latents = latents.view(n_samples, num_particles, 2)[torch.arange(n_samples, device=device).unsqueeze(1), resample_indices[:, torch.randperm(resample_indices.size(1))[:10]]].view(-1, 2)
    # latents = latents.view(n_samples, num_particles, 2)[:, torch.argmax(normalized_w.view(n_samples, num_particles), dim=-1)[1], :]

    ess_trace = torch.stack(ess_trace, dim=1) if ess_trace else torch.tensor([])
    tempering_trace = torch.tensor(tempering_trace, device=device)
    rewards_trace = torch.stack(rewards_trace, dim=1) if rewards_trace else torch.tensor([])

    return latents.detach()

# %%
num_particles = 100

# %%
smc_samples = smc_sampling(
    pre_trained_model, scheduler, n_samples=1000, device=device, num_inference_steps=num_inference_steps,
    num_particles=num_particles, resample_strategy='ssp', ess_threshold=.5,
    tempering_gamma=0.008,
    eta=1.0, kl_coeff=kl_weight
)

# %%
smc_reward = compute_reward(smc_samples).mean().item()
smc_samples = smc_samples.cpu().numpy()

# %% [markdown]
# # Visualize Samples and Rewards

# %%
# Plot results
plt.figure(figsize=(35, 4))

# Set common axis limits
x_min, x_max = -7, 7
y_min, y_max = -7, 7

plt.subplot(1, 6, 1)
plt.scatter(pre_trained_samples[:, 0], pre_trained_samples[:, 1], alpha=0.5, s=1)
plt.title(f'Pre-trained Model Distribution | reward: {pre_trained_reward:.2f}')
plt.xlabel('X')
plt.ylabel('Y')
plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.subplot(1, 6, 2)
plt.scatter(target_samples[:, 0], target_samples[:, 1], alpha=0.5, s=1)
plt.title(f'Target Distribution | reward: {target_reward:.2f}')
plt.xlabel('X')
plt.ylabel('Y')
plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.subplot(1, 6, 3)
plt.scatter(rl_samples[:, 0], rl_samples[:, 1], alpha=0.5, s=1)
plt.title(f'RL | reward: {rl_reward:.2f}')
plt.xlabel('X')
plt.ylabel('Y')
plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.subplot(1, 6, 4)
plt.scatter(backprop_samples[:, 0], backprop_samples[:, 1], alpha=0.5, s=1)
plt.title(f'Direct Backpropagation | reward: {backprop_reward:.2f}')
plt.xlabel('X')
plt.ylabel('Y')
plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.subplot(1, 6, 5)
plt.scatter(guidance_samples[:, 0], guidance_samples[:, 1], alpha=0.5, s=1)
plt.title(f'Approximate Guidance | reward: {guidance_reward:.2f}')
plt.xlabel('X')
plt.ylabel('Y')
plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.subplot(1, 6, 6)
plt.scatter(smc_samples[:, 0], smc_samples[:, 1], alpha=0.5, s=1)
plt.title(f'SMC | reward: {smc_reward:.2f}')
plt.xlabel('X')
plt.ylabel('Y')
plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.tight_layout()

# Save the figure
plt.savefig('gaussian_mixture_2.png', dpi=300, bbox_inches='tight')

plt.show()

plt.close()

print("Figure saved as 'gaussian_mixture_2.png'")
# Out:
# Figure saved as 'gaussian_mixture_2.png'

# %%
from scipy.stats import wasserstein_distance_nd as WD
from numpy.random import choice

rl_emd = WD(rl_samples[choice(np.arange(len(rl_samples)), 500)], target_samples[choice(np.arange(len(target_samples)), 500)])
backprop_emd = WD(backprop_samples[choice(np.arange(len(backprop_samples)), 500)], target_samples[choice(np.arange(len(target_samples)), 500)])
guidance_emd = WD(guidance_samples[choice(np.arange(len(guidance_samples)), 500)], target_samples[choice(np.arange(len(target_samples)), 500)])
smc_emd = WD(smc_samples[choice(np.arange(len(smc_samples)), 500)], target_samples[choice(np.arange(len(target_samples)), 500)])
